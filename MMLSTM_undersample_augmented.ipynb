# %%
from preprocess.preprocess import load_dataset, compute_label_agg, select_data, get_data_loaders, undersample

import torch
import torch.nn as nn
import torch.optim as optim

from models.RNN import MMRNN
from utils.RNN_utils import *
# Out:
# d:\SUTD\T6\DL Project\Deep_Learning_ECGclassification\utils\RNN_utils.py:3: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Define device for torch
use_cuda = True
device = torch.device("cuda" if (
    use_cuda and torch.cuda.is_available()) else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Define options

# %%
EPOCH = 20
LOAD_DATASET = True
TRAIN_PATH = './PTB_train_undersampled.pt'
VALID_PATH = './PTB_valid_undersampled.pt'
TEST_PATH = './PTB_test_undersampled.pt'
SAVE_NAME = f'MMRNN_undersampled_augmented_rm_epoch_{EPOCH}'
SAVE_DIR = './model_saves/'
BATCH_SIZE = 64


torch.manual_seed(1)

# %% [markdown]
# # Loading the main dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'

    data, raw_labels = load_dataset(path)

    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    data, labels, y = undersample(data, labels, y)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    torch.save(train_loader, TRAIN_PATH)
    torch.save(valid_loader, VALID_PATH)
    torch.save(test_loader, TEST_PATH)

# %% [markdown]
# # Loading the augmented data loaders

# %%
train_loader_rm = torch.load('./trainloader_augmented_rm.pt')
valid_loader_rm = torch.load('./validloader_augmented_rm.pt')
test_loader_rm = torch.load('./testloader_augmented_rm.pt')

train_loader_rn = torch.load('./trainloader_augmented_rn.pt')
valid_loader_rn = torch.load('./validloader_augmented_rn.pt')
test_loader_rn = torch.load('./testloader_augmented_rn.pt')

# %% [markdown]
# # Combining the undersampled dataset with the Random Masking augmented dataset

# %%
combined_train_rm_ds = torch.utils.data.ConcatDataset([train_loader.dataset, train_loader_rm.dataset])
combined_valid_rm_ds = torch.utils.data.ConcatDataset([valid_loader.dataset, valid_loader_rm.dataset])
combined_test_rm_ds = torch.utils.data.ConcatDataset([test_loader.dataset, test_loader_rm.dataset])

combined_rm_trainloader = torch.utils.data.DataLoader(combined_train_rm_ds, batch_size=BATCH_SIZE, shuffle=True)
combined_rm_validloader = torch.utils.data.DataLoader(combined_valid_rm_ds, batch_size=BATCH_SIZE)
combined_rm_testloader = torch.utils.data.DataLoader(combined_test_rm_ds, batch_size=BATCH_SIZE)

# %% [markdown]
# # Training the model with Random Masking augmented data

# %%
model = MMRNN().to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-2)
criterion = nn.BCEWithLogitsLoss()

model = train_RNN(EPOCH, combined_rm_trainloader, combined_rm_validloader, model,
                  criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: [1/20], Step [3968/316160] | Train Loss:  0.580         | Train Accuracy:  0.630         | Val Loss:  0.436         | Val Accuracy:  0.689
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [1/20], Step [7936/316160] | Train Loss:  0.480         | Train Accuracy:  0.703         | Val Loss:  0.394         | Val Accuracy:  0.762
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch:
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [17/20], Step [256896/316160] | Train Loss:  0.273         | Train Accuracy:  0.871         | Val Loss:  0.309         | Val Accuracy:  0.844
# Epoch: [17/20], Step [260864/316160] | Train Loss:  0.277         | Train Accuracy:  0.873         | Val Loss:  0.324         | Val Accuracy:  0.839
# Epoch: [17/20], Step [264832/316160] | Train Loss:  0.275         | Train Accuracy:  0.874         | Val Loss:  0.316         | Val Accuracy:  0.838
# Epoch: [17/20], Step [268736/316160] | Train Loss:  0.278         | Train Accuracy:  0.871         | Val Loss:  0.314         | Val Accuracy:  0.843
# Epoch: [18/20], Step [272704/316160] | Train Loss:  0.274         | Train Accuracy:  0.873         | Val Loss:  0.322         | Val Accuracy:  0.834
# Epoch: [18/20], Step [276672/316160] | Train Loss:  0.275         | Train Accuracy:  0.872         | Val Loss:  0.324         | Val Accuracy:  0.849
# Epoch: [18/20], Step [280640/316160] | Train Loss:  0.277         | Train Accuracy:  0.873         | Val Loss:  0.316         | Val Accuracy:  0.836
# Epoch: [18/20], Step [284544/316160] | Train Loss:  0.279         | Train Accuracy:  0.870         | Val Loss:  0.317         | Val Accuracy:  0.834
# Epoch: [19/20], Step [288512/316160] | Train Loss:  0.272         | Train Accuracy:  0.875         | Val Loss:  0.312         | Val Accuracy:  0.839
# Epoch: [19/20], Step [292480/316160] | Train Loss:  0.271         | Train Accuracy:  0.875         | Val Loss:  0.313         | Val Accuracy:  0.840
# Epoch: [19/20], Step [296448/316160] | Train Loss:  0.273         | Train Accuracy:  0.871         | Val Loss:  0.304         | Val Accuracy:  0.845
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [19/20], Step [300352/316160] | Train Loss:  0.274         | Train Accuracy:  0.873         | Val Loss:  0.304         | Val Accuracy:  0.857
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [20/20], Step [304320/316160] | Train Loss:  0.279         | Train Accuracy:  0.867         | Val Loss:  0.320         | Val Accuracy:  0.839
# Epoch: [20/20], Step [308288/316160] | Train Loss:  0.279         | Train Accuracy:  0.869         | Val Loss:  0.312         | Val Accuracy:  0.836
# Epoch: [20/20], Step [312256/316160] | Train Loss:  0.278         | Train Accuracy:  0.868         | Val Loss:  0.312         | Val Accuracy:  0.846
# Epoch: [20/20], Step [316160/316160] | Train Loss:  0.276         | Train Accuracy:  0.872         | Val Loss:  0.303         | Val Accuracy:  0.839
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Training complete.

# %% [markdown]
# ## Evaluate and plot losses

# %%
test_accuracy = evaluate_RNN(model, combined_rm_testloader)
plot_losses(metrics_save_name=SAVE_NAME, save_dir=SAVE_DIR)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_accuracy)
# Out:
# Test Accuracy:  0.839

# %% [markdown]
# # Combining the undersampled dataset with the Random Noising augmented dataset

# %%
combined_train_rn_ds = torch.utils.data.ConcatDataset([train_loader.dataset, train_loader_rn.dataset])
combined_valid_rn_ds = torch.utils.data.ConcatDataset([valid_loader.dataset, valid_loader_rn.dataset])
combined_test_rn_ds = torch.utils.data.ConcatDataset([test_loader.dataset, test_loader_rn.dataset])

combined_rn_trainloader = torch.utils.data.DataLoader(combined_train_rn_ds, batch_size=BATCH_SIZE, shuffle=True)
combined_rn_validloader = torch.utils.data.DataLoader(combined_valid_rn_ds, batch_size=BATCH_SIZE)
combined_rn_testloader = torch.utils.data.DataLoader(combined_test_rn_ds, batch_size=BATCH_SIZE)

# %% [markdown]
# # Redefine options

# %%
SAVE_NAME = f'MMRNN_undersampled_augmented_rn_epoch_{EPOCH}'

# %% [markdown]
# # Training the model with Random Noising augmented data

# %%
model = MMRNN().to(device)
optimizer = optim.AdamW(model.parameters(), lr=1e-2)
criterion = nn.BCEWithLogitsLoss()

model = train_RNN(EPOCH, combined_rn_trainloader, combined_rn_validloader, model,
                  criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: [1/20], Step [4032/320500] | Train Loss:  0.562         | Train Accuracy:  0.610         | Val Loss:  0.408         | Val Accuracy:  0.741
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [1/20], Step [8064/320500] | Train Loss:  0.473         | Train Accuracy:  0.690         | Val Loss:  0.377         | Val Accuracy:  0.770
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [1/20], Step [12032/320500] | Train Loss:  0.432         | Train Accuracy:  0.731         | Val Loss:  0.379         | Val Accuracy:  0.782
# Epoch: [1/20], Step [16025/320500] | Train Loss:  0.410         | Train Accuracy:  0.755         | Val Loss:  0.359         | Val Accuracy:  0.799
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [2/20], Step [20057/320500] | Train Loss:  0.335         | Train Accuracy:  0.829         | Val Loss:  0.352         | Val Accuracy:  0.805
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [2/20], Step [24089/320500] | Train Loss:  0.330         | Train Accuracy:  0.837         | Val Loss:  0.352         | Val Accuracy:  0.822
# Epoch: [2/20], Step [28057/320500] | Train Loss:  0.330         | Train Accuracy:  0.837         | Val Loss:  0.355         | Val Accuracy:  0.816
# Epoch: [2/20], Step [32050/320500] | Train Loss:  0.330         | Train Accuracy:  0.840         | Val Loss:  0.344         | Val Accuracy:  0.813
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [3/20], Step [36082/320500] | Train Loss:  0.308         | Train Accuracy:  0.857         | Val Loss:  0.333         | Val Accuracy:  0.832
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [3/20], Step [40114/320500] | Train Loss:  0.313         | Train Accuracy:  0.851         | Val Loss:  0.337         | Val Accuracy:  0.830
# Epoch: [3/20], Step [44082/320500] | Train Loss:  0.318         | Train Accuracy:  0.848         | Val Loss:  0.347         | Val Accuracy:  0.820
# Epoch: [3/20], Step [48075/320500] | Train Loss:  0.318         | Train Accuracy:  0.848         | Val Loss:  0.362         | Val Accuracy:  0.798
# Epoch: [4/20], Step [52107/320500] | Train Loss:  0.307         | Train Accuracy:  0.853         | Val Loss:  0.342         | Val Accuracy:  0.811
# Epoch: [4/20], Step [56139/320500] | Train Loss:  0.309         | Train Accuracy:  0.849         | Val Loss:  0.341         | Val Accuracy:  0.831
# Epoch: [4/20], Step [60107/320500] | Train Loss:  0.312         | Train Accuracy:  0.848         | Val Loss:  0.364         | Val Accuracy:  0.796
# Epoch: [4/20], Step [64100/320500] | Train Loss:  0.308         | Train Accuracy:  0.852         | Val Loss:  0.341         | Val Accuracy:  0.824
# Epoch: [5/20], Step [68132/320500] | Train Loss:  0.295         | Train Accuracy:  0.853         | Val Loss:  0.347         | Val Accuracy:  0.824
# Epoch: [5/20], Step [72164/320500] | Train Loss:  0.300         | Train Accuracy:  0.851         | Val Loss:  0.345         | Val Accuracy:  0.812
# Epoch: [5/20], Step [76132/320500] | Train Loss:  0.301         | Train Accuracy:  0.853         | Val Loss:  0.324         | Val Accuracy:  0.838
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch:
# Epoch: [16/20], Step [248375/320500] | Train Loss:  0.279         | Train Accuracy:  0.870         | Val Loss:  0.327         | Val Accuracy:  0.838
# Epoch: [16/20], Step [252407/320500] | Train Loss:  0.278         | Train Accuracy:  0.872         | Val Loss:  0.321         | Val Accuracy:  0.832
# Epoch: [16/20], Step [256400/320500] | Train Loss:  0.277         | Train Accuracy:  0.872         | Val Loss:  0.316         | Val Accuracy:  0.837
# Epoch: [17/20], Step [260432/320500] | Train Loss:  0.271         | Train Accuracy:  0.875         | Val Loss:  0.332         | Val Accuracy:  0.834
# Epoch: [17/20], Step [264400/320500] | Train Loss:  0.271         | Train Accuracy:  0.880         | Val Loss:  0.309         | Val Accuracy:  0.844
# Epoch: [17/20], Step [268432/320500] | Train Loss:  0.271         | Train Accuracy:  0.878         | Val Loss:  0.302         | Val Accuracy:  0.845
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [17/20], Step [272425/320500] | Train Loss:  0.271         | Train Accuracy:  0.877         | Val Loss:  0.307         | Val Accuracy:  0.843
# Epoch: [18/20], Step [276457/320500] | Train Loss:  0.264         | Train Accuracy:  0.875         | Val Loss:  0.326         | Val Accuracy:  0.824
# Epoch: [18/20], Step [280425/320500] | Train Loss:  0.265         | Train Accuracy:  0.876         | Val Loss:  0.307         | Val Accuracy:  0.847
# Epoch: [18/20], Step [284457/320500] | Train Loss:  0.271         | Train Accuracy:  0.874         | Val Loss:  0.295         | Val Accuracy:  0.846
# Model saved to ==> ./model_saves/model_MMRNN_undersampled_augmented_rn_epoch_20.pt
# Epoch: [18/20], Step [288450/320500] | Train Loss:  0.273         | Train Accuracy:  0.873         | Val Loss:  0.305         | Val Accuracy:  0.850
# Epoch: [19/20], Step [292482/320500] | Train Loss:  0.266         | Train Accuracy:  0.887         | Val Loss:  0.316         | Val Accuracy:  0.837
# Epoch: [19/20], Step [296450/320500] | Train Loss:  0.271         | Train Accuracy:  0.877         | Val Loss:  0.322         | Val Accuracy:  0.843
# Epoch: [19/20], Step [300482/320500] | Train Loss:  0.270         | Train Accuracy:  0.877         | Val Loss:  0.313         | Val Accuracy:  0.834
# Epoch: [19/20], Step [304475/320500] | Train Loss:  0.271         | Train Accuracy:  0.876         | Val Loss:  0.301         | Val Accuracy:  0.852
# Epoch: [20/20], Step [308507/320500] | Train Loss:  0.266         | Train Accuracy:  0.879         | Val Loss:  0.306         | Val Accuracy:  0.843
# Epoch: [20/20], Step [312475/320500] | Train Loss:  0.266         | Train Accuracy:  0.879         | Val Loss:  0.310         | Val Accuracy:  0.851
# Epoch: [20/20], Step [316507/320500] | Train Loss:  0.268         | Train Accuracy:  0.878         | Val Loss:  0.301         | Val Accuracy:  0.849
# Epoch: [20/20], Step [320500/320500] | Train Loss:  0.268         | Train Accuracy:  0.878         | Val Loss:  0.310         | Val Accuracy:  0.846
# Training complete.

# %% [markdown]
# ## Evaluate and plot losses

# %%
test_accuracy = evaluate_RNN(model, combined_rn_testloader)
plot_losses(metrics_save_name=SAVE_NAME, save_dir=SAVE_DIR)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_accuracy)
# Out:
# Test Accuracy:  0.842
