# %%
from preprocess.preprocess import load_dataset, compute_label_agg, select_data, get_data_loaders, undersample

import torch
import torch.nn as nn
import torch.optim as optim

from models.CNN import CNN
from utils.trainer import trainer
from utils.RNN_utils import plot_losses, rename_with_acc

# %%
# Define device for torch
use_cuda = True
device = torch.device("cuda" if (
    use_cuda and torch.cuda.is_available()) else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Define options

# %%
LOAD_DATASET = False
TRAIN_PATH = './PTB_train.pt'
VALID_PATH = './PTB_valid.pt'
TEST_PATH = './PTB_test.pt'
SAVE_NAME = 'CNN_epoch_30_shuffle'
SAVE_DIR = './model_saves/'
BATCH_SIZE = 256

# %% [markdown]
# # Loading the Base Dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)
# Out:
# Start loading
# done loading

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = CNN().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
# cuda
# Epoch [1/30], Step [10/67], Train Loss: 0.5642
# Epoch [1/30], Train Accuracy: 0.3895
# Epoch [1/30], Validation Accuracy: 0.4450, Validation Loss: 0.5538
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [1/30], Step [20/67], Train Loss: 0.5435
# Epoch [1/30], Train Accuracy: 0.4150
# Epoch [1/30], Validation Accuracy: 0.4450, Validation Loss: 0.5470
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [1/30], Step [30/67], Train Loss: 0.5291
# Epoch [1/30], Train Accuracy: 0.4245
# Epoch [1/30], Validation Accuracy: 0.4450, Validation Loss: 0.5419
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [1/30], Step [40/67], Train Loss: 0.5310
# Epoch [1/30], Train Accuracy: 0.4308
# Epoch [1/30], Validation Accuracy: 0.4459, Validation Loss: 0.5340
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [1/30], Step [50/67], Train Loss: 0.5299
# Epoch [1/30], Train Accuracy: 0.4330
# Epoch [1/30], Validation Accuracy: 0.4651, Validation Loss: 0.5252
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [1/30], Step [60/67], Train Loss: 0.4981
# Epoch [1/30], Train Accuracy: 0.4407
# Epoch [1/30], Validation Accuracy: 0.4762, Validation Loss: 0.5170
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [1/30], Step [67/67], Train Loss: 0.4872
# Epoch [1/30], Train Accuracy: 0.4450
# Epoch [1/30], Validation Accuracy: 0.4814, Validation Loss: 0.5127
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [2/30], Step [10/67], Train Loss: 0.4881
# Epoch [2/30], Train Accuracy: 0.5094
# Epoch [2/30], Validation Accuracy: 0.4856, Validation Loss: 0.5066
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [2/30], Step [20/67], Train Loss: 0.4800
# Epoch [2/30], Train Accuracy: 0.5121
# Epoch [2/30], Validation Accuracy: 0.5312, Validation Loss: 0.4960
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [2/30], Step [30/67], Train Loss: 0.4930
# Epoch [2/30], Train Accuracy: 0.5191
# Epoch [2/30], Validation Accuracy: 0.5415, Validation Loss: 0.4921
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [2/30], Step [40/67], Train Loss: 0.4719
# Epoch [2/30], Train Accuracy: 0.5223
# Epoch [2/30], Validation Accuracy: 0.5429, Validation Loss: 0.4849
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [2/30], Step [50/67], Train Loss: 0.4660
# Epoch [2/30], Train Accuracy: 0.5270
# Epoch [2/30], Validation Accuracy: 0.5513, Validation Loss: 0.4803
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [2/30], Step [60/67], Train Loss: 0.4819
# Epoch [2/30], Train Accuracy: 0.5321
# Epoch [2/30], Validation Accuracy: 0.5564, Validation Loss: 0.4752
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [2/30], Step [67/67], Train Loss: 0.5161
# Epoch [2/30], Train Accuracy: 0.5319
# Epoch [2/30], Validation Accuracy: 0.5638, Validation Loss: 0.4806
# Epoch [3/30], Step [10/67], Train Loss: 0.4805
# Epoch [3/30], Train Accuracy: 0.5664
# Epoch [3/30], Validation Accuracy: 0.5811, Validation Loss: 0.4678
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [3/30], Step [20/67], Train Loss: 0.4670
# Epoch [3/30], Train Accuracy: 0.5705
# Epoch [3/30], Validation Accuracy: 0.5806, Validation Loss: 0.4639
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [3/30], Step [30/67], Train Loss: 0.4457
# Epoch [3/30], Train Accuracy: 0.5803
# Epoch [3/30], Validation Accuracy: 0.5899, Validation Loss: 0.4578
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [3/30], Step [40/67], Train Loss: 0.4622
# Epoch [3/30], Train Accuracy: 0.5812
# Epoch [3/30], Validation Accuracy: 0.5983, Validation Loss: 0.4535
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [3/30], Step [50/67], Train Loss: 0.4534
# Epoch [3/30], Train Accuracy: 0.5805
# Epoch [3/30], Validation Accuracy: 0.5853, Validation Loss: 0.4549
# Epoch [3/30], Step [60/67], Train Loss: 0.4555
# Epoch [3/30], Train Accuracy: 0.5839
# Epoch [3/30], Validation Accuracy: 0.5909, Validation Loss: 0.4484
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [3/30], Step [67/67], Train Loss: 0.4583
# Epoch [3/30], Train Accuracy: 0.5859
# Epoch [3/30], Validation Accuracy: 0.6030, Validation Loss: 0.4422
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [4/30], Step [10/67], Train Loss: 0.4290
# Epoch [4/30], Train Accuracy: 0.6191
# Epoch [4/30], Validation Accuracy: 0.6062, Validation Loss: 0.4391
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [4/30], Step [20/67], Train Loss: 0.4295
# Epoch [4/30], Train Accuracy: 0.6135
# Epoch [4/30], Validation Accuracy: 0.6142, Validation Loss: 0.4355
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [4/30], Step [30/67], Train Loss: 0.4564
# Epoch [4/30], Train Accuracy: 0.6141
# Epoch [4/30], Validation Accuracy: 0.6128, Validation Loss: 0.4323
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [4/30], Step [40/67], Train Loss: 0.4198
# Epoch [4/30], Train Accuracy: 0.6202
# Epoch [4/30], Validation Accuracy: 0.6137, Validation Loss: 0.4306
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [4/30], Step [50/67], Train Loss: 0.4173
# Epoch [4/30], Train Accuracy: 0.6209
# Epoch [4/30], Validation Accuracy: 0.6272, Validation Loss: 0.4263
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [4/30], Step [60/67], Train Loss: 0.4068
# Epoch [4/30], Train Accuracy: 0.6237
# Epoch [4/30], Validation Accuracy: 0.6179, Validation Loss: 0.4266
# Epoch [4/30], Step [67/67], Train Loss: 0.4359
# Epoch [4/30], Train Accuracy: 0.6238
# Epoch [4/30], Validation Accuracy: 0.6267, Validation Loss: 0.4262
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [5/30], Step [10/67], Train Loss: 0.4170
# Epoch [5/30], Train Accuracy: 0.6535
# Epoch [5/30], Validation Accuracy: 0.6253, Validation Loss: 0.4232
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [5/30], Step [20/67], Train Loss: 0.4028
# Epoch [5/30], Train Accuracy: 0.6551
# Epoch [5/30], Validation Accuracy: 0.6365, Validation Loss: 0.4173
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [5/30], Step [30/67], Train Loss: 0.4123
# Epoch [5/30], Train Accuracy: 0.6553
# Epoch [5/30], Validation Accuracy: 0.6244, Validation Loss: 0.4217
# Epoch [5/30], Step [40/67], Train Loss: 0.4015
# Epoch [5/30], Train Accuracy: 0.6546
# Epoch [5/30], Validation Accuracy: 0.6277, Validation Loss: 0.4198
# Epoch [5/30], Step [50/67], Train Loss: 0.3754
# Epoch [5/30], Train Accuracy: 0.6556
# Epoch [5/30], Validation Accuracy: 0.6365, Validation Loss: 0.4145
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [5/30], Step [60/67], Train Loss: 0.4078
# Epoch [5/30], Train Accuracy: 0.6537
# Epoch [5/30], Validation Accuracy: 0.6417, Validation Loss: 0.4113
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [5/30], Step [67/67], Train Loss: 0.4307
# Epoch [5/30], Train Accuracy: 0.6528
# Epoch [5/30], Validation Accuracy: 0.6486, Validation Loss: 0.4094
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [6/30], Step [10/67], Train Loss: 0.4030
# Epoch [6/30], Train Accuracy: 0.6648
# Epoch [6/30], Validation Accuracy: 0.6496, Validation Loss: 0.4082
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [6/30], Step [20/67], Train Loss: 0.4309
# Epoch [6/30], Train Accuracy: 0.6631
# Epoch [6/30], Validation Accuracy: 0.6309, Validation Loss: 0.4152
# Epoch [6/30], Step [30/67], Train Loss: 0.4050
# Epoch [6/30], Train Accuracy: 0.6583
# Epoch [6/30], Validation Accuracy: 0.6473, Validation Loss: 0.4060
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [6/30], Step [40/67], Train Loss: 0.3806
# Epoch [6/30], Train Accuracy: 0.6581
# Epoch [6/30], Validation Accuracy: 0.6454, Validation Loss: 0.4069
# Epoch [6/30], Step [50/67], Train Loss: 0.3793
# Epoch [6/30], Train Accuracy: 0.6615
# Epoch [6/30], Validation Accuracy: 0.6421, Validation Loss: 0.4094
# Epoch [6/30], Step [60/67], Train Loss: 0.3856
# Epoch [6/30], Train Accuracy: 0.6629
# Epoch [6/30], Validation Accuracy: 0.6570, Validation Loss: 0.4021
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [6/30], Step [67/67], Train Loss: 0.3871
# Epoch [6/30], Train Accuracy: 0.6654
# Epoch [6/30], Validation Accuracy: 0.6514, Validation Loss: 0.4000
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [7/30], Step [10/67], Train Loss: 0.4100
# Epoch [7/30], Train Accuracy: 0.6738
# Epoch [7/30], Validation Accuracy: 0.6547, Validation Loss: 0.4006
# Epoch [7/30], Step [20/67], Train Loss: 0.3927
# Epoch [7/30], Train Accuracy: 0.6809
# Epoch [7/30], Validation Accuracy: 0.6528, Validation Loss: 0.4005
# Epoch [7/30], Step [30/67], Train Loss: 0.4004
# Epoch [7/30], Train Accuracy: 0.6785
# Epoch [7/30], Validation Accuracy: 0.6608, Validation Loss: 0.3980
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [7/30], Step [40/67], Train Loss: 0.3559
# Epoch [7/30], Train Accuracy: 0.6777
# Epoch [7/30], Validation Accuracy: 0.6561, Validation Loss: 0.3974
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [7/30], Step [50/67], Train Loss: 0.3856
# Epoch [7/30], Train Accuracy: 0.6759
# Epoch [7/30], Validation Accuracy: 0.6612, Validation Loss: 0.3937
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [7/30], Step [60/67], Train Loss: 0.3775
# Epoch [7/30], Train Accuracy: 0.6781
# Epoch [7/30], Validation Accuracy: 0.6608, Validation Loss: 0.3937
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [7/30], Step [67/67], Train Loss: 0.3779
# Epoch [7/30], Train Accuracy: 0.6771
# Epoch [7/30], Validation Accuracy: 0.6654, Validation Loss: 0.3920
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [8/30], Step [10/67], Train Loss: 0.3927
# Epoch [8/30], Train Accuracy: 0.7008
# Epoch [8/30], Validation Accuracy: 0.6636, Validation Loss: 0.3918
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [8/30], Step [20/67], Train Loss: 0.3772
# Epoch [8/30], Train Accuracy: 0.6969
# Epoch [8/30], Validation Accuracy: 0.6594, Validation Loss: 0.3932
# Epoch [8/30], Step [30/67], Train Loss: 0.3705
# Epoch [8/30], Train Accuracy: 0.6958
# Epoch [8/30], Validation Accuracy: 0.6580, Validation Loss: 0.3943
# Epoch [8/30], Step [40/67], Train Loss: 0.3645
# Epoch [8/30], Train Accuracy: 0.6954
# Epoch [8/30], Validation Accuracy: 0.6678, Validation Loss: 0.3883
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [8/30], Step [50/67], Train Loss: 0.3511
# Epoch [8/30], Train Accuracy: 0.6957
# Epoch [8/30], Validation Accuracy: 0.6715, Validation Loss: 0.3869
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [8/30], Step [60/67], Train Loss: 0.3745
# Epoch [8/30], Train Accuracy: 0.6958
# Epoch [8/30], Validation Accuracy: 0.6533, Validation Loss: 0.4022
# Epoch [8/30], Step [67/67], Train Loss: 0.3580
# Epoch [8/30], Train Accuracy: 0.6943
# Epoch [8/30], Validation Accuracy: 0.6673, Validation Loss: 0.3864
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [9/30], Step [10/67], Train Loss: 0.3808
# Epoch [9/30], Train Accuracy: 0.6965
# Epoch [9/30], Validation Accuracy: 0.6719, Validation Loss: 0.3851
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [9/30], Step [20/67], Train Loss: 0.3800
# Epoch [9/30], Train Accuracy: 0.6924
# Epoch [9/30], Validation Accuracy: 0.6789, Validation Loss: 0.3838
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [9/30], Step [30/67], Train Loss: 0.3743
# Epoch [9/30], Train Accuracy: 0.6964
# Epoch [9/30], Validation Accuracy: 0.6771, Validation Loss: 0.3832
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [9/30], Step [40/67], Train Loss: 0.3646
# Epoch [9/30], Train Accuracy: 0.6986
# Epoch [9/30], Validation Accuracy: 0.6841, Validation Loss: 0.3821
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [9/30], Step [50/67], Train Loss: 0.3404
# Epoch [9/30], Train Accuracy: 0.6984
# Epoch [9/30], Validation Accuracy: 0.6785, Validation Loss: 0.3830
# Epoch [9/30], Step [60/67], Train Loss: 0.3944
# Epoch [9/30], Train Accuracy: 0.7001
# Epoch [9/30], Validation Accuracy: 0.6813, Validation Loss: 0.3807
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [9/30], Step [67/67], Train Loss: 0.3850
# Epoch [9/30], Train Accuracy: 0.7014
# Epoch [9/30], Validation Accuracy: 0.6761, Validation Loss: 0.3825
# Epoch [10/30], Step [10/67], Train Loss: 0.3487
# Epoch [10/30], Train Accuracy: 0.7063
# Epoch [10/30], Validation Accuracy: 0.6701, Validation Loss: 0.3885
# Epoch [10/30], Step [20/67], Train Loss: 0.3555
# Epoch [10/30], Train Accuracy: 0.7154
# Epoch [10/30], Validation Accuracy: 0.6752, Validation Loss: 0.3815
# Epoch [10/30], Step [30/67], Train Loss: 0.3598
# Epoch [10/30], Train Accuracy: 0.7087
# Epoch [10/30], Validation Accuracy: 0.6869, Validation Loss: 0.3790
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [10/30], Step [40/67], Train Loss: 0.3854
# Epoch [10/30], Train Accuracy: 0.7065
# Epoch [10/30], Validation Accuracy: 0.6864, Validation Loss: 0.3801
# Epoch [10/30], Step [50/67], Train Loss: 0.3515
# Epoch [10/30], Train Accuracy: 0.7084
# Epoch [10/30], Validation Accuracy: 0.6761, Validation Loss: 0.3815
# Epoch [10/30], Step [60/67], Train Loss: 0.3550
# Epoch [10/30], Train Accuracy: 0.7077
# Epoch [10/30], Validation Accuracy: 0.6911, Validation Loss: 0.3771
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [10/30], Step [67/67], Train Loss: 0.3689
# Epoch [10/30], Train Accuracy: 0.7081
# Epoch [10/30], Validation Accuracy: 0.6952, Validation Loss: 0.3757
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [11/30], Step [10/67], Train Loss: 0.3452
# Epoch [11/30], Train Accuracy: 0.7133
# Epoch [11/30], Validation Accuracy: 0.6897, Validation Loss: 0.3758
# Epoch [11/30], Step [20/67], Train Loss: 0.3510
# Epoch [11/30], Train Accuracy: 0.7141
# Epoch [11/30], Validation Accuracy: 0.6962, Validation Loss: 0.3748
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [11/30], Step [30/67], Train Loss: 0.3699
# Epoch [11/30], Train Accuracy: 0.7186
# Epoch [11/30], Validation Accuracy: 0.6934, Validation Loss: 0.3744
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [11/30], Step [40/67], Train Loss: 0.3230
# Epoch [11/30], Train Accuracy: 0.7177
# Epoch [11/30], Validation Accuracy: 0.6771, Validation Loss: 0.3836
# Epoch [11/30], Step [50/67], Train Loss: 0.3599
# Epoch [11/30], Train Accuracy: 0.7152
# Epoch [11/30], Validation Accuracy: 0.6943, Validation Loss: 0.3733
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [11/30], Step [60/67], Train Loss: 0.3723
# Epoch [11/30], Train Accuracy: 0.7135
# Epoch [11/30], Validation Accuracy: 0.6952, Validation Loss: 0.3723
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [11/30], Step [67/67], Train Loss: 0.3373
# Epoch [11/30], Train Accuracy: 0.7149
# Epoch [11/30], Validation Accuracy: 0.6799, Validation Loss: 0.3837
# Epoch [12/30], Step [10/67], Train Loss: 0.3265
# Epoch [12/30], Train Accuracy: 0.7176
# Epoch [12/30], Validation Accuracy: 0.6911, Validation Loss: 0.3746
# Epoch [12/30], Step [20/67], Train Loss: 0.3681
# Epoch [12/30], Train Accuracy: 0.7229
# Epoch [12/30], Validation Accuracy: 0.7004, Validation Loss: 0.3729
# Epoch [12/30], Step [30/67], Train Loss: 0.3302
# Epoch [12/30], Train Accuracy: 0.7236
# Epoch [12/30], Validation Accuracy: 0.6901, Validation Loss: 0.3731
# Epoch [12/30], Step [40/67], Train Loss: 0.3608
# Epoch [12/30], Train Accuracy: 0.7197
# Epoch [12/30], Validation Accuracy: 0.6943, Validation Loss: 0.3721
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [12/30], Step [50/67], Train Loss: 0.3658
# Epoch [12/30], Train Accuracy: 0.7194
# Epoch [12/30], Validation Accuracy: 0.6897, Validation Loss: 0.3720
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [12/30], Step [60/67], Train Loss: 0.3748
# Epoch [12/30], Train Accuracy: 0.7219
# Epoch [12/30], Validation Accuracy: 0.7027, Validation Loss: 0.3711
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [12/30], Step [67/67], Train Loss: 0.3470
# Epoch [12/30], Train Accuracy: 0.7216
# Epoch [12/30], Validation Accuracy: 0.7022, Validation Loss: 0.3718
# Epoch [13/30], Step [10/67], Train Loss: 0.3843
# Epoch [13/30], Train Accuracy: 0.7152
# Epoch [13/30], Validation Accuracy: 0.6938, Validation Loss: 0.3778
# Epoch [13/30], Step [20/67], Train Loss: 0.3271
# Epoch [13/30], Train Accuracy: 0.7137
# Epoch [13/30], Validation Accuracy: 0.7008, Validation Loss: 0.3709
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [13/30], Step [30/67], Train Loss: 0.3304
# Epoch [13/30], Train Accuracy: 0.7207
# Epoch [13/30], Validation Accuracy: 0.7018, Validation Loss: 0.3683
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [13/30], Step [40/67], Train Loss: 0.3683
# Epoch [13/30], Train Accuracy: 0.7221
# Epoch [13/30], Validation Accuracy: 0.6934, Validation Loss: 0.3725
# Epoch [13/30], Step [50/67], Train Loss: 0.3344
# Epoch [13/30], Train Accuracy: 0.7226
# Epoch [13/30], Validation Accuracy: 0.6789, Validation Loss: 0.3914
# Epoch [13/30], Step [60/67], Train Loss: 0.3325
# Epoch [13/30], Train Accuracy: 0.7229
# Epoch [13/30], Validation Accuracy: 0.6920, Validation Loss: 0.3749
# Epoch [13/30], Step [67/67], Train Loss: 0.3875
# Epoch [13/30], Train Accuracy: 0.7237
# Epoch [13/30], Validation Accuracy: 0.6985, Validation Loss: 0.3685
# Epoch [14/30], Step [10/67], Train Loss: 0.3546
# Epoch [14/30], Train Accuracy: 0.7426
# Epoch [14/30], Validation Accuracy: 0.6980, Validation Loss: 0.3688
# Epoch [14/30], Step [20/67], Train Loss: 0.3535
# Epoch [14/30], Train Accuracy: 0.7393
# Epoch [14/30], Validation Accuracy: 0.6957, Validation Loss: 0.3717
# Epoch [14/30], Step [30/67], Train Loss: 0.3398
# Epoch [14/30], Train Accuracy: 0.7359
# Epoch [14/30], Validation Accuracy: 0.6887, Validation Loss: 0.3786
# Epoch [14/30], Step [40/67], Train Loss: 0.3609
# Epoch [14/30], Train Accuracy: 0.7297
# Epoch [14/30], Validation Accuracy: 0.6901, Validation Loss: 0.3838
# Epoch [14/30], Step [50/67], Train Loss: 0.3432
# Epoch [14/30], Train Accuracy: 0.7279
# Epoch [14/30], Validation Accuracy: 0.7130, Validation Loss: 0.3660
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [14/30], Step [60/67], Train Loss: 0.3583
# Epoch [14/30], Train Accuracy: 0.7273
# Epoch [14/30], Validation Accuracy: 0.7088, Validation Loss: 0.3669
# Epoch [14/30], Step [67/67], Train Loss: 0.3274
# Epoch [14/30], Train Accuracy: 0.7278
# Epoch [14/30], Validation Accuracy: 0.7055, Validation Loss: 0.3712
# Epoch [15/30], Step [10/67], Train Loss: 0.3321
# Epoch [15/30], Train Accuracy: 0.7363
# Epoch [15/30], Validation Accuracy: 0.7041, Validation Loss: 0.3672
# Epoch [15/30], Step [20/67], Train Loss: 0.3531
# Epoch [15/30], Train Accuracy: 0.7365
# Epoch [15/30], Validation Accuracy: 0.7120, Validation Loss: 0.3638
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [15/30], Step [30/67], Train Loss: 0.3566
# Epoch [15/30], Train Accuracy: 0.7311
# Epoch [15/30], Validation Accuracy: 0.7018, Validation Loss: 0.3735
# Epoch [15/30], Step [40/67], Train Loss: 0.3475
# Epoch [15/30], Train Accuracy: 0.7336
# Epoch [15/30], Validation Accuracy: 0.7111, Validation Loss: 0.3642
# Epoch [15/30], Step [50/67], Train Loss: 0.3478
# Epoch [15/30], Train Accuracy: 0.7345
# Epoch [15/30], Validation Accuracy: 0.7027, Validation Loss: 0.3677
# Epoch [15/30], Step [60/67], Train Loss: 0.3596
# Epoch [15/30], Train Accuracy: 0.7325
# Epoch [15/30], Validation Accuracy: 0.7050, Validation Loss: 0.3667
# Epoch [15/30], Step [67/67], Train Loss: 0.3624
# Epoch [15/30], Train Accuracy: 0.7326
# Epoch [15/30], Validation Accuracy: 0.7078, Validation Loss: 0.3713
# Epoch [16/30], Step [10/67], Train Loss: 0.3599
# Epoch [16/30], Train Accuracy: 0.7281
# Epoch [16/30], Validation Accuracy: 0.7111, Validation Loss: 0.3718
# Epoch [16/30], Step [20/67], Train Loss: 0.3267
# Epoch [16/30], Train Accuracy: 0.7248
# Epoch [16/30], Validation Accuracy: 0.7050, Validation Loss: 0.3651
# Epoch [16/30], Step [30/67], Train Loss: 0.3083
# Epoch [16/30], Train Accuracy: 0.7305
# Epoch [16/30], Validation Accuracy: 0.7102, Validation Loss: 0.3632
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [16/30], Step [40/67], Train Loss: 0.3548
# Epoch [16/30], Train Accuracy: 0.7314
# Epoch [16/30], Validation Accuracy: 0.7199, Validation Loss: 0.3624
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [16/30], Step [50/67], Train Loss: 0.3590
# Epoch [16/30], Train Accuracy: 0.7323
# Epoch [16/30], Validation Accuracy: 0.7139, Validation Loss: 0.3623
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [16/30], Step [60/67], Train Loss: 0.3649
# Epoch [16/30], Train Accuracy: 0.7337
# Epoch [16/30], Validation Accuracy: 0.7102, Validation Loss: 0.3707
# Epoch [16/30], Step [67/67], Train Loss: 0.3143
# Epoch [16/30], Train Accuracy: 0.7333
# Epoch [16/30], Validation Accuracy: 0.7139, Validation Loss: 0.3618
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [17/30], Step [10/67], Train Loss: 0.3363
# Epoch [17/30], Train Accuracy: 0.7363
# Epoch [17/30], Validation Accuracy: 0.7144, Validation Loss: 0.3629
# Epoch [17/30], Step [20/67], Train Loss: 0.3380
# Epoch [17/30], Train Accuracy: 0.7369
# Epoch [17/30], Validation Accuracy: 0.7144, Validation Loss: 0.3621
# Epoch [17/30], Step [30/67], Train Loss: 0.3479
# Epoch [17/30], Train Accuracy: 0.7418
# Epoch [17/30], Validation Accuracy: 0.7074, Validation Loss: 0.3682
# Epoch [17/30], Step [40/67], Train Loss: 0.3315
# Epoch [17/30], Train Accuracy: 0.7387
# Epoch [17/30], Validation Accuracy: 0.7069, Validation Loss: 0.3641
# Epoch [17/30], Step [50/67], Train Loss: 0.3615
# Epoch [17/30], Train Accuracy: 0.7366
# Epoch [17/30], Validation Accuracy: 0.7148, Validation Loss: 0.3656
# Epoch [17/30], Step [60/67], Train Loss: 0.3654
# Epoch [17/30], Train Accuracy: 0.7355
# Epoch [17/30], Validation Accuracy: 0.7078, Validation Loss: 0.3649
# Epoch [17/30], Step [67/67], Train Loss: 0.3648
# Epoch [17/30], Train Accuracy: 0.7358
# Epoch [17/30], Validation Accuracy: 0.7120, Validation Loss: 0.3648
# Epoch [18/30], Step [10/67], Train Loss: 0.3619
# Epoch [18/30], Train Accuracy: 0.7355
# Epoch [18/30], Validation Accuracy: 0.7097, Validation Loss: 0.3704
# Epoch [18/30], Step [20/67], Train Loss: 0.3332
# Epoch [18/30], Train Accuracy: 0.7375
# Epoch [18/30], Validation Accuracy: 0.7218, Validation Loss: 0.3595
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [18/30], Step [30/67], Train Loss: 0.3468
# Epoch [18/30], Train Accuracy: 0.7405
# Epoch [18/30], Validation Accuracy: 0.7218, Validation Loss: 0.3594
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [18/30], Step [40/67], Train Loss: 0.3602
# Epoch [18/30], Train Accuracy: 0.7408
# Epoch [18/30], Validation Accuracy: 0.7223, Validation Loss: 0.3600
# Epoch [18/30], Step [50/67], Train Loss: 0.3312
# Epoch [18/30], Train Accuracy: 0.7402
# Epoch [18/30], Validation Accuracy: 0.7022, Validation Loss: 0.3659
# Epoch [18/30], Step [60/67], Train Loss: 0.3144
# Epoch [18/30], Train Accuracy: 0.7403
# Epoch [18/30], Validation Accuracy: 0.7171, Validation Loss: 0.3600
# Epoch [18/30], Step [67/67], Train Loss: 0.3295
# Epoch [18/30], Train Accuracy: 0.7388
# Epoch [18/30], Validation Accuracy: 0.7246, Validation Loss: 0.3590
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [19/30], Step [10/67], Train Loss: 0.3312
# Epoch [19/30], Train Accuracy: 0.7480
# Epoch [19/30], Validation Accuracy: 0.7181, Validation Loss: 0.3585
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [19/30], Step [20/67], Train Loss: 0.3316
# Epoch [19/30], Train Accuracy: 0.7445
# Epoch [19/30], Validation Accuracy: 0.7153, Validation Loss: 0.3599
# Epoch [19/30], Step [30/67], Train Loss: 0.3306
# Epoch [19/30], Train Accuracy: 0.7452
# Epoch [19/30], Validation Accuracy: 0.7158, Validation Loss: 0.3629
# Epoch [19/30], Step [40/67], Train Loss: 0.3219
# Epoch [19/30], Train Accuracy: 0.7422
# Epoch [19/30], Validation Accuracy: 0.7153, Validation Loss: 0.3607
# Epoch [19/30], Step [50/67], Train Loss: 0.3590
# Epoch [19/30], Train Accuracy: 0.7398
# Epoch [19/30], Validation Accuracy: 0.7209, Validation Loss: 0.3578
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [19/30], Step [60/67], Train Loss: 0.3505
# Epoch [19/30], Train Accuracy: 0.7396
# Epoch [19/30], Validation Accuracy: 0.7162, Validation Loss: 0.3615
# Epoch [19/30], Step [67/67], Train Loss: 0.3060
# Epoch [19/30], Train Accuracy: 0.7403
# Epoch [19/30], Validation Accuracy: 0.7097, Validation Loss: 0.3721
# Epoch [20/30], Step [10/67], Train Loss: 0.3392
# Epoch [20/30], Train Accuracy: 0.7488
# Epoch [20/30], Validation Accuracy: 0.7237, Validation Loss: 0.3577
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [20/30], Step [20/67], Train Loss: 0.3538
# Epoch [20/30], Train Accuracy: 0.7455
# Epoch [20/30], Validation Accuracy: 0.7209, Validation Loss: 0.3604
# Epoch [20/30], Step [30/67], Train Loss: 0.3280
# Epoch [20/30], Train Accuracy: 0.7410
# Epoch [20/30], Validation Accuracy: 0.7260, Validation Loss: 0.3564
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [20/30], Step [40/67], Train Loss: 0.3466
# Epoch [20/30], Train Accuracy: 0.7430
# Epoch [20/30], Validation Accuracy: 0.7167, Validation Loss: 0.3609
# Epoch [20/30], Step [50/67], Train Loss: 0.3501
# Epoch [20/30], Train Accuracy: 0.7411
# Epoch [20/30], Validation Accuracy: 0.7120, Validation Loss: 0.3608
# Epoch [20/30], Step [60/67], Train Loss: 0.3106
# Epoch [20/30], Train Accuracy: 0.7423
# Epoch [20/30], Validation Accuracy: 0.7162, Validation Loss: 0.3616
# Epoch [20/30], Step [67/67], Train Loss: 0.3152
# Epoch [20/30], Train Accuracy: 0.7440
# Epoch [20/30], Validation Accuracy: 0.7232, Validation Loss: 0.3578
# Epoch [21/30], Step [10/67], Train Loss: 0.3593
# Epoch [21/30], Train Accuracy: 0.7457
# Epoch [21/30], Validation Accuracy: 0.7255, Validation Loss: 0.3568
# Epoch [21/30], Step [20/67], Train Loss: 0.3022
# Epoch [21/30], Train Accuracy: 0.7467
# Epoch [21/30], Validation Accuracy: 0.7190, Validation Loss: 0.3580
# Epoch [21/30], Step [30/67], Train Loss: 0.3680
# Epoch [21/30], Train Accuracy: 0.7484
# Epoch [21/30], Validation Accuracy: 0.7265, Validation Loss: 0.3573
# Epoch [21/30], Step [40/67], Train Loss: 0.3391
# Epoch [21/30], Train Accuracy: 0.7488
# Epoch [21/30], Validation Accuracy: 0.7237, Validation Loss: 0.3563
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [21/30], Step [50/67], Train Loss: 0.3512
# Epoch [21/30], Train Accuracy: 0.7466
# Epoch [21/30], Validation Accuracy: 0.7158, Validation Loss: 0.3637
# Epoch [21/30], Step [60/67], Train Loss: 0.3214
# Epoch [21/30], Train Accuracy: 0.7484
# Epoch [21/30], Validation Accuracy: 0.7246, Validation Loss: 0.3550
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [21/30], Step [67/67], Train Loss: 0.3203
# Epoch [21/30], Train Accuracy: 0.7483
# Epoch [21/30], Validation Accuracy: 0.7232, Validation Loss: 0.3559
# Epoch [22/30], Step [10/67], Train Loss: 0.3388
# Epoch [22/30], Train Accuracy: 0.7477
# Epoch [22/30], Validation Accuracy: 0.7297, Validation Loss: 0.3556
# Epoch [22/30], Step [20/67], Train Loss: 0.3611
# Epoch [22/30], Train Accuracy: 0.7545
# Epoch [22/30], Validation Accuracy: 0.7190, Validation Loss: 0.3624
# Epoch [22/30], Step [30/67], Train Loss: 0.3513
# Epoch [22/30], Train Accuracy: 0.7484
# Epoch [22/30], Validation Accuracy: 0.7097, Validation Loss: 0.3682
# Epoch [22/30], Step [40/67], Train Loss: 0.3330
# Epoch [22/30], Train Accuracy: 0.7480
# Epoch [22/30], Validation Accuracy: 0.7134, Validation Loss: 0.3631
# Epoch [22/30], Step [50/67], Train Loss: 0.3426
# Epoch [22/30], Train Accuracy: 0.7481
# Epoch [22/30], Validation Accuracy: 0.7181, Validation Loss: 0.3577
# Epoch [22/30], Step [60/67], Train Loss: 0.3389
# Epoch [22/30], Train Accuracy: 0.7503
# Epoch [22/30], Validation Accuracy: 0.7139, Validation Loss: 0.3653
# Epoch [22/30], Step [67/67], Train Loss: 0.3370
# Epoch [22/30], Train Accuracy: 0.7494
# Epoch [22/30], Validation Accuracy: 0.7302, Validation Loss: 0.3551
# Epoch [23/30], Step [10/67], Train Loss: 0.3417
# Epoch [23/30], Train Accuracy: 0.7602
# Epoch [23/30], Validation Accuracy: 0.7288, Validation Loss: 0.3542
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [23/30], Step [20/67], Train Loss: 0.3203
# Epoch [23/30], Train Accuracy: 0.7652
# Epoch [23/30], Validation Accuracy: 0.7255, Validation Loss: 0.3544
# Epoch [23/30], Step [30/67], Train Loss: 0.3476
# Epoch [23/30], Train Accuracy: 0.7638
# Epoch [23/30], Validation Accuracy: 0.7176, Validation Loss: 0.3598
# Epoch [23/30], Step [40/67], Train Loss: 0.3315
# Epoch [23/30], Train Accuracy: 0.7555
# Epoch [23/30], Validation Accuracy: 0.7190, Validation Loss: 0.3594
# Epoch [23/30], Step [50/67], Train Loss: 0.3248
# Epoch [23/30], Train Accuracy: 0.7527
# Epoch [23/30], Validation Accuracy: 0.7260, Validation Loss: 0.3554
# Epoch [23/30], Step [60/67], Train Loss: 0.3017
# Epoch [23/30], Train Accuracy: 0.7533
# Epoch [23/30], Validation Accuracy: 0.7125, Validation Loss: 0.3684
# Epoch [23/30], Step [67/67], Train Loss: 0.2693
# Epoch [23/30], Train Accuracy: 0.7522
# Epoch [23/30], Validation Accuracy: 0.7269, Validation Loss: 0.3571
# Epoch [24/30], Step [10/67], Train Loss: 0.3304
# Epoch [24/30], Train Accuracy: 0.7633
# Epoch [24/30], Validation Accuracy: 0.7288, Validation Loss: 0.3529
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [24/30], Step [20/67], Train Loss: 0.3333
# Epoch [24/30], Train Accuracy: 0.7578
# Epoch [24/30], Validation Accuracy: 0.6938, Validation Loss: 0.4019
# Epoch [24/30], Step [30/67], Train Loss: 0.3158
# Epoch [24/30], Train Accuracy: 0.7562
# Epoch [24/30], Validation Accuracy: 0.7293, Validation Loss: 0.3529
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [24/30], Step [40/67], Train Loss: 0.3381
# Epoch [24/30], Train Accuracy: 0.7538
# Epoch [24/30], Validation Accuracy: 0.7335, Validation Loss: 0.3559
# Epoch [24/30], Step [50/67], Train Loss: 0.3405
# Epoch [24/30], Train Accuracy: 0.7532
# Epoch [24/30], Validation Accuracy: 0.7190, Validation Loss: 0.3627
# Epoch [24/30], Step [60/67], Train Loss: 0.3457
# Epoch [24/30], Train Accuracy: 0.7520
# Epoch [24/30], Validation Accuracy: 0.7316, Validation Loss: 0.3525
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [24/30], Step [67/67], Train Loss: 0.3796
# Epoch [24/30], Train Accuracy: 0.7525
# Epoch [24/30], Validation Accuracy: 0.7307, Validation Loss: 0.3539
# Epoch [25/30], Step [10/67], Train Loss: 0.3552
# Epoch [25/30], Train Accuracy: 0.7680
# Epoch [25/30], Validation Accuracy: 0.7302, Validation Loss: 0.3584
# Epoch [25/30], Step [20/67], Train Loss: 0.3336
# Epoch [25/30], Train Accuracy: 0.7641
# Epoch [25/30], Validation Accuracy: 0.7260, Validation Loss: 0.3542
# Epoch [25/30], Step [30/67], Train Loss: 0.3525
# Epoch [25/30], Train Accuracy: 0.7586
# Epoch [25/30], Validation Accuracy: 0.7269, Validation Loss: 0.3558
# Epoch [25/30], Step [40/67], Train Loss: 0.3315
# Epoch [25/30], Train Accuracy: 0.7557
# Epoch [25/30], Validation Accuracy: 0.7335, Validation Loss: 0.3531
# Epoch [25/30], Step [50/67], Train Loss: 0.3375
# Epoch [25/30], Train Accuracy: 0.7570
# Epoch [25/30], Validation Accuracy: 0.7311, Validation Loss: 0.3523
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [25/30], Step [60/67], Train Loss: 0.3218
# Epoch [25/30], Train Accuracy: 0.7566
# Epoch [25/30], Validation Accuracy: 0.7106, Validation Loss: 0.3688
# Epoch [25/30], Step [67/67], Train Loss: 0.3334
# Epoch [25/30], Train Accuracy: 0.7552
# Epoch [25/30], Validation Accuracy: 0.7321, Validation Loss: 0.3520
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [26/30], Step [10/67], Train Loss: 0.3500
# Epoch [26/30], Train Accuracy: 0.7504
# Epoch [26/30], Validation Accuracy: 0.7269, Validation Loss: 0.3638
# Epoch [26/30], Step [20/67], Train Loss: 0.3185
# Epoch [26/30], Train Accuracy: 0.7625
# Epoch [26/30], Validation Accuracy: 0.7302, Validation Loss: 0.3541
# Epoch [26/30], Step [30/67], Train Loss: 0.3922
# Epoch [26/30], Train Accuracy: 0.7570
# Epoch [26/30], Validation Accuracy: 0.7297, Validation Loss: 0.3568
# Epoch [26/30], Step [40/67], Train Loss: 0.3435
# Epoch [26/30], Train Accuracy: 0.7622
# Epoch [26/30], Validation Accuracy: 0.7311, Validation Loss: 0.3533
# Epoch [26/30], Step [50/67], Train Loss: 0.3209
# Epoch [26/30], Train Accuracy: 0.7592
# Epoch [26/30], Validation Accuracy: 0.7288, Validation Loss: 0.3506
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [26/30], Step [60/67], Train Loss: 0.3257
# Epoch [26/30], Train Accuracy: 0.7583
# Epoch [26/30], Validation Accuracy: 0.7363, Validation Loss: 0.3506
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [26/30], Step [67/67], Train Loss: 0.3733
# Epoch [26/30], Train Accuracy: 0.7587
# Epoch [26/30], Validation Accuracy: 0.7316, Validation Loss: 0.3505
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [27/30], Step [10/67], Train Loss: 0.3370
# Epoch [27/30], Train Accuracy: 0.7680
# Epoch [27/30], Validation Accuracy: 0.7265, Validation Loss: 0.3559
# Epoch [27/30], Step [20/67], Train Loss: 0.3304
# Epoch [27/30], Train Accuracy: 0.7605
# Epoch [27/30], Validation Accuracy: 0.7344, Validation Loss: 0.3524
# Epoch [27/30], Step [30/67], Train Loss: 0.3031
# Epoch [27/30], Train Accuracy: 0.7566
# Epoch [27/30], Validation Accuracy: 0.7279, Validation Loss: 0.3555
# Epoch [27/30], Step [40/67], Train Loss: 0.3411
# Epoch [27/30], Train Accuracy: 0.7568
# Epoch [27/30], Validation Accuracy: 0.7353, Validation Loss: 0.3505
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [27/30], Step [50/67], Train Loss: 0.3290
# Epoch [27/30], Train Accuracy: 0.7588
# Epoch [27/30], Validation Accuracy: 0.7302, Validation Loss: 0.3501
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [27/30], Step [60/67], Train Loss: 0.3258
# Epoch [27/30], Train Accuracy: 0.7599
# Epoch [27/30], Validation Accuracy: 0.7367, Validation Loss: 0.3531
# Epoch [27/30], Step [67/67], Train Loss: 0.3372
# Epoch [27/30], Train Accuracy: 0.7592
# Epoch [27/30], Validation Accuracy: 0.7335, Validation Loss: 0.3551
# Epoch [28/30], Step [10/67], Train Loss: 0.2912
# Epoch [28/30], Train Accuracy: 0.7609
# Epoch [28/30], Validation Accuracy: 0.7316, Validation Loss: 0.3512
# Epoch [28/30], Step [20/67], Train Loss: 0.3133
# Epoch [28/30], Train Accuracy: 0.7549
# Epoch [28/30], Validation Accuracy: 0.7311, Validation Loss: 0.3560
# Epoch [28/30], Step [30/67], Train Loss: 0.3130
# Epoch [28/30], Train Accuracy: 0.7572
# Epoch [28/30], Validation Accuracy: 0.7339, Validation Loss: 0.3521
# Epoch [28/30], Step [40/67], Train Loss: 0.3158
# Epoch [28/30], Train Accuracy: 0.7592
# Epoch [28/30], Validation Accuracy: 0.7381, Validation Loss: 0.3498
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [28/30], Step [50/67], Train Loss: 0.3334
# Epoch [28/30], Train Accuracy: 0.7602
# Epoch [28/30], Validation Accuracy: 0.7386, Validation Loss: 0.3522
# Epoch [28/30], Step [60/67], Train Loss: 0.3255
# Epoch [28/30], Train Accuracy: 0.7591
# Epoch [28/30], Validation Accuracy: 0.7358, Validation Loss: 0.3498
# Model saved to ==> ./model_saves/model_CNN_epoch_30_shuffle.pt
# Epoch [28/30], Step [67/67], Train Loss: 0.3061
# Epoch [28/30], Train Accuracy: 0.7620
# Epoch [28/30], Validation Accuracy: 0.7078, Validation Loss: 0.3791
# Epoch [29/30], Step [10/67], Train Loss: 0.3041
# Epoch [29/30], Train Accuracy: 0.7688
# Epoch [29/30], Validation Accuracy: 0.7335, Validation Loss: 0.3548
# Epoch [29/30], Step [20/67], Train Loss: 0.3175
# Epoch [29/30], Train Accuracy: 0.7762
# Epoch [29/30], Validation Accuracy: 0.7213, Validation Loss: 0.3660
# Epoch [29/30], Step [30/67], Train Loss: 0.3247
# Epoch [29/30], Train Accuracy: 0.7646
# Epoch [29/30], Validation Accuracy: 0.7283, Validation Loss: 0.3516
# Epoch [29/30], Step [40/67], Train Loss: 0.3272
# Epoch [29/30], Train Accuracy: 0.7617
# Epoch [29/30], Validation Accuracy: 0.7325, Validation Loss: 0.3529
# Epoch [29/30], Step [50/67], Train Loss: 0.3103
# Epoch [29/30], Train Accuracy: 0.7628
# Epoch [29/30], Validation Accuracy: 0.7255, Validation Loss: 0.3519
# Epoch [29/30], Step [60/67], Train Loss: 0.3336
# Epoch [29/30], Train Accuracy: 0.7619
# Epoch [29/30], Validation Accuracy: 0.7367, Validation Loss: 0.3501
# Epoch [29/30], Step [67/67], Train Loss: 0.3061
# Epoch [29/30], Train Accuracy: 0.7643
# Epoch [29/30], Validation Accuracy: 0.7363, Validation Loss: 0.3510
# Epoch [30/30], Step [10/67], Train Loss: 0.3508
# Epoch [30/30], Train Accuracy: 0.7633
# Epoch [30/30], Validation Accuracy: 0.7274, Validation Loss: 0.3558
# Epoch [30/30], Step [20/67], Train Loss: 0.3414
# Epoch [30/30], Train Accuracy: 0.7705
# Epoch [30/30], Validation Accuracy: 0.7335, Validation Loss: 0.3517
# Epoch [30/30], Step [30/67], Train Loss: 0.3335
# Epoch [30/30], Train Accuracy: 0.7677
# Epoch [30/30], Validation Accuracy: 0.7390, Validation Loss: 0.3508
# Epoch [30/30], Step [40/67], Train Loss: 0.3239
# Epoch [30/30], Train Accuracy: 0.7700
# Epoch [30/30], Validation Accuracy: 0.7395, Validation Loss: 0.3500
# Epoch [30/30], Step [50/67], Train Loss: 0.3166
# Epoch [30/30], Train Accuracy: 0.7657
# Epoch [30/30], Validation Accuracy: 0.7344, Validation Loss: 0.3498
# Epoch [30/30], Step [60/67], Train Loss: 0.2977
# Epoch [30/30], Train Accuracy: 0.7685
# Epoch [30/30], Validation Accuracy: 0.7260, Validation Loss: 0.3562
# Epoch [30/30], Step [67/67], Train Loss: 0.2972
# Epoch [30/30], Train Accuracy: 0.7666
# Epoch [30/30], Validation Accuracy: 0.7218, Validation Loss: 0.3646
# Ended Training, Test Accuracy: 0.7146

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)

# %% [markdown]
# # Loading the Undersampled Dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    data, labels, y = undersample(data, labels, y)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)

# %% [markdown]
# # Redefine Some Options

# %%
# SAVE_NAME = 'CNN_epoch_30'
SAVE_DIR = './model_saves_undersampled/'

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = CNN().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)
