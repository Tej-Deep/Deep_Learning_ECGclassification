# %%
from preprocess.preprocess import load_dataset, compute_label_agg, select_data, get_data_loaders

import torch
import torch.nn as nn
import torch.optim as optim

from models.CNN import MMCNN_CAT
from utils.trainer import trainer
from utils.RNN_utils import plot_losses, rename_with_acc

# %%
# Define device for torch
use_cuda = True
device = torch.device("cuda" if (
    use_cuda and torch.cuda.is_available()) else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Define options

# %%
LOAD_DATASET = False
TRAIN_PATH = './PTB_train.pt'
VALID_PATH = './PTB_valid.pt'
TEST_PATH = './PTB_test.pt'
SAVE_NAME = 'MMCNN_CAT_epoch_30'
SAVE_DIR = './model_saves/'
BATCH_SIZE = 256

# %% [markdown]
# # Loading the dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)
# Out:
# Start loading
# done loading

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = MMCNN_CAT().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
# cuda
# Epoch [1/30], Step [10/67], Train Loss: 0.4853
# Epoch [1/30], Train Accuracy: 0.4898
# Epoch [1/30], Validation Accuracy: 0.4450, Validation Loss: 0.5339
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [20/67], Train Loss: 0.5134
# Epoch [1/30], Train Accuracy: 0.4967
# Epoch [1/30], Validation Accuracy: 0.5084, Validation Loss: 0.5052
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [30/67], Train Loss: 0.4591
# Epoch [1/30], Train Accuracy: 0.4997
# Epoch [1/30], Validation Accuracy: 0.5256, Validation Loss: 0.4858
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [40/67], Train Loss: 0.4716
# Epoch [1/30], Train Accuracy: 0.5194
# Epoch [1/30], Validation Accuracy: 0.6398, Validation Loss: 0.4689
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [50/67], Train Loss: 0.4787
# Epoch [1/30], Train Accuracy: 0.5427
# Epoch [1/30], Validation Accuracy: 0.6426, Validation Loss: 0.4531
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [60/67], Train Loss: 0.4640
# Epoch [1/30], Train Accuracy: 0.5652
# Epoch [1/30], Validation Accuracy: 0.6710, Validation Loss: 0.4400
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [67/67], Train Loss: 0.4447
# Epoch [1/30], Train Accuracy: 0.5770
# Epoch [1/30], Validation Accuracy: 0.6733, Validation Loss: 0.4310
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [10/67], Train Loss: 0.4026
# Epoch [2/30], Train Accuracy: 0.7047
# Epoch [2/30], Validation Accuracy: 0.5979, Validation Loss: 0.4258
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [20/67], Train Loss: 0.4210
# Epoch [2/30], Train Accuracy: 0.6980
# Epoch [2/30], Validation Accuracy: 0.6622, Validation Loss: 0.4129
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [30/67], Train Loss: 0.3611
# Epoch [2/30], Train Accuracy: 0.6977
# Epoch [2/30], Validation Accuracy: 0.6692, Validation Loss: 0.4051
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [40/67], Train Loss: 0.3812
# Epoch [2/30], Train Accuracy: 0.7005
# Epoch [2/30], Validation Accuracy: 0.6980, Validation Loss: 0.3979
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [50/67], Train Loss: 0.4098
# Epoch [2/30], Train Accuracy: 0.7047
# Epoch [2/30], Validation Accuracy: 0.6915, Validation Loss: 0.3920
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [60/67], Train Loss: 0.4003
# Epoch [2/30], Train Accuracy: 0.7074
# Epoch [2/30], Validation Accuracy: 0.6962, Validation Loss: 0.3864
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [67/67], Train Loss: 0.3926
# Epoch [2/30], Train Accuracy: 0.7080
# Epoch [2/30], Validation Accuracy: 0.6962, Validation Loss: 0.3839
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [10/67], Train Loss: 0.3662
# Epoch [3/30], Train Accuracy: 0.7363
# Epoch [3/30], Validation Accuracy: 0.6925, Validation Loss: 0.3810
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [20/67], Train Loss: 0.3802
# Epoch [3/30], Train Accuracy: 0.7443
# Epoch [3/30], Validation Accuracy: 0.7064, Validation Loss: 0.3754
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [30/67], Train Loss: 0.3225
# Epoch [3/30], Train Accuracy: 0.7411
# Epoch [3/30], Validation Accuracy: 0.7027, Validation Loss: 0.3716
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [40/67], Train Loss: 0.3420
# Epoch [3/30], Train Accuracy: 0.7419
# Epoch [3/30], Validation Accuracy: 0.7218, Validation Loss: 0.3670
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [50/67], Train Loss: 0.3730
# Epoch [3/30], Train Accuracy: 0.7430
# Epoch [3/30], Validation Accuracy: 0.7195, Validation Loss: 0.3625
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [60/67], Train Loss: 0.3683
# Epoch [3/30], Train Accuracy: 0.7468
# Epoch [3/30], Validation Accuracy: 0.7176, Validation Loss: 0.3584
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [67/67], Train Loss: 0.3579
# Epoch [3/30], Train Accuracy: 0.7482
# Epoch [3/30], Validation Accuracy: 0.7199, Validation Loss: 0.3570
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [10/67], Train Loss: 0.3393
# Epoch [4/30], Train Accuracy: 0.7750
# Epoch [4/30], Validation Accuracy: 0.7195, Validation Loss: 0.3542
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [20/67], Train Loss: 0.3518
# Epoch [4/30], Train Accuracy: 0.7795
# Epoch [4/30], Validation Accuracy: 0.7400, Validation Loss: 0.3505
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [30/67], Train Loss: 0.2986
# Epoch [4/30], Train Accuracy: 0.7764
# Epoch [4/30], Validation Accuracy: 0.7269, Validation Loss: 0.3478
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [40/67], Train Loss: 0.3163
# Epoch [4/30], Train Accuracy: 0.7759
# Epoch [4/30], Validation Accuracy: 0.7465, Validation Loss: 0.3448
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [50/67], Train Loss: 0.3431
# Epoch [4/30], Train Accuracy: 0.7763
# Epoch [4/30], Validation Accuracy: 0.7432, Validation Loss: 0.3401
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [60/67], Train Loss: 0.3454
# Epoch [4/30], Train Accuracy: 0.7790
# Epoch [4/30], Validation Accuracy: 0.7474, Validation Loss: 0.3369
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [67/67], Train Loss: 0.3284
# Epoch [4/30], Train Accuracy: 0.7797
# Epoch [4/30], Validation Accuracy: 0.7498, Validation Loss: 0.3364
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [10/67], Train Loss: 0.3173
# Epoch [5/30], Train Accuracy: 0.7930
# Epoch [5/30], Validation Accuracy: 0.7535, Validation Loss: 0.3347
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [20/67], Train Loss: 0.3305
# Epoch [5/30], Train Accuracy: 0.7967
# Epoch [5/30], Validation Accuracy: 0.7600, Validation Loss: 0.3327
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [30/67], Train Loss: 0.2823
# Epoch [5/30], Train Accuracy: 0.7948
# Epoch [5/30], Validation Accuracy: 0.7549, Validation Loss: 0.3310
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [40/67], Train Loss: 0.3005
# Epoch [5/30], Train Accuracy: 0.7944
# Epoch [5/30], Validation Accuracy: 0.7540, Validation Loss: 0.3305
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [50/67], Train Loss: 0.3243
# Epoch [5/30], Train Accuracy: 0.7925
# Epoch [5/30], Validation Accuracy: 0.7605, Validation Loss: 0.3259
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [60/67], Train Loss: 0.3297
# Epoch [5/30], Train Accuracy: 0.7943
# Epoch [5/30], Validation Accuracy: 0.7610, Validation Loss: 0.3235
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [67/67], Train Loss: 0.3088
# Epoch [5/30], Train Accuracy: 0.7944
# Epoch [5/30], Validation Accuracy: 0.7637, Validation Loss: 0.3238
# Epoch [6/30], Step [10/67], Train Loss: 0.3045
# Epoch [6/30], Train Accuracy: 0.7977
# Epoch [6/30], Validation Accuracy: 0.7651, Validation Loss: 0.3227
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [20/67], Train Loss: 0.3168
# Epoch [6/30], Train Accuracy: 0.8049
# Epoch [6/30], Validation Accuracy: 0.7689, Validation Loss: 0.3216
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [30/67], Train Loss: 0.2702
# Epoch [6/30], Train Accuracy: 0.8048
# Epoch [6/30], Validation Accuracy: 0.7661, Validation Loss: 0.3204
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [40/67], Train Loss: 0.2897
# Epoch [6/30], Train Accuracy: 0.8048
# Epoch [6/30], Validation Accuracy: 0.7633, Validation Loss: 0.3213
# Epoch [6/30], Step [50/67], Train Loss: 0.3121
# Epoch [6/30], Train Accuracy: 0.8030
# Epoch [6/30], Validation Accuracy: 0.7665, Validation Loss: 0.3166
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [60/67], Train Loss: 0.3186
# Epoch [6/30], Train Accuracy: 0.8048
# Epoch [6/30], Validation Accuracy: 0.7689, Validation Loss: 0.3144
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [67/67], Train Loss: 0.2957
# Epoch [6/30], Train Accuracy: 0.8048
# Epoch [6/30], Validation Accuracy: 0.7721, Validation Loss: 0.3154
# Epoch [7/30], Step [10/67], Train Loss: 0.2955
# Epoch [7/30], Train Accuracy: 0.8086
# Epoch [7/30], Validation Accuracy: 0.7749, Validation Loss: 0.3143
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [20/67], Train Loss: 0.3072
# Epoch [7/30], Train Accuracy: 0.8146
# Epoch [7/30], Validation Accuracy: 0.7759, Validation Loss: 0.3138
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [30/67], Train Loss: 0.2602
# Epoch [7/30], Train Accuracy: 0.8146
# Epoch [7/30], Validation Accuracy: 0.7768, Validation Loss: 0.3124
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [40/67], Train Loss: 0.2816
# Epoch [7/30], Train Accuracy: 0.8144
# Epoch [7/30], Validation Accuracy: 0.7679, Validation Loss: 0.3139
# Epoch [7/30], Step [50/67], Train Loss: 0.3031
# Epoch [7/30], Train Accuracy: 0.8138
# Epoch [7/30], Validation Accuracy: 0.7749, Validation Loss: 0.3093
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [60/67], Train Loss: 0.3100
# Epoch [7/30], Train Accuracy: 0.8152
# Epoch [7/30], Validation Accuracy: 0.7759, Validation Loss: 0.3074
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [67/67], Train Loss: 0.2861
# Epoch [7/30], Train Accuracy: 0.8151
# Epoch [7/30], Validation Accuracy: 0.7759, Validation Loss: 0.3089
# Epoch [8/30], Step [10/67], Train Loss: 0.2881
# Epoch [8/30], Train Accuracy: 0.8180
# Epoch [8/30], Validation Accuracy: 0.7801, Validation Loss: 0.3075
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [20/67], Train Loss: 0.2994
# Epoch [8/30], Train Accuracy: 0.8213
# Epoch [8/30], Validation Accuracy: 0.7796, Validation Loss: 0.3072
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [30/67], Train Loss: 0.2519
# Epoch [8/30], Train Accuracy: 0.8227
# Epoch [8/30], Validation Accuracy: 0.7805, Validation Loss: 0.3059
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [40/67], Train Loss: 0.2754
# Epoch [8/30], Train Accuracy: 0.8232
# Epoch [8/30], Validation Accuracy: 0.7749, Validation Loss: 0.3077
# Epoch [8/30], Step [50/67], Train Loss: 0.2959
# Epoch [8/30], Train Accuracy: 0.8231
# Epoch [8/30], Validation Accuracy: 0.7810, Validation Loss: 0.3032
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [60/67], Train Loss: 0.3031
# Epoch [8/30], Train Accuracy: 0.8238
# Epoch [8/30], Validation Accuracy: 0.7847, Validation Loss: 0.3014
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [67/67], Train Loss: 0.2787
# Epoch [8/30], Train Accuracy: 0.8237
# Epoch [8/30], Validation Accuracy: 0.7805, Validation Loss: 0.3032
# Epoch [9/30], Step [10/67], Train Loss: 0.2814
# Epoch [9/30], Train Accuracy: 0.8238
# Epoch [9/30], Validation Accuracy: 0.7861, Validation Loss: 0.3017
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [20/67], Train Loss: 0.2931
# Epoch [9/30], Train Accuracy: 0.8275
# Epoch [9/30], Validation Accuracy: 0.7870, Validation Loss: 0.3017
# Epoch [9/30], Step [30/67], Train Loss: 0.2448
# Epoch [9/30], Train Accuracy: 0.8289
# Epoch [9/30], Validation Accuracy: 0.7847, Validation Loss: 0.3003
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [40/67], Train Loss: 0.2701
# Epoch [9/30], Train Accuracy: 0.8292
# Epoch [9/30], Validation Accuracy: 0.7824, Validation Loss: 0.3023
# Epoch [9/30], Step [50/67], Train Loss: 0.2898
# Epoch [9/30], Train Accuracy: 0.8295
# Epoch [9/30], Validation Accuracy: 0.7815, Validation Loss: 0.2978
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [60/67], Train Loss: 0.2975
# Epoch [9/30], Train Accuracy: 0.8303
# Epoch [9/30], Validation Accuracy: 0.7917, Validation Loss: 0.2961
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [67/67], Train Loss: 0.2727
# Epoch [9/30], Train Accuracy: 0.8306
# Epoch [9/30], Validation Accuracy: 0.7833, Validation Loss: 0.2980
# Epoch [10/30], Step [10/67], Train Loss: 0.2749
# Epoch [10/30], Train Accuracy: 0.8352
# Epoch [10/30], Validation Accuracy: 0.7903, Validation Loss: 0.2965
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [20/67], Train Loss: 0.2876
# Epoch [10/30], Train Accuracy: 0.8367
# Epoch [10/30], Validation Accuracy: 0.7936, Validation Loss: 0.2969
# Epoch [10/30], Step [30/67], Train Loss: 0.2385
# Epoch [10/30], Train Accuracy: 0.8374
# Epoch [10/30], Validation Accuracy: 0.7842, Validation Loss: 0.2953
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [40/67], Train Loss: 0.2655
# Epoch [10/30], Train Accuracy: 0.8375
# Epoch [10/30], Validation Accuracy: 0.7856, Validation Loss: 0.2970
# Epoch [10/30], Step [50/67], Train Loss: 0.2845
# Epoch [10/30], Train Accuracy: 0.8372
# Epoch [10/30], Validation Accuracy: 0.7912, Validation Loss: 0.2929
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [60/67], Train Loss: 0.2927
# Epoch [10/30], Train Accuracy: 0.8379
# Epoch [10/30], Validation Accuracy: 0.7936, Validation Loss: 0.2913
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [67/67], Train Loss: 0.2675
# Epoch [10/30], Train Accuracy: 0.8386
# Epoch [10/30], Validation Accuracy: 0.7875, Validation Loss: 0.2932
# Epoch [11/30], Step [10/67], Train Loss: 0.2692
# Epoch [11/30], Train Accuracy: 0.8395
# Epoch [11/30], Validation Accuracy: 0.7954, Validation Loss: 0.2917
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [20/67], Train Loss: 0.2827
# Epoch [11/30], Train Accuracy: 0.8418
# Epoch [11/30], Validation Accuracy: 0.8010, Validation Loss: 0.2926
# Epoch [11/30], Step [30/67], Train Loss: 0.2329
# Epoch [11/30], Train Accuracy: 0.8423
# Epoch [11/30], Validation Accuracy: 0.7931, Validation Loss: 0.2907
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [40/67], Train Loss: 0.2616
# Epoch [11/30], Train Accuracy: 0.8442
# Epoch [11/30], Validation Accuracy: 0.7940, Validation Loss: 0.2923
# Epoch [11/30], Step [50/67], Train Loss: 0.2798
# Epoch [11/30], Train Accuracy: 0.8436
# Epoch [11/30], Validation Accuracy: 0.7950, Validation Loss: 0.2883
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [60/67], Train Loss: 0.2886
# Epoch [11/30], Train Accuracy: 0.8447
# Epoch [11/30], Validation Accuracy: 0.7992, Validation Loss: 0.2869
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [67/67], Train Loss: 0.2631
# Epoch [11/30], Train Accuracy: 0.8450
# Epoch [11/30], Validation Accuracy: 0.7922, Validation Loss: 0.2887
# Epoch [12/30], Step [10/67], Train Loss: 0.2639
# Epoch [12/30], Train Accuracy: 0.8465
# Epoch [12/30], Validation Accuracy: 0.8015, Validation Loss: 0.2874
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [20/67], Train Loss: 0.2785
# Epoch [12/30], Train Accuracy: 0.8461
# Epoch [12/30], Validation Accuracy: 0.8075, Validation Loss: 0.2888
# Epoch [12/30], Step [30/67], Train Loss: 0.2278
# Epoch [12/30], Train Accuracy: 0.8473
# Epoch [12/30], Validation Accuracy: 0.7954, Validation Loss: 0.2866
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [40/67], Train Loss: 0.2580
# Epoch [12/30], Train Accuracy: 0.8491
# Epoch [12/30], Validation Accuracy: 0.8029, Validation Loss: 0.2879
# Epoch [12/30], Step [50/67], Train Loss: 0.2755
# Epoch [12/30], Train Accuracy: 0.8477
# Epoch [12/30], Validation Accuracy: 0.8001, Validation Loss: 0.2842
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [60/67], Train Loss: 0.2851
# Epoch [12/30], Train Accuracy: 0.8488
# Epoch [12/30], Validation Accuracy: 0.8057, Validation Loss: 0.2830
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [67/67], Train Loss: 0.2594
# Epoch [12/30], Train Accuracy: 0.8488
# Epoch [12/30], Validation Accuracy: 0.7992, Validation Loss: 0.2847
# Epoch [13/30], Step [10/67], Train Loss: 0.2589
# Epoch [13/30], Train Accuracy: 0.8508
# Epoch [13/30], Validation Accuracy: 0.8048, Validation Loss: 0.2836
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [20/67], Train Loss: 0.2749
# Epoch [13/30], Train Accuracy: 0.8494
# Epoch [13/30], Validation Accuracy: 0.8108, Validation Loss: 0.2852
# Epoch [13/30], Step [30/67], Train Loss: 0.2232
# Epoch [13/30], Train Accuracy: 0.8492
# Epoch [13/30], Validation Accuracy: 0.8001, Validation Loss: 0.2828
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [40/67], Train Loss: 0.2549
# Epoch [13/30], Train Accuracy: 0.8517
# Epoch [13/30], Validation Accuracy: 0.8071, Validation Loss: 0.2840
# Epoch [13/30], Step [50/67], Train Loss: 0.2716
# Epoch [13/30], Train Accuracy: 0.8502
# Epoch [13/30], Validation Accuracy: 0.8048, Validation Loss: 0.2805
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [60/67], Train Loss: 0.2820
# Epoch [13/30], Train Accuracy: 0.8517
# Epoch [13/30], Validation Accuracy: 0.8089, Validation Loss: 0.2794
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [67/67], Train Loss: 0.2562
# Epoch [13/30], Train Accuracy: 0.8515
# Epoch [13/30], Validation Accuracy: 0.8015, Validation Loss: 0.2811
# Epoch [14/30], Step [10/67], Train Loss: 0.2544
# Epoch [14/30], Train Accuracy: 0.8535
# Epoch [14/30], Validation Accuracy: 0.8094, Validation Loss: 0.2800
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [20/67], Train Loss: 0.2716
# Epoch [14/30], Train Accuracy: 0.8531
# Epoch [14/30], Validation Accuracy: 0.8127, Validation Loss: 0.2821
# Epoch [14/30], Step [30/67], Train Loss: 0.2194
# Epoch [14/30], Train Accuracy: 0.8520
# Epoch [14/30], Validation Accuracy: 0.8066, Validation Loss: 0.2795
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [40/67], Train Loss: 0.2521
# Epoch [14/30], Train Accuracy: 0.8548
# Epoch [14/30], Validation Accuracy: 0.8094, Validation Loss: 0.2804
# Epoch [14/30], Step [50/67], Train Loss: 0.2680
# Epoch [14/30], Train Accuracy: 0.8537
# Epoch [14/30], Validation Accuracy: 0.8155, Validation Loss: 0.2771
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [60/67], Train Loss: 0.2790
# Epoch [14/30], Train Accuracy: 0.8553
# Epoch [14/30], Validation Accuracy: 0.8164, Validation Loss: 0.2763
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [67/67], Train Loss: 0.2533
# Epoch [14/30], Train Accuracy: 0.8552
# Epoch [14/30], Validation Accuracy: 0.8103, Validation Loss: 0.2780
# Epoch [15/30], Step [10/67], Train Loss: 0.2502
# Epoch [15/30], Train Accuracy: 0.8570
# Epoch [15/30], Validation Accuracy: 0.8159, Validation Loss: 0.2770
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [20/67], Train Loss: 0.2686
# Epoch [15/30], Train Accuracy: 0.8578
# Epoch [15/30], Validation Accuracy: 0.8155, Validation Loss: 0.2792
# Epoch [15/30], Step [30/67], Train Loss: 0.2162
# Epoch [15/30], Train Accuracy: 0.8562
# Epoch [15/30], Validation Accuracy: 0.8117, Validation Loss: 0.2765
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [40/67], Train Loss: 0.2496
# Epoch [15/30], Train Accuracy: 0.8592
# Epoch [15/30], Validation Accuracy: 0.8117, Validation Loss: 0.2774
# Epoch [15/30], Step [50/67], Train Loss: 0.2649
# Epoch [15/30], Train Accuracy: 0.8577
# Epoch [15/30], Validation Accuracy: 0.8183, Validation Loss: 0.2742
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [60/67], Train Loss: 0.2764
# Epoch [15/30], Train Accuracy: 0.8590
# Epoch [15/30], Validation Accuracy: 0.8206, Validation Loss: 0.2736
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [67/67], Train Loss: 0.2508
# Epoch [15/30], Train Accuracy: 0.8587
# Epoch [15/30], Validation Accuracy: 0.8150, Validation Loss: 0.2753
# Epoch [16/30], Step [10/67], Train Loss: 0.2462
# Epoch [16/30], Train Accuracy: 0.8605
# Epoch [16/30], Validation Accuracy: 0.8192, Validation Loss: 0.2742
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [20/67], Train Loss: 0.2657
# Epoch [16/30], Train Accuracy: 0.8607
# Epoch [16/30], Validation Accuracy: 0.8150, Validation Loss: 0.2768
# Epoch [16/30], Step [30/67], Train Loss: 0.2133
# Epoch [16/30], Train Accuracy: 0.8596
# Epoch [16/30], Validation Accuracy: 0.8155, Validation Loss: 0.2738
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [40/67], Train Loss: 0.2474
# Epoch [16/30], Train Accuracy: 0.8620
# Epoch [16/30], Validation Accuracy: 0.8164, Validation Loss: 0.2746
# Epoch [16/30], Step [50/67], Train Loss: 0.2620
# Epoch [16/30], Train Accuracy: 0.8604
# Epoch [16/30], Validation Accuracy: 0.8220, Validation Loss: 0.2715
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [60/67], Train Loss: 0.2737
# Epoch [16/30], Train Accuracy: 0.8616
# Epoch [16/30], Validation Accuracy: 0.8239, Validation Loss: 0.2711
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [67/67], Train Loss: 0.2487
# Epoch [16/30], Train Accuracy: 0.8613
# Epoch [16/30], Validation Accuracy: 0.8211, Validation Loss: 0.2727
# Epoch [17/30], Step [10/67], Train Loss: 0.2426
# Epoch [17/30], Train Accuracy: 0.8664
# Epoch [17/30], Validation Accuracy: 0.8225, Validation Loss: 0.2717
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [20/67], Train Loss: 0.2631
# Epoch [17/30], Train Accuracy: 0.8654
# Epoch [17/30], Validation Accuracy: 0.8173, Validation Loss: 0.2745
# Epoch [17/30], Step [30/67], Train Loss: 0.2108
# Epoch [17/30], Train Accuracy: 0.8633
# Epoch [17/30], Validation Accuracy: 0.8192, Validation Loss: 0.2715
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [40/67], Train Loss: 0.2452
# Epoch [17/30], Train Accuracy: 0.8660
# Epoch [17/30], Validation Accuracy: 0.8197, Validation Loss: 0.2721
# Epoch [17/30], Step [50/67], Train Loss: 0.2593
# Epoch [17/30], Train Accuracy: 0.8643
# Epoch [17/30], Validation Accuracy: 0.8253, Validation Loss: 0.2692
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [60/67], Train Loss: 0.2713
# Epoch [17/30], Train Accuracy: 0.8652
# Epoch [17/30], Validation Accuracy: 0.8243, Validation Loss: 0.2689
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [67/67], Train Loss: 0.2466
# Epoch [17/30], Train Accuracy: 0.8644
# Epoch [17/30], Validation Accuracy: 0.8211, Validation Loss: 0.2705
# Epoch [18/30], Step [10/67], Train Loss: 0.2392
# Epoch [18/30], Train Accuracy: 0.8703
# Epoch [18/30], Validation Accuracy: 0.8253, Validation Loss: 0.2694
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [20/67], Train Loss: 0.2606
# Epoch [18/30], Train Accuracy: 0.8684
# Epoch [18/30], Validation Accuracy: 0.8220, Validation Loss: 0.2726
# Epoch [18/30], Step [30/67], Train Loss: 0.2084
# Epoch [18/30], Train Accuracy: 0.8671
# Epoch [18/30], Validation Accuracy: 0.8229, Validation Loss: 0.2693
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [40/67], Train Loss: 0.2431
# Epoch [18/30], Train Accuracy: 0.8695
# Epoch [18/30], Validation Accuracy: 0.8234, Validation Loss: 0.2699
# Epoch [18/30], Step [50/67], Train Loss: 0.2568
# Epoch [18/30], Train Accuracy: 0.8678
# Epoch [18/30], Validation Accuracy: 0.8281, Validation Loss: 0.2670
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [60/67], Train Loss: 0.2690
# Epoch [18/30], Train Accuracy: 0.8684
# Epoch [18/30], Validation Accuracy: 0.8299, Validation Loss: 0.2669
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [67/67], Train Loss: 0.2447
# Epoch [18/30], Train Accuracy: 0.8676
# Epoch [18/30], Validation Accuracy: 0.8239, Validation Loss: 0.2685
# Epoch [19/30], Step [10/67], Train Loss: 0.2359
# Epoch [19/30], Train Accuracy: 0.8742
# Epoch [19/30], Validation Accuracy: 0.8285, Validation Loss: 0.2674
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [20/67], Train Loss: 0.2580
# Epoch [19/30], Train Accuracy: 0.8715
# Epoch [19/30], Validation Accuracy: 0.8257, Validation Loss: 0.2707
# Epoch [19/30], Step [30/67], Train Loss: 0.2062
# Epoch [19/30], Train Accuracy: 0.8698
# Epoch [19/30], Validation Accuracy: 0.8262, Validation Loss: 0.2674
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [40/67], Train Loss: 0.2412
# Epoch [19/30], Train Accuracy: 0.8723
# Epoch [19/30], Validation Accuracy: 0.8290, Validation Loss: 0.2679
# Epoch [19/30], Step [50/67], Train Loss: 0.2545
# Epoch [19/30], Train Accuracy: 0.8704
# Epoch [19/30], Validation Accuracy: 0.8285, Validation Loss: 0.2651
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [60/67], Train Loss: 0.2668
# Epoch [19/30], Train Accuracy: 0.8708
# Epoch [19/30], Validation Accuracy: 0.8318, Validation Loss: 0.2652
# Epoch [19/30], Step [67/67], Train Loss: 0.2429
# Epoch [19/30], Train Accuracy: 0.8698
# Epoch [19/30], Validation Accuracy: 0.8295, Validation Loss: 0.2666
# Epoch [20/30], Step [10/67], Train Loss: 0.2328
# Epoch [20/30], Train Accuracy: 0.8766
# Epoch [20/30], Validation Accuracy: 0.8308, Validation Loss: 0.2656
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [20/67], Train Loss: 0.2557
# Epoch [20/30], Train Accuracy: 0.8736
# Epoch [20/30], Validation Accuracy: 0.8257, Validation Loss: 0.2691
# Epoch [20/30], Step [30/67], Train Loss: 0.2040
# Epoch [20/30], Train Accuracy: 0.8723
# Epoch [20/30], Validation Accuracy: 0.8295, Validation Loss: 0.2656
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [40/67], Train Loss: 0.2392
# Epoch [20/30], Train Accuracy: 0.8745
# Epoch [20/30], Validation Accuracy: 0.8295, Validation Loss: 0.2660
# Epoch [20/30], Step [50/67], Train Loss: 0.2522
# Epoch [20/30], Train Accuracy: 0.8727
# Epoch [20/30], Validation Accuracy: 0.8313, Validation Loss: 0.2634
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [60/67], Train Loss: 0.2645
# Epoch [20/30], Train Accuracy: 0.8736
# Epoch [20/30], Validation Accuracy: 0.8327, Validation Loss: 0.2635
# Epoch [20/30], Step [67/67], Train Loss: 0.2410
# Epoch [20/30], Train Accuracy: 0.8723
# Epoch [20/30], Validation Accuracy: 0.8318, Validation Loss: 0.2650
# Epoch [21/30], Step [10/67], Train Loss: 0.2298
# Epoch [21/30], Train Accuracy: 0.8805
# Epoch [21/30], Validation Accuracy: 0.8322, Validation Loss: 0.2640
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [21/30], Step [20/67], Train Loss: 0.2533
# Epoch [21/30], Train Accuracy: 0.8773
# Epoch [21/30], Validation Accuracy: 0.8262, Validation Loss: 0.2675
# Epoch [21/30], Step [30/67], Train Loss: 0.2022
# Epoch [21/30], Train Accuracy: 0.8759
# Epoch [21/30], Validation Accuracy: 0.8308, Validation Loss: 0.2640
# Epoch [21/30], Step [40/67], Train Loss: 0.2376
# Epoch [21/30], Train Accuracy: 0.8774
# Epoch [21/30], Validation Accuracy: 0.8304, Validation Loss: 0.2643
# Epoch [21/30], Step [50/67], Train Loss: 0.2500
# Epoch [21/30], Train Accuracy: 0.8753
# Epoch [21/30], Validation Accuracy: 0.8318, Validation Loss: 0.2618
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [21/30], Step [60/67], Train Loss: 0.2623
# Epoch [21/30], Train Accuracy: 0.8760
# Epoch [21/30], Validation Accuracy: 0.8336, Validation Loss: 0.2620
# Epoch [21/30], Step [67/67], Train Loss: 0.2393
# Epoch [21/30], Train Accuracy: 0.8747
# Epoch [21/30], Validation Accuracy: 0.8327, Validation Loss: 0.2634
# Epoch [22/30], Step [10/67], Train Loss: 0.2269
# Epoch [22/30], Train Accuracy: 0.8816
# Epoch [22/30], Validation Accuracy: 0.8332, Validation Loss: 0.2624
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [22/30], Step [20/67], Train Loss: 0.2511
# Epoch [22/30], Train Accuracy: 0.8791
# Epoch [22/30], Validation Accuracy: 0.8285, Validation Loss: 0.2659
# Epoch [22/30], Step [30/67], Train Loss: 0.2004
# Epoch [22/30], Train Accuracy: 0.8777
# Epoch [22/30], Validation Accuracy: 0.8346, Validation Loss: 0.2625
# Epoch [22/30], Step [40/67], Train Loss: 0.2358
# Epoch [22/30], Train Accuracy: 0.8792
# Epoch [22/30], Validation Accuracy: 0.8304, Validation Loss: 0.2629
# Epoch [22/30], Step [50/67], Train Loss: 0.2478
# Epoch [22/30], Train Accuracy: 0.8770
# Epoch [22/30], Validation Accuracy: 0.8322, Validation Loss: 0.2603
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [22/30], Step [60/67], Train Loss: 0.2603
# Epoch [22/30], Train Accuracy: 0.8779
# Epoch [22/30], Validation Accuracy: 0.8350, Validation Loss: 0.2606
# Epoch [22/30], Step [67/67], Train Loss: 0.2376
# Epoch [22/30], Train Accuracy: 0.8766
# Epoch [22/30], Validation Accuracy: 0.8346, Validation Loss: 0.2620
# Epoch [23/30], Step [10/67], Train Loss: 0.2240
# Epoch [23/30], Train Accuracy: 0.8840
# Epoch [23/30], Validation Accuracy: 0.8350, Validation Loss: 0.2610
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [23/30], Step [20/67], Train Loss: 0.2488
# Epoch [23/30], Train Accuracy: 0.8812
# Epoch [23/30], Validation Accuracy: 0.8332, Validation Loss: 0.2645
# Epoch [23/30], Step [30/67], Train Loss: 0.1985
# Epoch [23/30], Train Accuracy: 0.8796
# Epoch [23/30], Validation Accuracy: 0.8350, Validation Loss: 0.2611
# Epoch [23/30], Step [40/67], Train Loss: 0.2340
# Epoch [23/30], Train Accuracy: 0.8812
# Epoch [23/30], Validation Accuracy: 0.8313, Validation Loss: 0.2615
# Epoch [23/30], Step [50/67], Train Loss: 0.2457
# Epoch [23/30], Train Accuracy: 0.8788
# Epoch [23/30], Validation Accuracy: 0.8341, Validation Loss: 0.2590
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [23/30], Step [60/67], Train Loss: 0.2584
# Epoch [23/30], Train Accuracy: 0.8799
# Epoch [23/30], Validation Accuracy: 0.8360, Validation Loss: 0.2594
# Epoch [23/30], Step [67/67], Train Loss: 0.2358
# Epoch [23/30], Train Accuracy: 0.8785
# Epoch [23/30], Validation Accuracy: 0.8360, Validation Loss: 0.2607
# Epoch [24/30], Step [10/67], Train Loss: 0.2214
# Epoch [24/30], Train Accuracy: 0.8852
# Epoch [24/30], Validation Accuracy: 0.8369, Validation Loss: 0.2597
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [24/30], Step [20/67], Train Loss: 0.2467
# Epoch [24/30], Train Accuracy: 0.8826
# Epoch [24/30], Validation Accuracy: 0.8336, Validation Loss: 0.2633
# Epoch [24/30], Step [30/67], Train Loss: 0.1967
# Epoch [24/30], Train Accuracy: 0.8812
# Epoch [24/30], Validation Accuracy: 0.8341, Validation Loss: 0.2597
# Epoch [24/30], Step [40/67], Train Loss: 0.2324
# Epoch [24/30], Train Accuracy: 0.8829
# Epoch [24/30], Validation Accuracy: 0.8336, Validation Loss: 0.2602
# Epoch [24/30], Step [50/67], Train Loss: 0.2436
# Epoch [24/30], Train Accuracy: 0.8804
# Epoch [24/30], Validation Accuracy: 0.8355, Validation Loss: 0.2577
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [24/30], Step [60/67], Train Loss: 0.2565
# Epoch [24/30], Train Accuracy: 0.8813
# Epoch [24/30], Validation Accuracy: 0.8369, Validation Loss: 0.2582
# Epoch [24/30], Step [67/67], Train Loss: 0.2342
# Epoch [24/30], Train Accuracy: 0.8797
# Epoch [24/30], Validation Accuracy: 0.8364, Validation Loss: 0.2594
# Epoch [25/30], Step [10/67], Train Loss: 0.2189
# Epoch [25/30], Train Accuracy: 0.8855
# Epoch [25/30], Validation Accuracy: 0.8360, Validation Loss: 0.2585
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [25/30], Step [20/67], Train Loss: 0.2447
# Epoch [25/30], Train Accuracy: 0.8834
# Epoch [25/30], Validation Accuracy: 0.8364, Validation Loss: 0.2622
# Epoch [25/30], Step [30/67], Train Loss: 0.1950
# Epoch [25/30], Train Accuracy: 0.8826
# Epoch [25/30], Validation Accuracy: 0.8355, Validation Loss: 0.2585
# Epoch [25/30], Step [40/67], Train Loss: 0.2307
# Epoch [25/30], Train Accuracy: 0.8841
# Epoch [25/30], Validation Accuracy: 0.8346, Validation Loss: 0.2590
# Epoch [25/30], Step [50/67], Train Loss: 0.2416
# Epoch [25/30], Train Accuracy: 0.8818
# Epoch [25/30], Validation Accuracy: 0.8383, Validation Loss: 0.2565
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [25/30], Step [60/67], Train Loss: 0.2547
# Epoch [25/30], Train Accuracy: 0.8826
# Epoch [25/30], Validation Accuracy: 0.8369, Validation Loss: 0.2571
# Epoch [25/30], Step [67/67], Train Loss: 0.2325
# Epoch [25/30], Train Accuracy: 0.8811
# Epoch [25/30], Validation Accuracy: 0.8383, Validation Loss: 0.2583
# Epoch [26/30], Step [10/67], Train Loss: 0.2164
# Epoch [26/30], Train Accuracy: 0.8887
# Epoch [26/30], Validation Accuracy: 0.8402, Validation Loss: 0.2574
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [26/30], Step [20/67], Train Loss: 0.2424
# Epoch [26/30], Train Accuracy: 0.8857
# Epoch [26/30], Validation Accuracy: 0.8355, Validation Loss: 0.2609
# Epoch [26/30], Step [30/67], Train Loss: 0.1933
# Epoch [26/30], Train Accuracy: 0.8844
# Epoch [26/30], Validation Accuracy: 0.8374, Validation Loss: 0.2574
# Epoch [26/30], Step [40/67], Train Loss: 0.2291
# Epoch [26/30], Train Accuracy: 0.8859
# Epoch [26/30], Validation Accuracy: 0.8355, Validation Loss: 0.2579
# Epoch [26/30], Step [50/67], Train Loss: 0.2396
# Epoch [26/30], Train Accuracy: 0.8838
# Epoch [26/30], Validation Accuracy: 0.8397, Validation Loss: 0.2554
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [26/30], Step [60/67], Train Loss: 0.2529
# Epoch [26/30], Train Accuracy: 0.8841
# Epoch [26/30], Validation Accuracy: 0.8374, Validation Loss: 0.2560
# Epoch [26/30], Step [67/67], Train Loss: 0.2308
# Epoch [26/30], Train Accuracy: 0.8825
# Epoch [26/30], Validation Accuracy: 0.8378, Validation Loss: 0.2574
# Epoch [27/30], Step [10/67], Train Loss: 0.2141
# Epoch [27/30], Train Accuracy: 0.8902
# Epoch [27/30], Validation Accuracy: 0.8406, Validation Loss: 0.2565
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [27/30], Step [20/67], Train Loss: 0.2403
# Epoch [27/30], Train Accuracy: 0.8875
# Epoch [27/30], Validation Accuracy: 0.8378, Validation Loss: 0.2599
# Epoch [27/30], Step [30/67], Train Loss: 0.1918
# Epoch [27/30], Train Accuracy: 0.8855
# Epoch [27/30], Validation Accuracy: 0.8388, Validation Loss: 0.2564
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [27/30], Step [40/67], Train Loss: 0.2273
# Epoch [27/30], Train Accuracy: 0.8870
# Epoch [27/30], Validation Accuracy: 0.8364, Validation Loss: 0.2568
# Epoch [27/30], Step [50/67], Train Loss: 0.2376
# Epoch [27/30], Train Accuracy: 0.8852
# Epoch [27/30], Validation Accuracy: 0.8420, Validation Loss: 0.2545
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [27/30], Step [60/67], Train Loss: 0.2511
# Epoch [27/30], Train Accuracy: 0.8855
# Epoch [27/30], Validation Accuracy: 0.8397, Validation Loss: 0.2551
# Epoch [27/30], Step [67/67], Train Loss: 0.2291
# Epoch [27/30], Train Accuracy: 0.8840
# Epoch [27/30], Validation Accuracy: 0.8402, Validation Loss: 0.2565
# Epoch [28/30], Step [10/67], Train Loss: 0.2118
# Epoch [28/30], Train Accuracy: 0.8922
# Epoch [28/30], Validation Accuracy: 0.8416, Validation Loss: 0.2556
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [20/67], Train Loss: 0.2383
# Epoch [28/30], Train Accuracy: 0.8895
# Epoch [28/30], Validation Accuracy: 0.8383, Validation Loss: 0.2589
# Epoch [28/30], Step [30/67], Train Loss: 0.1904
# Epoch [28/30], Train Accuracy: 0.8875
# Epoch [28/30], Validation Accuracy: 0.8392, Validation Loss: 0.2554
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [40/67], Train Loss: 0.2257
# Epoch [28/30], Train Accuracy: 0.8888
# Epoch [28/30], Validation Accuracy: 0.8383, Validation Loss: 0.2560
# Epoch [28/30], Step [50/67], Train Loss: 0.2358
# Epoch [28/30], Train Accuracy: 0.8873
# Epoch [28/30], Validation Accuracy: 0.8430, Validation Loss: 0.2536
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [60/67], Train Loss: 0.2493
# Epoch [28/30], Train Accuracy: 0.8872
# Epoch [28/30], Validation Accuracy: 0.8406, Validation Loss: 0.2542
# Epoch [28/30], Step [67/67], Train Loss: 0.2274
# Epoch [28/30], Train Accuracy: 0.8858
# Epoch [28/30], Validation Accuracy: 0.8406, Validation Loss: 0.2557
# Epoch [29/30], Step [10/67], Train Loss: 0.2096
# Epoch [29/30], Train Accuracy: 0.8938
# Epoch [29/30], Validation Accuracy: 0.8434, Validation Loss: 0.2547
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [29/30], Step [20/67], Train Loss: 0.2362
# Epoch [29/30], Train Accuracy: 0.8910
# Epoch [29/30], Validation Accuracy: 0.8406, Validation Loss: 0.2580
# Epoch [29/30], Step [30/67], Train Loss: 0.1890
# Epoch [29/30], Train Accuracy: 0.8891
# Epoch [29/30], Validation Accuracy: 0.8392, Validation Loss: 0.2546
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [29/30], Step [40/67], Train Loss: 0.2241
# Epoch [29/30], Train Accuracy: 0.8900
# Epoch [29/30], Validation Accuracy: 0.8383, Validation Loss: 0.2551
# Epoch [29/30], Step [50/67], Train Loss: 0.2338
# Epoch [29/30], Train Accuracy: 0.8886
# Epoch [29/30], Validation Accuracy: 0.8430, Validation Loss: 0.2527
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [29/30], Step [60/67], Train Loss: 0.2475
# Epoch [29/30], Train Accuracy: 0.8885
# Epoch [29/30], Validation Accuracy: 0.8439, Validation Loss: 0.2534
# Epoch [29/30], Step [67/67], Train Loss: 0.2257
# Epoch [29/30], Train Accuracy: 0.8872
# Epoch [29/30], Validation Accuracy: 0.8416, Validation Loss: 0.2548
# Epoch [30/30], Step [10/67], Train Loss: 0.2075
# Epoch [30/30], Train Accuracy: 0.8953
# Epoch [30/30], Validation Accuracy: 0.8439, Validation Loss: 0.2539
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [20/67], Train Loss: 0.2341
# Epoch [30/30], Train Accuracy: 0.8922
# Epoch [30/30], Validation Accuracy: 0.8416, Validation Loss: 0.2570
# Epoch [30/30], Step [30/67], Train Loss: 0.1875
# Epoch [30/30], Train Accuracy: 0.8902
# Epoch [30/30], Validation Accuracy: 0.8406, Validation Loss: 0.2537
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [40/67], Train Loss: 0.2226
# Epoch [30/30], Train Accuracy: 0.8910
# Epoch [30/30], Validation Accuracy: 0.8402, Validation Loss: 0.2545
# Epoch [30/30], Step [50/67], Train Loss: 0.2319
# Epoch [30/30], Train Accuracy: 0.8895
# Epoch [30/30], Validation Accuracy: 0.8425, Validation Loss: 0.2520
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [60/67], Train Loss: 0.2457
# Epoch [30/30], Train Accuracy: 0.8893
# Epoch [30/30], Validation Accuracy: 0.8439, Validation Loss: 0.2526
# Epoch [30/30], Step [67/67], Train Loss: 0.2240
# Epoch [30/30], Train Accuracy: 0.8880
# Epoch [30/30], Validation Accuracy: 0.8420, Validation Loss: 0.2540
# Ended Training, Test Accuracy: 0.8350

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)
