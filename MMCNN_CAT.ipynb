# %%
from preprocess.preprocess import load_dataset, compute_label_agg, select_data, get_data_loaders, undersample

import torch
import torch.nn as nn
import torch.optim as optim

from models.CNN import MMCNN_CAT
from utils.trainer import trainer
from utils.RNN_utils import plot_losses, rename_with_acc

# %%
# Define device for torch
use_cuda = True
device = torch.device("cuda" if (
    use_cuda and torch.cuda.is_available()) else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Define options

# %%
LOAD_DATASET = False
TRAIN_PATH = './PTB_train.pt'
VALID_PATH = './PTB_valid.pt'
TEST_PATH = './PTB_test.pt'
SAVE_NAME = 'MMCNN_CAT_epoch_30'
SAVE_DIR = './model_saves/'
BATCH_SIZE = 256

# %% [markdown]
# # Loading the dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)
# Out:
# Start loading
# done loading

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = MMCNN_CAT().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
# cuda
# Epoch [1/30], Step [10/67], Train Loss: 0.5169
# Epoch [1/30], Train Accuracy: 0.4285
# Epoch [1/30], Validation Accuracy: 0.4450, Validation Loss: 0.5141
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [20/67], Train Loss: 0.5085
# Epoch [1/30], Train Accuracy: 0.4568
# Epoch [1/30], Validation Accuracy: 0.5475, Validation Loss: 0.4908
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [30/67], Train Loss: 0.4663
# Epoch [1/30], Train Accuracy: 0.5010
# Epoch [1/30], Validation Accuracy: 0.6104, Validation Loss: 0.4687
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [40/67], Train Loss: 0.4479
# Epoch [1/30], Train Accuracy: 0.5390
# Epoch [1/30], Validation Accuracy: 0.6477, Validation Loss: 0.4489
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [50/67], Train Loss: 0.4322
# Epoch [1/30], Train Accuracy: 0.5641
# Epoch [1/30], Validation Accuracy: 0.6580, Validation Loss: 0.4313
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [60/67], Train Loss: 0.4288
# Epoch [1/30], Train Accuracy: 0.5862
# Epoch [1/30], Validation Accuracy: 0.6766, Validation Loss: 0.4192
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [67/67], Train Loss: 0.4199
# Epoch [1/30], Train Accuracy: 0.5968
# Epoch [1/30], Validation Accuracy: 0.6859, Validation Loss: 0.4091
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [10/67], Train Loss: 0.3805
# Epoch [2/30], Train Accuracy: 0.7219
# Epoch [2/30], Validation Accuracy: 0.6813, Validation Loss: 0.4001
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [20/67], Train Loss: 0.3557
# Epoch [2/30], Train Accuracy: 0.7174
# Epoch [2/30], Validation Accuracy: 0.6813, Validation Loss: 0.3906
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [30/67], Train Loss: 0.3757
# Epoch [2/30], Train Accuracy: 0.7236
# Epoch [2/30], Validation Accuracy: 0.7008, Validation Loss: 0.3822
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [40/67], Train Loss: 0.3457
# Epoch [2/30], Train Accuracy: 0.7247
# Epoch [2/30], Validation Accuracy: 0.7004, Validation Loss: 0.3767
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [50/67], Train Loss: 0.3640
# Epoch [2/30], Train Accuracy: 0.7277
# Epoch [2/30], Validation Accuracy: 0.7148, Validation Loss: 0.3703
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [60/67], Train Loss: 0.3651
# Epoch [2/30], Train Accuracy: 0.7313
# Epoch [2/30], Validation Accuracy: 0.7144, Validation Loss: 0.3641
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [67/67], Train Loss: 0.3601
# Epoch [2/30], Train Accuracy: 0.7329
# Epoch [2/30], Validation Accuracy: 0.7106, Validation Loss: 0.3603
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [10/67], Train Loss: 0.3120
# Epoch [3/30], Train Accuracy: 0.7641
# Epoch [3/30], Validation Accuracy: 0.7260, Validation Loss: 0.3553
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [20/67], Train Loss: 0.3173
# Epoch [3/30], Train Accuracy: 0.7631
# Epoch [3/30], Validation Accuracy: 0.7307, Validation Loss: 0.3549
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [30/67], Train Loss: 0.3428
# Epoch [3/30], Train Accuracy: 0.7612
# Epoch [3/30], Validation Accuracy: 0.7437, Validation Loss: 0.3465
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [40/67], Train Loss: 0.3191
# Epoch [3/30], Train Accuracy: 0.7661
# Epoch [3/30], Validation Accuracy: 0.7358, Validation Loss: 0.3445
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [50/67], Train Loss: 0.3065
# Epoch [3/30], Train Accuracy: 0.7666
# Epoch [3/30], Validation Accuracy: 0.7493, Validation Loss: 0.3395
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [60/67], Train Loss: 0.3372
# Epoch [3/30], Train Accuracy: 0.7689
# Epoch [3/30], Validation Accuracy: 0.7596, Validation Loss: 0.3354
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [67/67], Train Loss: 0.3125
# Epoch [3/30], Train Accuracy: 0.7714
# Epoch [3/30], Validation Accuracy: 0.7577, Validation Loss: 0.3344
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [10/67], Train Loss: 0.2846
# Epoch [4/30], Train Accuracy: 0.8121
# Epoch [4/30], Validation Accuracy: 0.7498, Validation Loss: 0.3357
# Epoch [4/30], Step [20/67], Train Loss: 0.3099
# Epoch [4/30], Train Accuracy: 0.7984
# Epoch [4/30], Validation Accuracy: 0.7591, Validation Loss: 0.3283
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [30/67], Train Loss: 0.3408
# Epoch [4/30], Train Accuracy: 0.7943
# Epoch [4/30], Validation Accuracy: 0.7698, Validation Loss: 0.3251
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [40/67], Train Loss: 0.2896
# Epoch [4/30], Train Accuracy: 0.7972
# Epoch [4/30], Validation Accuracy: 0.7642, Validation Loss: 0.3257
# Epoch [4/30], Step [50/67], Train Loss: 0.2961
# Epoch [4/30], Train Accuracy: 0.7969
# Epoch [4/30], Validation Accuracy: 0.7754, Validation Loss: 0.3202
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [60/67], Train Loss: 0.2970
# Epoch [4/30], Train Accuracy: 0.7985
# Epoch [4/30], Validation Accuracy: 0.7675, Validation Loss: 0.3192
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [67/67], Train Loss: 0.3014
# Epoch [4/30], Train Accuracy: 0.7995
# Epoch [4/30], Validation Accuracy: 0.7675, Validation Loss: 0.3203
# Epoch [5/30], Step [10/67], Train Loss: 0.2974
# Epoch [5/30], Train Accuracy: 0.8098
# Epoch [5/30], Validation Accuracy: 0.7782, Validation Loss: 0.3149
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [20/67], Train Loss: 0.2770
# Epoch [5/30], Train Accuracy: 0.8076
# Epoch [5/30], Validation Accuracy: 0.7754, Validation Loss: 0.3143
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [30/67], Train Loss: 0.3204
# Epoch [5/30], Train Accuracy: 0.8103
# Epoch [5/30], Validation Accuracy: 0.7861, Validation Loss: 0.3118
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [40/67], Train Loss: 0.3053
# Epoch [5/30], Train Accuracy: 0.8105
# Epoch [5/30], Validation Accuracy: 0.7889, Validation Loss: 0.3107
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [50/67], Train Loss: 0.2930
# Epoch [5/30], Train Accuracy: 0.8137
# Epoch [5/30], Validation Accuracy: 0.7838, Validation Loss: 0.3093
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [60/67], Train Loss: 0.2885
# Epoch [5/30], Train Accuracy: 0.8160
# Epoch [5/30], Validation Accuracy: 0.7903, Validation Loss: 0.3093
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [67/67], Train Loss: 0.2916
# Epoch [5/30], Train Accuracy: 0.8163
# Epoch [5/30], Validation Accuracy: 0.7819, Validation Loss: 0.3100
# Epoch [6/30], Step [10/67], Train Loss: 0.2816
# Epoch [6/30], Train Accuracy: 0.8168
# Epoch [6/30], Validation Accuracy: 0.7917, Validation Loss: 0.3064
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [20/67], Train Loss: 0.2702
# Epoch [6/30], Train Accuracy: 0.8270
# Epoch [6/30], Validation Accuracy: 0.7945, Validation Loss: 0.3035
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [30/67], Train Loss: 0.2728
# Epoch [6/30], Train Accuracy: 0.8286
# Epoch [6/30], Validation Accuracy: 0.7936, Validation Loss: 0.3023
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [40/67], Train Loss: 0.2762
# Epoch [6/30], Train Accuracy: 0.8259
# Epoch [6/30], Validation Accuracy: 0.7950, Validation Loss: 0.3019
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [50/67], Train Loss: 0.2884
# Epoch [6/30], Train Accuracy: 0.8276
# Epoch [6/30], Validation Accuracy: 0.8001, Validation Loss: 0.3011
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [60/67], Train Loss: 0.3007
# Epoch [6/30], Train Accuracy: 0.8266
# Epoch [6/30], Validation Accuracy: 0.8038, Validation Loss: 0.2993
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [67/67], Train Loss: 0.2490
# Epoch [6/30], Train Accuracy: 0.8276
# Epoch [6/30], Validation Accuracy: 0.7819, Validation Loss: 0.3047
# Epoch [7/30], Step [10/67], Train Loss: 0.2706
# Epoch [7/30], Train Accuracy: 0.8320
# Epoch [7/30], Validation Accuracy: 0.7982, Validation Loss: 0.2985
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [20/67], Train Loss: 0.2742
# Epoch [7/30], Train Accuracy: 0.8314
# Epoch [7/30], Validation Accuracy: 0.8020, Validation Loss: 0.2986
# Epoch [7/30], Step [30/67], Train Loss: 0.2826
# Epoch [7/30], Train Accuracy: 0.8346
# Epoch [7/30], Validation Accuracy: 0.8052, Validation Loss: 0.2966
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [40/67], Train Loss: 0.2531
# Epoch [7/30], Train Accuracy: 0.8331
# Epoch [7/30], Validation Accuracy: 0.8006, Validation Loss: 0.2971
# Epoch [7/30], Step [50/67], Train Loss: 0.2568
# Epoch [7/30], Train Accuracy: 0.8333
# Epoch [7/30], Validation Accuracy: 0.8001, Validation Loss: 0.2960
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [60/67], Train Loss: 0.2524
# Epoch [7/30], Train Accuracy: 0.8330
# Epoch [7/30], Validation Accuracy: 0.8020, Validation Loss: 0.2950
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [67/67], Train Loss: 0.2892
# Epoch [7/30], Train Accuracy: 0.8334
# Epoch [7/30], Validation Accuracy: 0.7992, Validation Loss: 0.2953
# Epoch [8/30], Step [10/67], Train Loss: 0.2633
# Epoch [8/30], Train Accuracy: 0.8473
# Epoch [8/30], Validation Accuracy: 0.8015, Validation Loss: 0.2933
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [20/67], Train Loss: 0.2705
# Epoch [8/30], Train Accuracy: 0.8445
# Epoch [8/30], Validation Accuracy: 0.8080, Validation Loss: 0.2924
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [30/67], Train Loss: 0.2492
# Epoch [8/30], Train Accuracy: 0.8374
# Epoch [8/30], Validation Accuracy: 0.8085, Validation Loss: 0.2914
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [40/67], Train Loss: 0.2662
# Epoch [8/30], Train Accuracy: 0.8402
# Epoch [8/30], Validation Accuracy: 0.8062, Validation Loss: 0.2917
# Epoch [8/30], Step [50/67], Train Loss: 0.2564
# Epoch [8/30], Train Accuracy: 0.8387
# Epoch [8/30], Validation Accuracy: 0.8062, Validation Loss: 0.2900
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [60/67], Train Loss: 0.2494
# Epoch [8/30], Train Accuracy: 0.8395
# Epoch [8/30], Validation Accuracy: 0.7996, Validation Loss: 0.2899
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [67/67], Train Loss: 0.3122
# Epoch [8/30], Train Accuracy: 0.8403
# Epoch [8/30], Validation Accuracy: 0.8043, Validation Loss: 0.2881
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [10/67], Train Loss: 0.2761
# Epoch [9/30], Train Accuracy: 0.8363
# Epoch [9/30], Validation Accuracy: 0.7926, Validation Loss: 0.2972
# Epoch [9/30], Step [20/67], Train Loss: 0.2424
# Epoch [9/30], Train Accuracy: 0.8408
# Epoch [9/30], Validation Accuracy: 0.8089, Validation Loss: 0.2873
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [30/67], Train Loss: 0.2429
# Epoch [9/30], Train Accuracy: 0.8448
# Epoch [9/30], Validation Accuracy: 0.8099, Validation Loss: 0.2864
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [40/67], Train Loss: 0.2732
# Epoch [9/30], Train Accuracy: 0.8430
# Epoch [9/30], Validation Accuracy: 0.8066, Validation Loss: 0.2863
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [50/67], Train Loss: 0.2755
# Epoch [9/30], Train Accuracy: 0.8445
# Epoch [9/30], Validation Accuracy: 0.8080, Validation Loss: 0.2870
# Epoch [9/30], Step [60/67], Train Loss: 0.2584
# Epoch [9/30], Train Accuracy: 0.8456
# Epoch [9/30], Validation Accuracy: 0.8052, Validation Loss: 0.2868
# Epoch [9/30], Step [67/67], Train Loss: 0.2631
# Epoch [9/30], Train Accuracy: 0.8458
# Epoch [9/30], Validation Accuracy: 0.8113, Validation Loss: 0.2838
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [10/67], Train Loss: 0.2541
# Epoch [10/30], Train Accuracy: 0.8602
# Epoch [10/30], Validation Accuracy: 0.8103, Validation Loss: 0.2843
# Epoch [10/30], Step [20/67], Train Loss: 0.2561
# Epoch [10/30], Train Accuracy: 0.8510
# Epoch [10/30], Validation Accuracy: 0.8122, Validation Loss: 0.2835
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [30/67], Train Loss: 0.2631
# Epoch [10/30], Train Accuracy: 0.8479
# Epoch [10/30], Validation Accuracy: 0.8136, Validation Loss: 0.2824
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [40/67], Train Loss: 0.2669
# Epoch [10/30], Train Accuracy: 0.8473
# Epoch [10/30], Validation Accuracy: 0.8155, Validation Loss: 0.2823
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [50/67], Train Loss: 0.2609
# Epoch [10/30], Train Accuracy: 0.8484
# Epoch [10/30], Validation Accuracy: 0.8071, Validation Loss: 0.2838
# Epoch [10/30], Step [60/67], Train Loss: 0.2403
# Epoch [10/30], Train Accuracy: 0.8503
# Epoch [10/30], Validation Accuracy: 0.8117, Validation Loss: 0.2822
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [67/67], Train Loss: 0.2631
# Epoch [10/30], Train Accuracy: 0.8491
# Epoch [10/30], Validation Accuracy: 0.8173, Validation Loss: 0.2812
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [10/67], Train Loss: 0.2460
# Epoch [11/30], Train Accuracy: 0.8609
# Epoch [11/30], Validation Accuracy: 0.8131, Validation Loss: 0.2814
# Epoch [11/30], Step [20/67], Train Loss: 0.2444
# Epoch [11/30], Train Accuracy: 0.8584
# Epoch [11/30], Validation Accuracy: 0.8169, Validation Loss: 0.2804
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [30/67], Train Loss: 0.2384
# Epoch [11/30], Train Accuracy: 0.8548
# Epoch [11/30], Validation Accuracy: 0.8122, Validation Loss: 0.2790
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [40/67], Train Loss: 0.2646
# Epoch [11/30], Train Accuracy: 0.8508
# Epoch [11/30], Validation Accuracy: 0.8150, Validation Loss: 0.2792
# Epoch [11/30], Step [50/67], Train Loss: 0.2427
# Epoch [11/30], Train Accuracy: 0.8524
# Epoch [11/30], Validation Accuracy: 0.8155, Validation Loss: 0.2788
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [60/67], Train Loss: 0.2312
# Epoch [11/30], Train Accuracy: 0.8516
# Epoch [11/30], Validation Accuracy: 0.8159, Validation Loss: 0.2804
# Epoch [11/30], Step [67/67], Train Loss: 0.2511
# Epoch [11/30], Train Accuracy: 0.8525
# Epoch [11/30], Validation Accuracy: 0.8145, Validation Loss: 0.2815
# Epoch [12/30], Step [10/67], Train Loss: 0.2244
# Epoch [12/30], Train Accuracy: 0.8586
# Epoch [12/30], Validation Accuracy: 0.8178, Validation Loss: 0.2770
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [20/67], Train Loss: 0.2807
# Epoch [12/30], Train Accuracy: 0.8564
# Epoch [12/30], Validation Accuracy: 0.8178, Validation Loss: 0.2769
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [30/67], Train Loss: 0.2522
# Epoch [12/30], Train Accuracy: 0.8553
# Epoch [12/30], Validation Accuracy: 0.8145, Validation Loss: 0.2769
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [40/67], Train Loss: 0.2221
# Epoch [12/30], Train Accuracy: 0.8562
# Epoch [12/30], Validation Accuracy: 0.8150, Validation Loss: 0.2769
# Epoch [12/30], Step [50/67], Train Loss: 0.2302
# Epoch [12/30], Train Accuracy: 0.8565
# Epoch [12/30], Validation Accuracy: 0.8159, Validation Loss: 0.2781
# Epoch [12/30], Step [60/67], Train Loss: 0.2666
# Epoch [12/30], Train Accuracy: 0.8570
# Epoch [12/30], Validation Accuracy: 0.8131, Validation Loss: 0.2771
# Epoch [12/30], Step [67/67], Train Loss: 0.2027
# Epoch [12/30], Train Accuracy: 0.8565
# Epoch [12/30], Validation Accuracy: 0.8215, Validation Loss: 0.2743
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [10/67], Train Loss: 0.2346
# Epoch [13/30], Train Accuracy: 0.8641
# Epoch [13/30], Validation Accuracy: 0.8159, Validation Loss: 0.2757
# Epoch [13/30], Step [20/67], Train Loss: 0.2465
# Epoch [13/30], Train Accuracy: 0.8629
# Epoch [13/30], Validation Accuracy: 0.8201, Validation Loss: 0.2764
# Epoch [13/30], Step [30/67], Train Loss: 0.2479
# Epoch [13/30], Train Accuracy: 0.8629
# Epoch [13/30], Validation Accuracy: 0.8201, Validation Loss: 0.2749
# Epoch [13/30], Step [40/67], Train Loss: 0.2438
# Epoch [13/30], Train Accuracy: 0.8610
# Epoch [13/30], Validation Accuracy: 0.8141, Validation Loss: 0.2782
# Epoch [13/30], Step [50/67], Train Loss: 0.2596
# Epoch [13/30], Train Accuracy: 0.8620
# Epoch [13/30], Validation Accuracy: 0.8239, Validation Loss: 0.2761
# Epoch [13/30], Step [60/67], Train Loss: 0.2390
# Epoch [13/30], Train Accuracy: 0.8603
# Epoch [13/30], Validation Accuracy: 0.8206, Validation Loss: 0.2734
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [67/67], Train Loss: 0.2748
# Epoch [13/30], Train Accuracy: 0.8602
# Epoch [13/30], Validation Accuracy: 0.8211, Validation Loss: 0.2724
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [10/67], Train Loss: 0.2552
# Epoch [14/30], Train Accuracy: 0.8566
# Epoch [14/30], Validation Accuracy: 0.8239, Validation Loss: 0.2745
# Epoch [14/30], Step [20/67], Train Loss: 0.2452
# Epoch [14/30], Train Accuracy: 0.8617
# Epoch [14/30], Validation Accuracy: 0.8131, Validation Loss: 0.2775
# Epoch [14/30], Step [30/67], Train Loss: 0.2449
# Epoch [14/30], Train Accuracy: 0.8665
# Epoch [14/30], Validation Accuracy: 0.8253, Validation Loss: 0.2748
# Epoch [14/30], Step [40/67], Train Loss: 0.2203
# Epoch [14/30], Train Accuracy: 0.8629
# Epoch [14/30], Validation Accuracy: 0.8187, Validation Loss: 0.2739
# Epoch [14/30], Step [50/67], Train Loss: 0.2333
# Epoch [14/30], Train Accuracy: 0.8646
# Epoch [14/30], Validation Accuracy: 0.8267, Validation Loss: 0.2738
# Epoch [14/30], Step [60/67], Train Loss: 0.2423
# Epoch [14/30], Train Accuracy: 0.8640
# Epoch [14/30], Validation Accuracy: 0.8262, Validation Loss: 0.2710
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [67/67], Train Loss: 0.1912
# Epoch [14/30], Train Accuracy: 0.8644
# Epoch [14/30], Validation Accuracy: 0.8169, Validation Loss: 0.2718
# Epoch [15/30], Step [10/67], Train Loss: 0.2207
# Epoch [15/30], Train Accuracy: 0.8699
# Epoch [15/30], Validation Accuracy: 0.8276, Validation Loss: 0.2697
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [20/67], Train Loss: 0.2529
# Epoch [15/30], Train Accuracy: 0.8660
# Epoch [15/30], Validation Accuracy: 0.8290, Validation Loss: 0.2735
# Epoch [15/30], Step [30/67], Train Loss: 0.2434
# Epoch [15/30], Train Accuracy: 0.8646
# Epoch [15/30], Validation Accuracy: 0.8262, Validation Loss: 0.2697
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [40/67], Train Loss: 0.2077
# Epoch [15/30], Train Accuracy: 0.8637
# Epoch [15/30], Validation Accuracy: 0.8215, Validation Loss: 0.2700
# Epoch [15/30], Step [50/67], Train Loss: 0.2448
# Epoch [15/30], Train Accuracy: 0.8650
# Epoch [15/30], Validation Accuracy: 0.8285, Validation Loss: 0.2703
# Epoch [15/30], Step [60/67], Train Loss: 0.2458
# Epoch [15/30], Train Accuracy: 0.8655
# Epoch [15/30], Validation Accuracy: 0.8285, Validation Loss: 0.2687
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [67/67], Train Loss: 0.2348
# Epoch [15/30], Train Accuracy: 0.8653
# Epoch [15/30], Validation Accuracy: 0.8299, Validation Loss: 0.2696
# Epoch [16/30], Step [10/67], Train Loss: 0.2477
# Epoch [16/30], Train Accuracy: 0.8629
# Epoch [16/30], Validation Accuracy: 0.8253, Validation Loss: 0.2706
# Epoch [16/30], Step [20/67], Train Loss: 0.2389
# Epoch [16/30], Train Accuracy: 0.8699
# Epoch [16/30], Validation Accuracy: 0.8290, Validation Loss: 0.2686
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [30/67], Train Loss: 0.2379
# Epoch [16/30], Train Accuracy: 0.8694
# Epoch [16/30], Validation Accuracy: 0.8267, Validation Loss: 0.2685
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [40/67], Train Loss: 0.2458
# Epoch [16/30], Train Accuracy: 0.8690
# Epoch [16/30], Validation Accuracy: 0.8290, Validation Loss: 0.2680
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [50/67], Train Loss: 0.2207
# Epoch [16/30], Train Accuracy: 0.8690
# Epoch [16/30], Validation Accuracy: 0.8295, Validation Loss: 0.2676
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [60/67], Train Loss: 0.2452
# Epoch [16/30], Train Accuracy: 0.8682
# Epoch [16/30], Validation Accuracy: 0.8304, Validation Loss: 0.2684
# Epoch [16/30], Step [67/67], Train Loss: 0.2655
# Epoch [16/30], Train Accuracy: 0.8663
# Epoch [16/30], Validation Accuracy: 0.8136, Validation Loss: 0.2872
# Epoch [17/30], Step [10/67], Train Loss: 0.2367
# Epoch [17/30], Train Accuracy: 0.8691
# Epoch [17/30], Validation Accuracy: 0.8257, Validation Loss: 0.2667
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [20/67], Train Loss: 0.2191
# Epoch [17/30], Train Accuracy: 0.8701
# Epoch [17/30], Validation Accuracy: 0.8290, Validation Loss: 0.2681
# Epoch [17/30], Step [30/67], Train Loss: 0.2143
# Epoch [17/30], Train Accuracy: 0.8740
# Epoch [17/30], Validation Accuracy: 0.8253, Validation Loss: 0.2671
# Epoch [17/30], Step [40/67], Train Loss: 0.2163
# Epoch [17/30], Train Accuracy: 0.8732
# Epoch [17/30], Validation Accuracy: 0.8271, Validation Loss: 0.2674
# Epoch [17/30], Step [50/67], Train Loss: 0.2162
# Epoch [17/30], Train Accuracy: 0.8727
# Epoch [17/30], Validation Accuracy: 0.8253, Validation Loss: 0.2679
# Epoch [17/30], Step [60/67], Train Loss: 0.2041
# Epoch [17/30], Train Accuracy: 0.8729
# Epoch [17/30], Validation Accuracy: 0.8262, Validation Loss: 0.2654
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [67/67], Train Loss: 0.1971
# Epoch [17/30], Train Accuracy: 0.8715
# Epoch [17/30], Validation Accuracy: 0.8267, Validation Loss: 0.2656
# Epoch [18/30], Step [10/67], Train Loss: 0.2673
# Epoch [18/30], Train Accuracy: 0.8676
# Epoch [18/30], Validation Accuracy: 0.8341, Validation Loss: 0.2650
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [20/67], Train Loss: 0.2040
# Epoch [18/30], Train Accuracy: 0.8729
# Epoch [18/30], Validation Accuracy: 0.8295, Validation Loss: 0.2644
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [30/67], Train Loss: 0.2235
# Epoch [18/30], Train Accuracy: 0.8742
# Epoch [18/30], Validation Accuracy: 0.8336, Validation Loss: 0.2647
# Epoch [18/30], Step [40/67], Train Loss: 0.2581
# Epoch [18/30], Train Accuracy: 0.8724
# Epoch [18/30], Validation Accuracy: 0.8318, Validation Loss: 0.2637
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [50/67], Train Loss: 0.2160
# Epoch [18/30], Train Accuracy: 0.8741
# Epoch [18/30], Validation Accuracy: 0.8332, Validation Loss: 0.2642
# Epoch [18/30], Step [60/67], Train Loss: 0.2512
# Epoch [18/30], Train Accuracy: 0.8736
# Epoch [18/30], Validation Accuracy: 0.8341, Validation Loss: 0.2651
# Epoch [18/30], Step [67/67], Train Loss: 0.2269
# Epoch [18/30], Train Accuracy: 0.8743
# Epoch [18/30], Validation Accuracy: 0.8318, Validation Loss: 0.2666
# Epoch [19/30], Step [10/67], Train Loss: 0.2203
# Epoch [19/30], Train Accuracy: 0.8781
# Epoch [19/30], Validation Accuracy: 0.8285, Validation Loss: 0.2646
# Epoch [19/30], Step [20/67], Train Loss: 0.2292
# Epoch [19/30], Train Accuracy: 0.8711
# Epoch [19/30], Validation Accuracy: 0.8322, Validation Loss: 0.2634
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [30/67], Train Loss: 0.2408
# Epoch [19/30], Train Accuracy: 0.8717
# Epoch [19/30], Validation Accuracy: 0.8327, Validation Loss: 0.2626
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [40/67], Train Loss: 0.2383
# Epoch [19/30], Train Accuracy: 0.8719
# Epoch [19/30], Validation Accuracy: 0.8369, Validation Loss: 0.2642
# Epoch [19/30], Step [50/67], Train Loss: 0.2309
# Epoch [19/30], Train Accuracy: 0.8735
# Epoch [19/30], Validation Accuracy: 0.8360, Validation Loss: 0.2625
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [60/67], Train Loss: 0.2360
# Epoch [19/30], Train Accuracy: 0.8759
# Epoch [19/30], Validation Accuracy: 0.8346, Validation Loss: 0.2635
# Epoch [19/30], Step [67/67], Train Loss: 0.2233
# Epoch [19/30], Train Accuracy: 0.8758
# Epoch [19/30], Validation Accuracy: 0.8341, Validation Loss: 0.2625
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [10/67], Train Loss: 0.2251
# Epoch [20/30], Train Accuracy: 0.8809
# Epoch [20/30], Validation Accuracy: 0.8318, Validation Loss: 0.2638
# Epoch [20/30], Step [20/67], Train Loss: 0.2187
# Epoch [20/30], Train Accuracy: 0.8777
# Epoch [20/30], Validation Accuracy: 0.8341, Validation Loss: 0.2622
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [30/67], Train Loss: 0.2256
# Epoch [20/30], Train Accuracy: 0.8802
# Epoch [20/30], Validation Accuracy: 0.8346, Validation Loss: 0.2637
# Epoch [20/30], Step [40/67], Train Loss: 0.2370
# Epoch [20/30], Train Accuracy: 0.8774
# Epoch [20/30], Validation Accuracy: 0.8346, Validation Loss: 0.2621
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [50/67], Train Loss: 0.1894
# Epoch [20/30], Train Accuracy: 0.8782
# Epoch [20/30], Validation Accuracy: 0.8374, Validation Loss: 0.2607
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [60/67], Train Loss: 0.2273
# Epoch [20/30], Train Accuracy: 0.8792
# Epoch [20/30], Validation Accuracy: 0.8304, Validation Loss: 0.2663
# Epoch [20/30], Step [67/67], Train Loss: 0.2418
# Epoch [20/30], Train Accuracy: 0.8790
# Epoch [20/30], Validation Accuracy: 0.8243, Validation Loss: 0.2665
# Epoch [21/30], Step [10/67], Train Loss: 0.2383
# Epoch [21/30], Train Accuracy: 0.8879
# Epoch [21/30], Validation Accuracy: 0.8346, Validation Loss: 0.2622
# Epoch [21/30], Step [20/67], Train Loss: 0.1840
# Epoch [21/30], Train Accuracy: 0.8812
# Epoch [21/30], Validation Accuracy: 0.8346, Validation Loss: 0.2625
# Epoch [21/30], Step [30/67], Train Loss: 0.2292
# Epoch [21/30], Train Accuracy: 0.8773
# Epoch [21/30], Validation Accuracy: 0.8336, Validation Loss: 0.2615
# Epoch [21/30], Step [40/67], Train Loss: 0.2126
# Epoch [21/30], Train Accuracy: 0.8784
# Epoch [21/30], Validation Accuracy: 0.8369, Validation Loss: 0.2603
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [21/30], Step [50/67], Train Loss: 0.2279
# Epoch [21/30], Train Accuracy: 0.8783
# Epoch [21/30], Validation Accuracy: 0.8364, Validation Loss: 0.2596
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [21/30], Step [60/67], Train Loss: 0.1991
# Epoch [21/30], Train Accuracy: 0.8807
# Epoch [21/30], Validation Accuracy: 0.8360, Validation Loss: 0.2598
# Epoch [21/30], Step [67/67], Train Loss: 0.2304
# Epoch [21/30], Train Accuracy: 0.8810
# Epoch [21/30], Validation Accuracy: 0.8313, Validation Loss: 0.2643
# Epoch [22/30], Step [10/67], Train Loss: 0.2089
# Epoch [22/30], Train Accuracy: 0.8840
# Epoch [22/30], Validation Accuracy: 0.8327, Validation Loss: 0.2621
# Epoch [22/30], Step [20/67], Train Loss: 0.2065
# Epoch [22/30], Train Accuracy: 0.8828
# Epoch [22/30], Validation Accuracy: 0.8322, Validation Loss: 0.2645
# Epoch [22/30], Step [30/67], Train Loss: 0.2521
# Epoch [22/30], Train Accuracy: 0.8842
# Epoch [22/30], Validation Accuracy: 0.8360, Validation Loss: 0.2604
# Epoch [22/30], Step [40/67], Train Loss: 0.2134
# Epoch [22/30], Train Accuracy: 0.8864
# Epoch [22/30], Validation Accuracy: 0.8355, Validation Loss: 0.2603
# Epoch [22/30], Step [50/67], Train Loss: 0.2107
# Epoch [22/30], Train Accuracy: 0.8839
# Epoch [22/30], Validation Accuracy: 0.8392, Validation Loss: 0.2582
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [22/30], Step [60/67], Train Loss: 0.2067
# Epoch [22/30], Train Accuracy: 0.8828
# Epoch [22/30], Validation Accuracy: 0.8346, Validation Loss: 0.2613
# Epoch [22/30], Step [67/67], Train Loss: 0.1959
# Epoch [22/30], Train Accuracy: 0.8827
# Epoch [22/30], Validation Accuracy: 0.8416, Validation Loss: 0.2583
# Epoch [23/30], Step [10/67], Train Loss: 0.2236
# Epoch [23/30], Train Accuracy: 0.8812
# Epoch [23/30], Validation Accuracy: 0.8360, Validation Loss: 0.2608
# Epoch [23/30], Step [20/67], Train Loss: 0.2450
# Epoch [23/30], Train Accuracy: 0.8875
# Epoch [23/30], Validation Accuracy: 0.8411, Validation Loss: 0.2579
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [23/30], Step [30/67], Train Loss: 0.2137
# Epoch [23/30], Train Accuracy: 0.8848
# Epoch [23/30], Validation Accuracy: 0.8402, Validation Loss: 0.2585
# Epoch [23/30], Step [40/67], Train Loss: 0.2213
# Epoch [23/30], Train Accuracy: 0.8862
# Epoch [23/30], Validation Accuracy: 0.8360, Validation Loss: 0.2611
# Epoch [23/30], Step [50/67], Train Loss: 0.2350
# Epoch [23/30], Train Accuracy: 0.8866
# Epoch [23/30], Validation Accuracy: 0.8360, Validation Loss: 0.2601
# Epoch [23/30], Step [60/67], Train Loss: 0.2116
# Epoch [23/30], Train Accuracy: 0.8850
# Epoch [23/30], Validation Accuracy: 0.8430, Validation Loss: 0.2594
# Epoch [23/30], Step [67/67], Train Loss: 0.1861
# Epoch [23/30], Train Accuracy: 0.8849
# Epoch [23/30], Validation Accuracy: 0.8341, Validation Loss: 0.2589
# Epoch [24/30], Step [10/67], Train Loss: 0.2062
# Epoch [24/30], Train Accuracy: 0.8891
# Epoch [24/30], Validation Accuracy: 0.8355, Validation Loss: 0.2628
# Epoch [24/30], Step [20/67], Train Loss: 0.1763
# Epoch [24/30], Train Accuracy: 0.8844
# Epoch [24/30], Validation Accuracy: 0.8341, Validation Loss: 0.2596
# Epoch [24/30], Step [30/67], Train Loss: 0.2308
# Epoch [24/30], Train Accuracy: 0.8857
# Epoch [24/30], Validation Accuracy: 0.8332, Validation Loss: 0.2628
# Epoch [24/30], Step [40/67], Train Loss: 0.2052
# Epoch [24/30], Train Accuracy: 0.8841
# Epoch [24/30], Validation Accuracy: 0.8369, Validation Loss: 0.2587
# Epoch [24/30], Step [50/67], Train Loss: 0.2364
# Epoch [24/30], Train Accuracy: 0.8861
# Epoch [24/30], Validation Accuracy: 0.8434, Validation Loss: 0.2615
# Epoch [24/30], Step [60/67], Train Loss: 0.2099
# Epoch [24/30], Train Accuracy: 0.8854
# Epoch [24/30], Validation Accuracy: 0.8406, Validation Loss: 0.2571
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [24/30], Step [67/67], Train Loss: 0.2596
# Epoch [24/30], Train Accuracy: 0.8846
# Epoch [24/30], Validation Accuracy: 0.8346, Validation Loss: 0.2607
# Epoch [25/30], Step [10/67], Train Loss: 0.2291
# Epoch [25/30], Train Accuracy: 0.8855
# Epoch [25/30], Validation Accuracy: 0.8402, Validation Loss: 0.2565
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [25/30], Step [20/67], Train Loss: 0.2042
# Epoch [25/30], Train Accuracy: 0.8896
# Epoch [25/30], Validation Accuracy: 0.8374, Validation Loss: 0.2571
# Epoch [25/30], Step [30/67], Train Loss: 0.2013
# Epoch [25/30], Train Accuracy: 0.8885
# Epoch [25/30], Validation Accuracy: 0.8388, Validation Loss: 0.2565
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [25/30], Step [40/67], Train Loss: 0.2083
# Epoch [25/30], Train Accuracy: 0.8896
# Epoch [25/30], Validation Accuracy: 0.8444, Validation Loss: 0.2564
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [25/30], Step [50/67], Train Loss: 0.2139
# Epoch [25/30], Train Accuracy: 0.8899
# Epoch [25/30], Validation Accuracy: 0.8397, Validation Loss: 0.2585
# Epoch [25/30], Step [60/67], Train Loss: 0.2359
# Epoch [25/30], Train Accuracy: 0.8884
# Epoch [25/30], Validation Accuracy: 0.8406, Validation Loss: 0.2576
# Epoch [25/30], Step [67/67], Train Loss: 0.2457
# Epoch [25/30], Train Accuracy: 0.8876
# Epoch [25/30], Validation Accuracy: 0.8397, Validation Loss: 0.2578
# Epoch [26/30], Step [10/67], Train Loss: 0.2066
# Epoch [26/30], Train Accuracy: 0.8859
# Epoch [26/30], Validation Accuracy: 0.8434, Validation Loss: 0.2563
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [26/30], Step [20/67], Train Loss: 0.1855
# Epoch [26/30], Train Accuracy: 0.8883
# Epoch [26/30], Validation Accuracy: 0.8416, Validation Loss: 0.2575
# Epoch [26/30], Step [30/67], Train Loss: 0.2199
# Epoch [26/30], Train Accuracy: 0.8878
# Epoch [26/30], Validation Accuracy: 0.8406, Validation Loss: 0.2557
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [26/30], Step [40/67], Train Loss: 0.1852
# Epoch [26/30], Train Accuracy: 0.8893
# Epoch [26/30], Validation Accuracy: 0.8383, Validation Loss: 0.2571
# Epoch [26/30], Step [50/67], Train Loss: 0.2353
# Epoch [26/30], Train Accuracy: 0.8902
# Epoch [26/30], Validation Accuracy: 0.8434, Validation Loss: 0.2562
# Epoch [26/30], Step [60/67], Train Loss: 0.2019
# Epoch [26/30], Train Accuracy: 0.8898
# Epoch [26/30], Validation Accuracy: 0.8448, Validation Loss: 0.2546
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [26/30], Step [67/67], Train Loss: 0.2443
# Epoch [26/30], Train Accuracy: 0.8886
# Epoch [26/30], Validation Accuracy: 0.8439, Validation Loss: 0.2555
# Epoch [27/30], Step [10/67], Train Loss: 0.2363
# Epoch [27/30], Train Accuracy: 0.8883
# Epoch [27/30], Validation Accuracy: 0.8439, Validation Loss: 0.2570
# Epoch [27/30], Step [20/67], Train Loss: 0.1876
# Epoch [27/30], Train Accuracy: 0.8887
# Epoch [27/30], Validation Accuracy: 0.8406, Validation Loss: 0.2585
# Epoch [27/30], Step [30/67], Train Loss: 0.1939
# Epoch [27/30], Train Accuracy: 0.8897
# Epoch [27/30], Validation Accuracy: 0.8406, Validation Loss: 0.2572
# Epoch [27/30], Step [40/67], Train Loss: 0.2198
# Epoch [27/30], Train Accuracy: 0.8876
# Epoch [27/30], Validation Accuracy: 0.8406, Validation Loss: 0.2564
# Epoch [27/30], Step [50/67], Train Loss: 0.2038
# Epoch [27/30], Train Accuracy: 0.8881
# Epoch [27/30], Validation Accuracy: 0.8486, Validation Loss: 0.2547
# Epoch [27/30], Step [60/67], Train Loss: 0.1906
# Epoch [27/30], Train Accuracy: 0.8905
# Epoch [27/30], Validation Accuracy: 0.8402, Validation Loss: 0.2572
# Epoch [27/30], Step [67/67], Train Loss: 0.2053
# Epoch [27/30], Train Accuracy: 0.8901
# Epoch [27/30], Validation Accuracy: 0.8430, Validation Loss: 0.2562
# Epoch [28/30], Step [10/67], Train Loss: 0.2178
# Epoch [28/30], Train Accuracy: 0.8805
# Epoch [28/30], Validation Accuracy: 0.8439, Validation Loss: 0.2542
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [20/67], Train Loss: 0.1737
# Epoch [28/30], Train Accuracy: 0.8910
# Epoch [28/30], Validation Accuracy: 0.8420, Validation Loss: 0.2570
# Epoch [28/30], Step [30/67], Train Loss: 0.2344
# Epoch [28/30], Train Accuracy: 0.8902
# Epoch [28/30], Validation Accuracy: 0.8462, Validation Loss: 0.2540
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [40/67], Train Loss: 0.1976
# Epoch [28/30], Train Accuracy: 0.8915
# Epoch [28/30], Validation Accuracy: 0.8458, Validation Loss: 0.2558
# Epoch [28/30], Step [50/67], Train Loss: 0.2014
# Epoch [28/30], Train Accuracy: 0.8912
# Epoch [28/30], Validation Accuracy: 0.8406, Validation Loss: 0.2598
# Epoch [28/30], Step [60/67], Train Loss: 0.2236
# Epoch [28/30], Train Accuracy: 0.8907
# Epoch [28/30], Validation Accuracy: 0.8486, Validation Loss: 0.2532
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [67/67], Train Loss: 0.2041
# Epoch [28/30], Train Accuracy: 0.8908
# Epoch [28/30], Validation Accuracy: 0.8411, Validation Loss: 0.2543
# Epoch [29/30], Step [10/67], Train Loss: 0.2035
# Epoch [29/30], Train Accuracy: 0.8863
# Epoch [29/30], Validation Accuracy: 0.8504, Validation Loss: 0.2534
# Epoch [29/30], Step [20/67], Train Loss: 0.2200
# Epoch [29/30], Train Accuracy: 0.8932
# Epoch [29/30], Validation Accuracy: 0.8458, Validation Loss: 0.2540
# Epoch [29/30], Step [30/67], Train Loss: 0.1960
# Epoch [29/30], Train Accuracy: 0.8919
# Epoch [29/30], Validation Accuracy: 0.8448, Validation Loss: 0.2562
# Epoch [29/30], Step [40/67], Train Loss: 0.2058
# Epoch [29/30], Train Accuracy: 0.8951
# Epoch [29/30], Validation Accuracy: 0.8467, Validation Loss: 0.2585
# Epoch [29/30], Step [50/67], Train Loss: 0.1777
# Epoch [29/30], Train Accuracy: 0.8937
# Epoch [29/30], Validation Accuracy: 0.8481, Validation Loss: 0.2543
# Epoch [29/30], Step [60/67], Train Loss: 0.1836
# Epoch [29/30], Train Accuracy: 0.8935
# Epoch [29/30], Validation Accuracy: 0.8481, Validation Loss: 0.2533
# Epoch [29/30], Step [67/67], Train Loss: 0.2027
# Epoch [29/30], Train Accuracy: 0.8931
# Epoch [29/30], Validation Accuracy: 0.8411, Validation Loss: 0.2552
# Epoch [30/30], Step [10/67], Train Loss: 0.2115
# Epoch [30/30], Train Accuracy: 0.8969
# Epoch [30/30], Validation Accuracy: 0.8476, Validation Loss: 0.2536
# Epoch [30/30], Step [20/67], Train Loss: 0.2079
# Epoch [30/30], Train Accuracy: 0.8955
# Epoch [30/30], Validation Accuracy: 0.8486, Validation Loss: 0.2539
# Epoch [30/30], Step [30/67], Train Loss: 0.1907
# Epoch [30/30], Train Accuracy: 0.8924
# Epoch [30/30], Validation Accuracy: 0.8486, Validation Loss: 0.2533
# Epoch [30/30], Step [40/67], Train Loss: 0.1945
# Epoch [30/30], Train Accuracy: 0.8938
# Epoch [30/30], Validation Accuracy: 0.8430, Validation Loss: 0.2582
# Epoch [30/30], Step [50/67], Train Loss: 0.1937
# Epoch [30/30], Train Accuracy: 0.8936
# Epoch [30/30], Validation Accuracy: 0.8504, Validation Loss: 0.2526
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [60/67], Train Loss: 0.2076
# Epoch [30/30], Train Accuracy: 0.8939
# Epoch [30/30], Validation Accuracy: 0.8532, Validation Loss: 0.2521
# Model saved to ==> ./model_saves/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [67/67], Train Loss: 0.1779
# Epoch [30/30], Train Accuracy: 0.8946
# Epoch [30/30], Validation Accuracy: 0.8448, Validation Loss: 0.2530
# Ended Training, Test Accuracy: 0.8429

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)

# %% [markdown]
# # Loading the Undersampled Dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    data, labels, y = undersample(data, labels, y)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)
# Out:
# Start loading
# done loading

# %% [markdown]
# # Redefine Some Options

# %%
# SAVE_NAME = 'CNN_epoch_30'
SAVE_DIR = './model_saves_undersampled/'

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = MMCNN_CAT().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
# cuda
# Epoch [1/30], Step [10/55], Train Loss: 0.5570
# Epoch [1/30], Train Accuracy: 0.4223
# Epoch [1/30], Validation Accuracy: 0.5287, Validation Loss: 0.5541
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [20/55], Train Loss: 0.5363
# Epoch [1/30], Train Accuracy: 0.5123
# Epoch [1/30], Validation Accuracy: 0.5854, Validation Loss: 0.5345
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [30/55], Train Loss: 0.5180
# Epoch [1/30], Train Accuracy: 0.5504
# Epoch [1/30], Validation Accuracy: 0.6051, Validation Loss: 0.5119
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [40/55], Train Loss: 0.4791
# Epoch [1/30], Train Accuracy: 0.5778
# Epoch [1/30], Validation Accuracy: 0.6433, Validation Loss: 0.4932
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [50/55], Train Loss: 0.4633
# Epoch [1/30], Train Accuracy: 0.5930
# Epoch [1/30], Validation Accuracy: 0.6630, Validation Loss: 0.4778
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [1/30], Step [55/55], Train Loss: 0.4637
# Epoch [1/30], Train Accuracy: 0.5995
# Epoch [1/30], Validation Accuracy: 0.6485, Validation Loss: 0.4691
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [10/55], Train Loss: 0.4614
# Epoch [2/30], Train Accuracy: 0.6719
# Epoch [2/30], Validation Accuracy: 0.6491, Validation Loss: 0.4581
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [20/55], Train Loss: 0.4409
# Epoch [2/30], Train Accuracy: 0.6730
# Epoch [2/30], Validation Accuracy: 0.6595, Validation Loss: 0.4485
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [30/55], Train Loss: 0.4168
# Epoch [2/30], Train Accuracy: 0.6858
# Epoch [2/30], Validation Accuracy: 0.6607, Validation Loss: 0.4393
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [40/55], Train Loss: 0.4372
# Epoch [2/30], Train Accuracy: 0.6890
# Epoch [2/30], Validation Accuracy: 0.6578, Validation Loss: 0.4342
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [50/55], Train Loss: 0.4205
# Epoch [2/30], Train Accuracy: 0.6929
# Epoch [2/30], Validation Accuracy: 0.6827, Validation Loss: 0.4271
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [2/30], Step [55/55], Train Loss: 0.4585
# Epoch [2/30], Train Accuracy: 0.6969
# Epoch [2/30], Validation Accuracy: 0.6908, Validation Loss: 0.4256
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [10/55], Train Loss: 0.3843
# Epoch [3/30], Train Accuracy: 0.7223
# Epoch [3/30], Validation Accuracy: 0.6862, Validation Loss: 0.4205
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [20/55], Train Loss: 0.3980
# Epoch [3/30], Train Accuracy: 0.7328
# Epoch [3/30], Validation Accuracy: 0.7006, Validation Loss: 0.4142
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [30/55], Train Loss: 0.4026
# Epoch [3/30], Train Accuracy: 0.7332
# Epoch [3/30], Validation Accuracy: 0.7018, Validation Loss: 0.4103
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [40/55], Train Loss: 0.3910
# Epoch [3/30], Train Accuracy: 0.7350
# Epoch [3/30], Validation Accuracy: 0.7035, Validation Loss: 0.4062
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [50/55], Train Loss: 0.3991
# Epoch [3/30], Train Accuracy: 0.7352
# Epoch [3/30], Validation Accuracy: 0.7163, Validation Loss: 0.4015
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [3/30], Step [55/55], Train Loss: 0.3931
# Epoch [3/30], Train Accuracy: 0.7383
# Epoch [3/30], Validation Accuracy: 0.7145, Validation Loss: 0.4007
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [10/55], Train Loss: 0.3539
# Epoch [4/30], Train Accuracy: 0.7730
# Epoch [4/30], Validation Accuracy: 0.7203, Validation Loss: 0.3953
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [20/55], Train Loss: 0.3849
# Epoch [4/30], Train Accuracy: 0.7641
# Epoch [4/30], Validation Accuracy: 0.7255, Validation Loss: 0.3924
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [30/55], Train Loss: 0.3560
# Epoch [4/30], Train Accuracy: 0.7651
# Epoch [4/30], Validation Accuracy: 0.7180, Validation Loss: 0.3889
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [40/55], Train Loss: 0.3480
# Epoch [4/30], Train Accuracy: 0.7646
# Epoch [4/30], Validation Accuracy: 0.7284, Validation Loss: 0.3871
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [50/55], Train Loss: 0.3540
# Epoch [4/30], Train Accuracy: 0.7653
# Epoch [4/30], Validation Accuracy: 0.7360, Validation Loss: 0.3820
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [4/30], Step [55/55], Train Loss: 0.3602
# Epoch [4/30], Train Accuracy: 0.7666
# Epoch [4/30], Validation Accuracy: 0.7406, Validation Loss: 0.3843
# Epoch [5/30], Step [10/55], Train Loss: 0.3408
# Epoch [5/30], Train Accuracy: 0.7758
# Epoch [5/30], Validation Accuracy: 0.7377, Validation Loss: 0.3772
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [20/55], Train Loss: 0.3537
# Epoch [5/30], Train Accuracy: 0.7830
# Epoch [5/30], Validation Accuracy: 0.7522, Validation Loss: 0.3725
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [30/55], Train Loss: 0.3317
# Epoch [5/30], Train Accuracy: 0.7859
# Epoch [5/30], Validation Accuracy: 0.7510, Validation Loss: 0.3696
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [40/55], Train Loss: 0.3625
# Epoch [5/30], Train Accuracy: 0.7881
# Epoch [5/30], Validation Accuracy: 0.7626, Validation Loss: 0.3674
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [5/30], Step [50/55], Train Loss: 0.3515
# Epoch [5/30], Train Accuracy: 0.7858
# Epoch [5/30], Validation Accuracy: 0.7446, Validation Loss: 0.3686
# Epoch [5/30], Step [55/55], Train Loss: 0.3346
# Epoch [5/30], Train Accuracy: 0.7865
# Epoch [5/30], Validation Accuracy: 0.7574, Validation Loss: 0.3642
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [10/55], Train Loss: 0.3170
# Epoch [6/30], Train Accuracy: 0.7953
# Epoch [6/30], Validation Accuracy: 0.7620, Validation Loss: 0.3617
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [20/55], Train Loss: 0.3333
# Epoch [6/30], Train Accuracy: 0.7986
# Epoch [6/30], Validation Accuracy: 0.7672, Validation Loss: 0.3641
# Epoch [6/30], Step [30/55], Train Loss: 0.3325
# Epoch [6/30], Train Accuracy: 0.7982
# Epoch [6/30], Validation Accuracy: 0.7672, Validation Loss: 0.3574
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [40/55], Train Loss: 0.3303
# Epoch [6/30], Train Accuracy: 0.7979
# Epoch [6/30], Validation Accuracy: 0.7765, Validation Loss: 0.3556
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [6/30], Step [50/55], Train Loss: 0.3298
# Epoch [6/30], Train Accuracy: 0.7997
# Epoch [6/30], Validation Accuracy: 0.7603, Validation Loss: 0.3561
# Epoch [6/30], Step [55/55], Train Loss: 0.3279
# Epoch [6/30], Train Accuracy: 0.7990
# Epoch [6/30], Validation Accuracy: 0.7805, Validation Loss: 0.3549
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [10/55], Train Loss: 0.3337
# Epoch [7/30], Train Accuracy: 0.8059
# Epoch [7/30], Validation Accuracy: 0.7823, Validation Loss: 0.3510
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [20/55], Train Loss: 0.3237
# Epoch [7/30], Train Accuracy: 0.8082
# Epoch [7/30], Validation Accuracy: 0.7672, Validation Loss: 0.3516
# Epoch [7/30], Step [30/55], Train Loss: 0.3109
# Epoch [7/30], Train Accuracy: 0.8095
# Epoch [7/30], Validation Accuracy: 0.7695, Validation Loss: 0.3514
# Epoch [7/30], Step [40/55], Train Loss: 0.3008
# Epoch [7/30], Train Accuracy: 0.8093
# Epoch [7/30], Validation Accuracy: 0.7574, Validation Loss: 0.3539
# Epoch [7/30], Step [50/55], Train Loss: 0.3194
# Epoch [7/30], Train Accuracy: 0.8118
# Epoch [7/30], Validation Accuracy: 0.7834, Validation Loss: 0.3458
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [7/30], Step [55/55], Train Loss: 0.3123
# Epoch [7/30], Train Accuracy: 0.8118
# Epoch [7/30], Validation Accuracy: 0.7643, Validation Loss: 0.3547
# Epoch [8/30], Step [10/55], Train Loss: 0.3309
# Epoch [8/30], Train Accuracy: 0.8152
# Epoch [8/30], Validation Accuracy: 0.7811, Validation Loss: 0.3440
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [20/55], Train Loss: 0.3227
# Epoch [8/30], Train Accuracy: 0.8207
# Epoch [8/30], Validation Accuracy: 0.7904, Validation Loss: 0.3425
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [30/55], Train Loss: 0.3270
# Epoch [8/30], Train Accuracy: 0.8176
# Epoch [8/30], Validation Accuracy: 0.7915, Validation Loss: 0.3414
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [40/55], Train Loss: 0.2943
# Epoch [8/30], Train Accuracy: 0.8166
# Epoch [8/30], Validation Accuracy: 0.7852, Validation Loss: 0.3423
# Epoch [8/30], Step [50/55], Train Loss: 0.2972
# Epoch [8/30], Train Accuracy: 0.8185
# Epoch [8/30], Validation Accuracy: 0.7840, Validation Loss: 0.3403
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [8/30], Step [55/55], Train Loss: 0.3019
# Epoch [8/30], Train Accuracy: 0.8196
# Epoch [8/30], Validation Accuracy: 0.7898, Validation Loss: 0.3395
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [10/55], Train Loss: 0.2784
# Epoch [9/30], Train Accuracy: 0.8215
# Epoch [9/30], Validation Accuracy: 0.7939, Validation Loss: 0.3372
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [20/55], Train Loss: 0.2975
# Epoch [9/30], Train Accuracy: 0.8244
# Epoch [9/30], Validation Accuracy: 0.7805, Validation Loss: 0.3393
# Epoch [9/30], Step [30/55], Train Loss: 0.2797
# Epoch [9/30], Train Accuracy: 0.8273
# Epoch [9/30], Validation Accuracy: 0.7921, Validation Loss: 0.3348
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [40/55], Train Loss: 0.2875
# Epoch [9/30], Train Accuracy: 0.8262
# Epoch [9/30], Validation Accuracy: 0.7881, Validation Loss: 0.3372
# Epoch [9/30], Step [50/55], Train Loss: 0.3017
# Epoch [9/30], Train Accuracy: 0.8259
# Epoch [9/30], Validation Accuracy: 0.7904, Validation Loss: 0.3343
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [9/30], Step [55/55], Train Loss: 0.3040
# Epoch [9/30], Train Accuracy: 0.8245
# Epoch [9/30], Validation Accuracy: 0.7962, Validation Loss: 0.3341
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [10/55], Train Loss: 0.2899
# Epoch [10/30], Train Accuracy: 0.8348
# Epoch [10/30], Validation Accuracy: 0.7927, Validation Loss: 0.3318
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [20/55], Train Loss: 0.3208
# Epoch [10/30], Train Accuracy: 0.8305
# Epoch [10/30], Validation Accuracy: 0.7950, Validation Loss: 0.3343
# Epoch [10/30], Step [30/55], Train Loss: 0.3232
# Epoch [10/30], Train Accuracy: 0.8310
# Epoch [10/30], Validation Accuracy: 0.7979, Validation Loss: 0.3322
# Epoch [10/30], Step [40/55], Train Loss: 0.3273
# Epoch [10/30], Train Accuracy: 0.8288
# Epoch [10/30], Validation Accuracy: 0.7765, Validation Loss: 0.3357
# Epoch [10/30], Step [50/55], Train Loss: 0.3117
# Epoch [10/30], Train Accuracy: 0.8298
# Epoch [10/30], Validation Accuracy: 0.7939, Validation Loss: 0.3306
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [10/30], Step [55/55], Train Loss: 0.2919
# Epoch [10/30], Train Accuracy: 0.8303
# Epoch [10/30], Validation Accuracy: 0.7944, Validation Loss: 0.3285
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [10/55], Train Loss: 0.2964
# Epoch [11/30], Train Accuracy: 0.8277
# Epoch [11/30], Validation Accuracy: 0.7997, Validation Loss: 0.3295
# Epoch [11/30], Step [20/55], Train Loss: 0.2634
# Epoch [11/30], Train Accuracy: 0.8330
# Epoch [11/30], Validation Accuracy: 0.7985, Validation Loss: 0.3268
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [30/55], Train Loss: 0.2775
# Epoch [11/30], Train Accuracy: 0.8316
# Epoch [11/30], Validation Accuracy: 0.7991, Validation Loss: 0.3279
# Epoch [11/30], Step [40/55], Train Loss: 0.2909
# Epoch [11/30], Train Accuracy: 0.8336
# Epoch [11/30], Validation Accuracy: 0.8002, Validation Loss: 0.3263
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [50/55], Train Loss: 0.3003
# Epoch [11/30], Train Accuracy: 0.8327
# Epoch [11/30], Validation Accuracy: 0.8008, Validation Loss: 0.3255
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [11/30], Step [55/55], Train Loss: 0.2675
# Epoch [11/30], Train Accuracy: 0.8339
# Epoch [11/30], Validation Accuracy: 0.7939, Validation Loss: 0.3262
# Epoch [12/30], Step [10/55], Train Loss: 0.2893
# Epoch [12/30], Train Accuracy: 0.8387
# Epoch [12/30], Validation Accuracy: 0.8054, Validation Loss: 0.3234
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [20/55], Train Loss: 0.3074
# Epoch [12/30], Train Accuracy: 0.8426
# Epoch [12/30], Validation Accuracy: 0.8031, Validation Loss: 0.3235
# Epoch [12/30], Step [30/55], Train Loss: 0.2833
# Epoch [12/30], Train Accuracy: 0.8387
# Epoch [12/30], Validation Accuracy: 0.8066, Validation Loss: 0.3233
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [40/55], Train Loss: 0.2870
# Epoch [12/30], Train Accuracy: 0.8415
# Epoch [12/30], Validation Accuracy: 0.8054, Validation Loss: 0.3216
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [12/30], Step [50/55], Train Loss: 0.3000
# Epoch [12/30], Train Accuracy: 0.8413
# Epoch [12/30], Validation Accuracy: 0.7875, Validation Loss: 0.3273
# Epoch [12/30], Step [55/55], Train Loss: 0.2798
# Epoch [12/30], Train Accuracy: 0.8410
# Epoch [12/30], Validation Accuracy: 0.7968, Validation Loss: 0.3234
# Epoch [13/30], Step [10/55], Train Loss: 0.2926
# Epoch [13/30], Train Accuracy: 0.8355
# Epoch [13/30], Validation Accuracy: 0.8014, Validation Loss: 0.3247
# Epoch [13/30], Step [20/55], Train Loss: 0.2744
# Epoch [13/30], Train Accuracy: 0.8428
# Epoch [13/30], Validation Accuracy: 0.8002, Validation Loss: 0.3211
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [30/55], Train Loss: 0.2818
# Epoch [13/30], Train Accuracy: 0.8453
# Epoch [13/30], Validation Accuracy: 0.7985, Validation Loss: 0.3196
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [40/55], Train Loss: 0.2849
# Epoch [13/30], Train Accuracy: 0.8442
# Epoch [13/30], Validation Accuracy: 0.8107, Validation Loss: 0.3208
# Epoch [13/30], Step [50/55], Train Loss: 0.2691
# Epoch [13/30], Train Accuracy: 0.8452
# Epoch [13/30], Validation Accuracy: 0.7950, Validation Loss: 0.3184
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [13/30], Step [55/55], Train Loss: 0.2519
# Epoch [13/30], Train Accuracy: 0.8451
# Epoch [13/30], Validation Accuracy: 0.8124, Validation Loss: 0.3180
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [10/55], Train Loss: 0.2853
# Epoch [14/30], Train Accuracy: 0.8457
# Epoch [14/30], Validation Accuracy: 0.8159, Validation Loss: 0.3212
# Epoch [14/30], Step [20/55], Train Loss: 0.2741
# Epoch [14/30], Train Accuracy: 0.8510
# Epoch [14/30], Validation Accuracy: 0.8095, Validation Loss: 0.3185
# Epoch [14/30], Step [30/55], Train Loss: 0.3041
# Epoch [14/30], Train Accuracy: 0.8484
# Epoch [14/30], Validation Accuracy: 0.8054, Validation Loss: 0.3272
# Epoch [14/30], Step [40/55], Train Loss: 0.3063
# Epoch [14/30], Train Accuracy: 0.8484
# Epoch [14/30], Validation Accuracy: 0.8089, Validation Loss: 0.3152
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [50/55], Train Loss: 0.2740
# Epoch [14/30], Train Accuracy: 0.8459
# Epoch [14/30], Validation Accuracy: 0.8066, Validation Loss: 0.3140
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [14/30], Step [55/55], Train Loss: 0.2608
# Epoch [14/30], Train Accuracy: 0.8465
# Epoch [14/30], Validation Accuracy: 0.8089, Validation Loss: 0.3161
# Epoch [15/30], Step [10/55], Train Loss: 0.2668
# Epoch [15/30], Train Accuracy: 0.8453
# Epoch [15/30], Validation Accuracy: 0.8078, Validation Loss: 0.3150
# Epoch [15/30], Step [20/55], Train Loss: 0.3009
# Epoch [15/30], Train Accuracy: 0.8422
# Epoch [15/30], Validation Accuracy: 0.8101, Validation Loss: 0.3160
# Epoch [15/30], Step [30/55], Train Loss: 0.2972
# Epoch [15/30], Train Accuracy: 0.8482
# Epoch [15/30], Validation Accuracy: 0.8159, Validation Loss: 0.3148
# Epoch [15/30], Step [40/55], Train Loss: 0.2815
# Epoch [15/30], Train Accuracy: 0.8488
# Epoch [15/30], Validation Accuracy: 0.8031, Validation Loss: 0.3166
# Epoch [15/30], Step [50/55], Train Loss: 0.2883
# Epoch [15/30], Train Accuracy: 0.8483
# Epoch [15/30], Validation Accuracy: 0.8153, Validation Loss: 0.3126
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [15/30], Step [55/55], Train Loss: 0.2713
# Epoch [15/30], Train Accuracy: 0.8485
# Epoch [15/30], Validation Accuracy: 0.8043, Validation Loss: 0.3139
# Epoch [16/30], Step [10/55], Train Loss: 0.2573
# Epoch [16/30], Train Accuracy: 0.8449
# Epoch [16/30], Validation Accuracy: 0.8089, Validation Loss: 0.3118
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [20/55], Train Loss: 0.2963
# Epoch [16/30], Train Accuracy: 0.8480
# Epoch [16/30], Validation Accuracy: 0.8147, Validation Loss: 0.3125
# Epoch [16/30], Step [30/55], Train Loss: 0.2575
# Epoch [16/30], Train Accuracy: 0.8483
# Epoch [16/30], Validation Accuracy: 0.8159, Validation Loss: 0.3095
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [16/30], Step [40/55], Train Loss: 0.2844
# Epoch [16/30], Train Accuracy: 0.8498
# Epoch [16/30], Validation Accuracy: 0.8147, Validation Loss: 0.3098
# Epoch [16/30], Step [50/55], Train Loss: 0.2876
# Epoch [16/30], Train Accuracy: 0.8518
# Epoch [16/30], Validation Accuracy: 0.7997, Validation Loss: 0.3174
# Epoch [16/30], Step [55/55], Train Loss: 0.2906
# Epoch [16/30], Train Accuracy: 0.8519
# Epoch [16/30], Validation Accuracy: 0.8008, Validation Loss: 0.3138
# Epoch [17/30], Step [10/55], Train Loss: 0.3136
# Epoch [17/30], Train Accuracy: 0.8473
# Epoch [17/30], Validation Accuracy: 0.8159, Validation Loss: 0.3096
# Epoch [17/30], Step [20/55], Train Loss: 0.2676
# Epoch [17/30], Train Accuracy: 0.8559
# Epoch [17/30], Validation Accuracy: 0.8159, Validation Loss: 0.3102
# Epoch [17/30], Step [30/55], Train Loss: 0.2416
# Epoch [17/30], Train Accuracy: 0.8542
# Epoch [17/30], Validation Accuracy: 0.8170, Validation Loss: 0.3085
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [40/55], Train Loss: 0.2767
# Epoch [17/30], Train Accuracy: 0.8549
# Epoch [17/30], Validation Accuracy: 0.8095, Validation Loss: 0.3072
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [17/30], Step [50/55], Train Loss: 0.2557
# Epoch [17/30], Train Accuracy: 0.8548
# Epoch [17/30], Validation Accuracy: 0.8124, Validation Loss: 0.3074
# Epoch [17/30], Step [55/55], Train Loss: 0.2573
# Epoch [17/30], Train Accuracy: 0.8545
# Epoch [17/30], Validation Accuracy: 0.8130, Validation Loss: 0.3099
# Epoch [18/30], Step [10/55], Train Loss: 0.2814
# Epoch [18/30], Train Accuracy: 0.8586
# Epoch [18/30], Validation Accuracy: 0.8170, Validation Loss: 0.3059
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [20/55], Train Loss: 0.2849
# Epoch [18/30], Train Accuracy: 0.8564
# Epoch [18/30], Validation Accuracy: 0.8193, Validation Loss: 0.3070
# Epoch [18/30], Step [30/55], Train Loss: 0.2910
# Epoch [18/30], Train Accuracy: 0.8549
# Epoch [18/30], Validation Accuracy: 0.8164, Validation Loss: 0.3055
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [40/55], Train Loss: 0.2727
# Epoch [18/30], Train Accuracy: 0.8575
# Epoch [18/30], Validation Accuracy: 0.8147, Validation Loss: 0.3060
# Epoch [18/30], Step [50/55], Train Loss: 0.2378
# Epoch [18/30], Train Accuracy: 0.8570
# Epoch [18/30], Validation Accuracy: 0.8170, Validation Loss: 0.3047
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [18/30], Step [55/55], Train Loss: 0.1922
# Epoch [18/30], Train Accuracy: 0.8579
# Epoch [18/30], Validation Accuracy: 0.8193, Validation Loss: 0.3055
# Epoch [19/30], Step [10/55], Train Loss: 0.2842
# Epoch [19/30], Train Accuracy: 0.8617
# Epoch [19/30], Validation Accuracy: 0.8176, Validation Loss: 0.3064
# Epoch [19/30], Step [20/55], Train Loss: 0.2774
# Epoch [19/30], Train Accuracy: 0.8535
# Epoch [19/30], Validation Accuracy: 0.8118, Validation Loss: 0.3088
# Epoch [19/30], Step [30/55], Train Loss: 0.2785
# Epoch [19/30], Train Accuracy: 0.8556
# Epoch [19/30], Validation Accuracy: 0.8176, Validation Loss: 0.3045
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [40/55], Train Loss: 0.2493
# Epoch [19/30], Train Accuracy: 0.8558
# Epoch [19/30], Validation Accuracy: 0.8193, Validation Loss: 0.3060
# Epoch [19/30], Step [50/55], Train Loss: 0.2699
# Epoch [19/30], Train Accuracy: 0.8593
# Epoch [19/30], Validation Accuracy: 0.8217, Validation Loss: 0.3043
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [19/30], Step [55/55], Train Loss: 0.3014
# Epoch [19/30], Train Accuracy: 0.8598
# Epoch [19/30], Validation Accuracy: 0.8107, Validation Loss: 0.3095
# Epoch [20/30], Step [10/55], Train Loss: 0.2521
# Epoch [20/30], Train Accuracy: 0.8703
# Epoch [20/30], Validation Accuracy: 0.8159, Validation Loss: 0.3033
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [20/55], Train Loss: 0.2547
# Epoch [20/30], Train Accuracy: 0.8617
# Epoch [20/30], Validation Accuracy: 0.8153, Validation Loss: 0.3075
# Epoch [20/30], Step [30/55], Train Loss: 0.3036
# Epoch [20/30], Train Accuracy: 0.8594
# Epoch [20/30], Validation Accuracy: 0.8159, Validation Loss: 0.3023
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [40/55], Train Loss: 0.2474
# Epoch [20/30], Train Accuracy: 0.8592
# Epoch [20/30], Validation Accuracy: 0.8199, Validation Loss: 0.3012
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [20/30], Step [50/55], Train Loss: 0.2891
# Epoch [20/30], Train Accuracy: 0.8608
# Epoch [20/30], Validation Accuracy: 0.8246, Validation Loss: 0.3013
# Epoch [20/30], Step [55/55], Train Loss: 0.2355
# Epoch [20/30], Train Accuracy: 0.8610
# Epoch [20/30], Validation Accuracy: 0.8199, Validation Loss: 0.3027
# Epoch [21/30], Step [10/55], Train Loss: 0.3003
# Epoch [21/30], Train Accuracy: 0.8484
# Epoch [21/30], Validation Accuracy: 0.8141, Validation Loss: 0.3010
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [21/30], Step [20/55], Train Loss: 0.2694
# Epoch [21/30], Train Accuracy: 0.8543
# Epoch [21/30], Validation Accuracy: 0.8182, Validation Loss: 0.3014
# Epoch [21/30], Step [30/55], Train Loss: 0.2567
# Epoch [21/30], Train Accuracy: 0.8583
# Epoch [21/30], Validation Accuracy: 0.8263, Validation Loss: 0.3024
# Epoch [21/30], Step [40/55], Train Loss: 0.2348
# Epoch [21/30], Train Accuracy: 0.8621
# Epoch [21/30], Validation Accuracy: 0.8170, Validation Loss: 0.3045
# Epoch [21/30], Step [50/55], Train Loss: 0.2704
# Epoch [21/30], Train Accuracy: 0.8632
# Epoch [21/30], Validation Accuracy: 0.8263, Validation Loss: 0.2996
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [21/30], Step [55/55], Train Loss: 0.2870
# Epoch [21/30], Train Accuracy: 0.8638
# Epoch [21/30], Validation Accuracy: 0.8234, Validation Loss: 0.2993
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [22/30], Step [10/55], Train Loss: 0.2625
# Epoch [22/30], Train Accuracy: 0.8707
# Epoch [22/30], Validation Accuracy: 0.8222, Validation Loss: 0.2995
# Epoch [22/30], Step [20/55], Train Loss: 0.2614
# Epoch [22/30], Train Accuracy: 0.8664
# Epoch [22/30], Validation Accuracy: 0.8251, Validation Loss: 0.2991
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [22/30], Step [30/55], Train Loss: 0.2724
# Epoch [22/30], Train Accuracy: 0.8685
# Epoch [22/30], Validation Accuracy: 0.8211, Validation Loss: 0.3000
# Epoch [22/30], Step [40/55], Train Loss: 0.2521
# Epoch [22/30], Train Accuracy: 0.8664
# Epoch [22/30], Validation Accuracy: 0.8199, Validation Loss: 0.2987
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [22/30], Step [50/55], Train Loss: 0.2575
# Epoch [22/30], Train Accuracy: 0.8652
# Epoch [22/30], Validation Accuracy: 0.8240, Validation Loss: 0.3008
# Epoch [22/30], Step [55/55], Train Loss: 0.3139
# Epoch [22/30], Train Accuracy: 0.8658
# Epoch [22/30], Validation Accuracy: 0.8083, Validation Loss: 0.3315
# Epoch [23/30], Step [10/55], Train Loss: 0.2415
# Epoch [23/30], Train Accuracy: 0.8781
# Epoch [23/30], Validation Accuracy: 0.8228, Validation Loss: 0.3031
# Epoch [23/30], Step [20/55], Train Loss: 0.2404
# Epoch [23/30], Train Accuracy: 0.8672
# Epoch [23/30], Validation Accuracy: 0.8246, Validation Loss: 0.2967
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [23/30], Step [30/55], Train Loss: 0.2771
# Epoch [23/30], Train Accuracy: 0.8664
# Epoch [23/30], Validation Accuracy: 0.8292, Validation Loss: 0.2980
# Epoch [23/30], Step [40/55], Train Loss: 0.2555
# Epoch [23/30], Train Accuracy: 0.8666
# Epoch [23/30], Validation Accuracy: 0.8269, Validation Loss: 0.2980
# Epoch [23/30], Step [50/55], Train Loss: 0.2688
# Epoch [23/30], Train Accuracy: 0.8672
# Epoch [23/30], Validation Accuracy: 0.8269, Validation Loss: 0.2962
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [23/30], Step [55/55], Train Loss: 0.2654
# Epoch [23/30], Train Accuracy: 0.8669
# Epoch [23/30], Validation Accuracy: 0.8176, Validation Loss: 0.3024
# Epoch [24/30], Step [10/55], Train Loss: 0.2522
# Epoch [24/30], Train Accuracy: 0.8633
# Epoch [24/30], Validation Accuracy: 0.8315, Validation Loss: 0.2968
# Epoch [24/30], Step [20/55], Train Loss: 0.2543
# Epoch [24/30], Train Accuracy: 0.8631
# Epoch [24/30], Validation Accuracy: 0.8257, Validation Loss: 0.2982
# Epoch [24/30], Step [30/55], Train Loss: 0.2680
# Epoch [24/30], Train Accuracy: 0.8632
# Epoch [24/30], Validation Accuracy: 0.8298, Validation Loss: 0.2957
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [24/30], Step [40/55], Train Loss: 0.2678
# Epoch [24/30], Train Accuracy: 0.8681
# Epoch [24/30], Validation Accuracy: 0.8286, Validation Loss: 0.2963
# Epoch [24/30], Step [50/55], Train Loss: 0.2558
# Epoch [24/30], Train Accuracy: 0.8690
# Epoch [24/30], Validation Accuracy: 0.8251, Validation Loss: 0.2949
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [24/30], Step [55/55], Train Loss: 0.2279
# Epoch [24/30], Train Accuracy: 0.8685
# Epoch [24/30], Validation Accuracy: 0.8222, Validation Loss: 0.3039
# Epoch [25/30], Step [10/55], Train Loss: 0.2544
# Epoch [25/30], Train Accuracy: 0.8746
# Epoch [25/30], Validation Accuracy: 0.8246, Validation Loss: 0.2966
# Epoch [25/30], Step [20/55], Train Loss: 0.2373
# Epoch [25/30], Train Accuracy: 0.8684
# Epoch [25/30], Validation Accuracy: 0.8217, Validation Loss: 0.2952
# Epoch [25/30], Step [30/55], Train Loss: 0.2366
# Epoch [25/30], Train Accuracy: 0.8694
# Epoch [25/30], Validation Accuracy: 0.8222, Validation Loss: 0.2957
# Epoch [25/30], Step [40/55], Train Loss: 0.2638
# Epoch [25/30], Train Accuracy: 0.8706
# Epoch [25/30], Validation Accuracy: 0.8327, Validation Loss: 0.2984
# Epoch [25/30], Step [50/55], Train Loss: 0.2580
# Epoch [25/30], Train Accuracy: 0.8721
# Epoch [25/30], Validation Accuracy: 0.8251, Validation Loss: 0.2973
# Epoch [25/30], Step [55/55], Train Loss: 0.2558
# Epoch [25/30], Train Accuracy: 0.8710
# Epoch [25/30], Validation Accuracy: 0.8315, Validation Loss: 0.2941
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [26/30], Step [10/55], Train Loss: 0.2754
# Epoch [26/30], Train Accuracy: 0.8699
# Epoch [26/30], Validation Accuracy: 0.8315, Validation Loss: 0.2944
# Epoch [26/30], Step [20/55], Train Loss: 0.2452
# Epoch [26/30], Train Accuracy: 0.8670
# Epoch [26/30], Validation Accuracy: 0.8292, Validation Loss: 0.2945
# Epoch [26/30], Step [30/55], Train Loss: 0.2630
# Epoch [26/30], Train Accuracy: 0.8669
# Epoch [26/30], Validation Accuracy: 0.8303, Validation Loss: 0.2953
# Epoch [26/30], Step [40/55], Train Loss: 0.2366
# Epoch [26/30], Train Accuracy: 0.8706
# Epoch [26/30], Validation Accuracy: 0.8298, Validation Loss: 0.2928
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [26/30], Step [50/55], Train Loss: 0.2499
# Epoch [26/30], Train Accuracy: 0.8709
# Epoch [26/30], Validation Accuracy: 0.8292, Validation Loss: 0.2947
# Epoch [26/30], Step [55/55], Train Loss: 0.2556
# Epoch [26/30], Train Accuracy: 0.8708
# Epoch [26/30], Validation Accuracy: 0.8384, Validation Loss: 0.2944
# Epoch [27/30], Step [10/55], Train Loss: 0.2642
# Epoch [27/30], Train Accuracy: 0.8781
# Epoch [27/30], Validation Accuracy: 0.8298, Validation Loss: 0.2937
# Epoch [27/30], Step [20/55], Train Loss: 0.2754
# Epoch [27/30], Train Accuracy: 0.8756
# Epoch [27/30], Validation Accuracy: 0.8222, Validation Loss: 0.3005
# Epoch [27/30], Step [30/55], Train Loss: 0.2376
# Epoch [27/30], Train Accuracy: 0.8749
# Epoch [27/30], Validation Accuracy: 0.8448, Validation Loss: 0.2926
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [27/30], Step [40/55], Train Loss: 0.2411
# Epoch [27/30], Train Accuracy: 0.8736
# Epoch [27/30], Validation Accuracy: 0.8332, Validation Loss: 0.2933
# Epoch [27/30], Step [50/55], Train Loss: 0.2608
# Epoch [27/30], Train Accuracy: 0.8737
# Epoch [27/30], Validation Accuracy: 0.8315, Validation Loss: 0.2926
# Epoch [27/30], Step [55/55], Train Loss: 0.2336
# Epoch [27/30], Train Accuracy: 0.8739
# Epoch [27/30], Validation Accuracy: 0.8321, Validation Loss: 0.2990
# Epoch [28/30], Step [10/55], Train Loss: 0.2634
# Epoch [28/30], Train Accuracy: 0.8656
# Epoch [28/30], Validation Accuracy: 0.8350, Validation Loss: 0.2907
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [20/55], Train Loss: 0.2539
# Epoch [28/30], Train Accuracy: 0.8727
# Epoch [28/30], Validation Accuracy: 0.8292, Validation Loss: 0.2935
# Epoch [28/30], Step [30/55], Train Loss: 0.2303
# Epoch [28/30], Train Accuracy: 0.8751
# Epoch [28/30], Validation Accuracy: 0.8327, Validation Loss: 0.2900
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [28/30], Step [40/55], Train Loss: 0.2443
# Epoch [28/30], Train Accuracy: 0.8750
# Epoch [28/30], Validation Accuracy: 0.8338, Validation Loss: 0.2905
# Epoch [28/30], Step [50/55], Train Loss: 0.2489
# Epoch [28/30], Train Accuracy: 0.8747
# Epoch [28/30], Validation Accuracy: 0.8327, Validation Loss: 0.2905
# Epoch [28/30], Step [55/55], Train Loss: 0.2067
# Epoch [28/30], Train Accuracy: 0.8739
# Epoch [28/30], Validation Accuracy: 0.8269, Validation Loss: 0.2958
# Epoch [29/30], Step [10/55], Train Loss: 0.2316
# Epoch [29/30], Train Accuracy: 0.8734
# Epoch [29/30], Validation Accuracy: 0.8396, Validation Loss: 0.2908
# Epoch [29/30], Step [20/55], Train Loss: 0.2738
# Epoch [29/30], Train Accuracy: 0.8783
# Epoch [29/30], Validation Accuracy: 0.8384, Validation Loss: 0.2903
# Epoch [29/30], Step [30/55], Train Loss: 0.2315
# Epoch [29/30], Train Accuracy: 0.8794
# Epoch [29/30], Validation Accuracy: 0.8367, Validation Loss: 0.2907
# Epoch [29/30], Step [40/55], Train Loss: 0.2417
# Epoch [29/30], Train Accuracy: 0.8789
# Epoch [29/30], Validation Accuracy: 0.8327, Validation Loss: 0.2915
# Epoch [29/30], Step [50/55], Train Loss: 0.2222
# Epoch [29/30], Train Accuracy: 0.8788
# Epoch [29/30], Validation Accuracy: 0.8315, Validation Loss: 0.2919
# Epoch [29/30], Step [55/55], Train Loss: 0.2392
# Epoch [29/30], Train Accuracy: 0.8776
# Epoch [29/30], Validation Accuracy: 0.8199, Validation Loss: 0.3009
# Epoch [30/30], Step [10/55], Train Loss: 0.2106
# Epoch [30/30], Train Accuracy: 0.8746
# Epoch [30/30], Validation Accuracy: 0.8413, Validation Loss: 0.2899
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [20/55], Train Loss: 0.2174
# Epoch [30/30], Train Accuracy: 0.8750
# Epoch [30/30], Validation Accuracy: 0.8292, Validation Loss: 0.2935
# Epoch [30/30], Step [30/55], Train Loss: 0.2572
# Epoch [30/30], Train Accuracy: 0.8770
# Epoch [30/30], Validation Accuracy: 0.8367, Validation Loss: 0.2896
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [40/55], Train Loss: 0.2437
# Epoch [30/30], Train Accuracy: 0.8759
# Epoch [30/30], Validation Accuracy: 0.8338, Validation Loss: 0.2893
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_CAT_epoch_30.pt
# Epoch [30/30], Step [50/55], Train Loss: 0.2256
# Epoch [30/30], Train Accuracy: 0.8758
# Epoch [30/30], Validation Accuracy: 0.8373, Validation Loss: 0.2901
# Epoch [30/30], Step [55/55], Train Loss: 0.2648
# Epoch [30/30], Train Accuracy: 0.8771
# Epoch [30/30], Validation Accuracy: 0.8327, Validation Loss: 0.2895
# Ended Training, Test Accuracy: 0.8194

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)
