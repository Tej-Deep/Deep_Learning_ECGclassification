# %%
from preprocess.preprocess import load_dataset, compute_label_agg, select_data, get_data_loaders, undersample

import torch
import torch.nn as nn
import torch.optim as optim

from models.CNN import MMCNN_SUM
from utils.trainer import trainer
from utils.RNN_utils import plot_losses, rename_with_acc

# %%
# Define device for torch
use_cuda = True
device = torch.device("cuda" if (
    use_cuda and torch.cuda.is_available()) else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Define options

# %%
LOAD_DATASET = False
TRAIN_PATH = './PTB_train.pt'
VALID_PATH = './PTB_valid.pt'
TEST_PATH = './PTB_test.pt'
SAVE_NAME = 'MMCNN_SUM_epoch_30'
SAVE_DIR = './model_saves/'
BATCH_SIZE = 256

# %% [markdown]
# # Loading the dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)
# Out:
# Start loading
# done loading

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = MMCNN_SUM().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
# cuda
# Epoch [1/30], Step [10/67], Train Loss: 0.4253
# Epoch [1/30], Train Accuracy: 0.5867
# Epoch [1/30], Validation Accuracy: 0.5801, Validation Loss: 0.4830
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [20/67], Train Loss: 0.4101
# Epoch [1/30], Train Accuracy: 0.6369
# Epoch [1/30], Validation Accuracy: 0.6650, Validation Loss: 0.4123
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [30/67], Train Loss: 0.3555
# Epoch [1/30], Train Accuracy: 0.6671
# Epoch [1/30], Validation Accuracy: 0.7130, Validation Loss: 0.3852
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [40/67], Train Loss: 0.3441
# Epoch [1/30], Train Accuracy: 0.6933
# Epoch [1/30], Validation Accuracy: 0.7558, Validation Loss: 0.3671
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [50/67], Train Loss: 0.3582
# Epoch [1/30], Train Accuracy: 0.7097
# Epoch [1/30], Validation Accuracy: 0.7623, Validation Loss: 0.3518
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [60/67], Train Loss: 0.3515
# Epoch [1/30], Train Accuracy: 0.7271
# Epoch [1/30], Validation Accuracy: 0.7586, Validation Loss: 0.3479
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [67/67], Train Loss: 0.3471
# Epoch [1/30], Train Accuracy: 0.7338
# Epoch [1/30], Validation Accuracy: 0.7707, Validation Loss: 0.3374
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [10/67], Train Loss: 0.3001
# Epoch [2/30], Train Accuracy: 0.8293
# Epoch [2/30], Validation Accuracy: 0.7721, Validation Loss: 0.3292
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [20/67], Train Loss: 0.3108
# Epoch [2/30], Train Accuracy: 0.8268
# Epoch [2/30], Validation Accuracy: 0.7964, Validation Loss: 0.3238
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [30/67], Train Loss: 0.2805
# Epoch [2/30], Train Accuracy: 0.8259
# Epoch [2/30], Validation Accuracy: 0.7796, Validation Loss: 0.3205
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [40/67], Train Loss: 0.2954
# Epoch [2/30], Train Accuracy: 0.8307
# Epoch [2/30], Validation Accuracy: 0.8043, Validation Loss: 0.3177
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [50/67], Train Loss: 0.3209
# Epoch [2/30], Train Accuracy: 0.8305
# Epoch [2/30], Validation Accuracy: 0.7926, Validation Loss: 0.3131
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [60/67], Train Loss: 0.3067
# Epoch [2/30], Train Accuracy: 0.8346
# Epoch [2/30], Validation Accuracy: 0.8085, Validation Loss: 0.3050
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [67/67], Train Loss: 0.2991
# Epoch [2/30], Train Accuracy: 0.8349
# Epoch [2/30], Validation Accuracy: 0.8103, Validation Loss: 0.3020
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [10/67], Train Loss: 0.2690
# Epoch [3/30], Train Accuracy: 0.8551
# Epoch [3/30], Validation Accuracy: 0.8131, Validation Loss: 0.2989
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [20/67], Train Loss: 0.2806
# Epoch [3/30], Train Accuracy: 0.8555
# Epoch [3/30], Validation Accuracy: 0.8178, Validation Loss: 0.2987
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [30/67], Train Loss: 0.2560
# Epoch [3/30], Train Accuracy: 0.8523
# Epoch [3/30], Validation Accuracy: 0.8057, Validation Loss: 0.2954
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [40/67], Train Loss: 0.2781
# Epoch [3/30], Train Accuracy: 0.8550
# Epoch [3/30], Validation Accuracy: 0.8248, Validation Loss: 0.2977
# Epoch [3/30], Step [50/67], Train Loss: 0.2944
# Epoch [3/30], Train Accuracy: 0.8535
# Epoch [3/30], Validation Accuracy: 0.8099, Validation Loss: 0.2927
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [60/67], Train Loss: 0.2907
# Epoch [3/30], Train Accuracy: 0.8554
# Epoch [3/30], Validation Accuracy: 0.8192, Validation Loss: 0.2857
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [67/67], Train Loss: 0.2832
# Epoch [3/30], Train Accuracy: 0.8551
# Epoch [3/30], Validation Accuracy: 0.8229, Validation Loss: 0.2848
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [4/30], Step [10/67], Train Loss: 0.2501
# Epoch [4/30], Train Accuracy: 0.8723
# Epoch [4/30], Validation Accuracy: 0.8225, Validation Loss: 0.2830
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [4/30], Step [20/67], Train Loss: 0.2627
# Epoch [4/30], Train Accuracy: 0.8689
# Epoch [4/30], Validation Accuracy: 0.8290, Validation Loss: 0.2836
# Epoch [4/30], Step [30/67], Train Loss: 0.2431
# Epoch [4/30], Train Accuracy: 0.8655
# Epoch [4/30], Validation Accuracy: 0.8145, Validation Loss: 0.2819
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [4/30], Step [40/67], Train Loss: 0.2686
# Epoch [4/30], Train Accuracy: 0.8669
# Epoch [4/30], Validation Accuracy: 0.8295, Validation Loss: 0.2867
# Epoch [4/30], Step [50/67], Train Loss: 0.2768
# Epoch [4/30], Train Accuracy: 0.8655
# Epoch [4/30], Validation Accuracy: 0.8229, Validation Loss: 0.2799
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [4/30], Step [60/67], Train Loss: 0.2815
# Epoch [4/30], Train Accuracy: 0.8662
# Epoch [4/30], Validation Accuracy: 0.8304, Validation Loss: 0.2733
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [4/30], Step [67/67], Train Loss: 0.2709
# Epoch [4/30], Train Accuracy: 0.8655
# Epoch [4/30], Validation Accuracy: 0.8336, Validation Loss: 0.2728
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [5/30], Step [10/67], Train Loss: 0.2355
# Epoch [5/30], Train Accuracy: 0.8836
# Epoch [5/30], Validation Accuracy: 0.8285, Validation Loss: 0.2719
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [5/30], Step [20/67], Train Loss: 0.2501
# Epoch [5/30], Train Accuracy: 0.8807
# Epoch [5/30], Validation Accuracy: 0.8341, Validation Loss: 0.2728
# Epoch [5/30], Step [30/67], Train Loss: 0.2305
# Epoch [5/30], Train Accuracy: 0.8764
# Epoch [5/30], Validation Accuracy: 0.8215, Validation Loss: 0.2723
# Epoch [5/30], Step [40/67], Train Loss: 0.2598
# Epoch [5/30], Train Accuracy: 0.8765
# Epoch [5/30], Validation Accuracy: 0.8327, Validation Loss: 0.2781
# Epoch [5/30], Step [50/67], Train Loss: 0.2622
# Epoch [5/30], Train Accuracy: 0.8741
# Epoch [5/30], Validation Accuracy: 0.8285, Validation Loss: 0.2704
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [5/30], Step [60/67], Train Loss: 0.2742
# Epoch [5/30], Train Accuracy: 0.8737
# Epoch [5/30], Validation Accuracy: 0.8355, Validation Loss: 0.2648
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [5/30], Step [67/67], Train Loss: 0.2716
# Epoch [5/30], Train Accuracy: 0.8725
# Epoch [5/30], Validation Accuracy: 0.8392, Validation Loss: 0.2676
# Epoch [6/30], Step [10/67], Train Loss: 0.2237
# Epoch [6/30], Train Accuracy: 0.8914
# Epoch [6/30], Validation Accuracy: 0.8341, Validation Loss: 0.2640
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [6/30], Step [20/67], Train Loss: 0.2401
# Epoch [6/30], Train Accuracy: 0.8885
# Epoch [6/30], Validation Accuracy: 0.8392, Validation Loss: 0.2654
# Epoch [6/30], Step [30/67], Train Loss: 0.2212
# Epoch [6/30], Train Accuracy: 0.8833
# Epoch [6/30], Validation Accuracy: 0.8267, Validation Loss: 0.2658
# Epoch [6/30], Step [40/67], Train Loss: 0.2498
# Epoch [6/30], Train Accuracy: 0.8838
# Epoch [6/30], Validation Accuracy: 0.8388, Validation Loss: 0.2711
# Epoch [6/30], Step [50/67], Train Loss: 0.2499
# Epoch [6/30], Train Accuracy: 0.8817
# Epoch [6/30], Validation Accuracy: 0.8350, Validation Loss: 0.2631
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [6/30], Step [60/67], Train Loss: 0.2665
# Epoch [6/30], Train Accuracy: 0.8808
# Epoch [6/30], Validation Accuracy: 0.8402, Validation Loss: 0.2585
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [6/30], Step [67/67], Train Loss: 0.2523
# Epoch [6/30], Train Accuracy: 0.8797
# Epoch [6/30], Validation Accuracy: 0.8420, Validation Loss: 0.2583
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [7/30], Step [10/67], Train Loss: 0.2131
# Epoch [7/30], Train Accuracy: 0.8953
# Epoch [7/30], Validation Accuracy: 0.8388, Validation Loss: 0.2586
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [7/30], Step [20/67], Train Loss: 0.2307
# Epoch [7/30], Train Accuracy: 0.8936
# Epoch [7/30], Validation Accuracy: 0.8434, Validation Loss: 0.2594
# Epoch [7/30], Step [30/67], Train Loss: 0.2093
# Epoch [7/30], Train Accuracy: 0.8885
# Epoch [7/30], Validation Accuracy: 0.8332, Validation Loss: 0.2610
# Epoch [7/30], Step [40/67], Train Loss: 0.2405
# Epoch [7/30], Train Accuracy: 0.8891
# Epoch [7/30], Validation Accuracy: 0.8416, Validation Loss: 0.2652
# Epoch [7/30], Step [50/67], Train Loss: 0.2387
# Epoch [7/30], Train Accuracy: 0.8867
# Epoch [7/30], Validation Accuracy: 0.8411, Validation Loss: 0.2584
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [7/30], Step [60/67], Train Loss: 0.2598
# Epoch [7/30], Train Accuracy: 0.8865
# Epoch [7/30], Validation Accuracy: 0.8420, Validation Loss: 0.2544
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [7/30], Step [67/67], Train Loss: 0.2424
# Epoch [7/30], Train Accuracy: 0.8854
# Epoch [7/30], Validation Accuracy: 0.8448, Validation Loss: 0.2529
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [8/30], Step [10/67], Train Loss: 0.2042
# Epoch [8/30], Train Accuracy: 0.8996
# Epoch [8/30], Validation Accuracy: 0.8416, Validation Loss: 0.2548
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [8/30], Step [20/67], Train Loss: 0.2231
# Epoch [8/30], Train Accuracy: 0.8979
# Epoch [8/30], Validation Accuracy: 0.8411, Validation Loss: 0.2559
# Epoch [8/30], Step [30/67], Train Loss: 0.1992
# Epoch [8/30], Train Accuracy: 0.8930
# Epoch [8/30], Validation Accuracy: 0.8355, Validation Loss: 0.2573
# Epoch [8/30], Step [40/67], Train Loss: 0.2315
# Epoch [8/30], Train Accuracy: 0.8944
# Epoch [8/30], Validation Accuracy: 0.8448, Validation Loss: 0.2604
# Epoch [8/30], Step [50/67], Train Loss: 0.2291
# Epoch [8/30], Train Accuracy: 0.8923
# Epoch [8/30], Validation Accuracy: 0.8425, Validation Loss: 0.2546
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [8/30], Step [60/67], Train Loss: 0.2526
# Epoch [8/30], Train Accuracy: 0.8915
# Epoch [8/30], Validation Accuracy: 0.8448, Validation Loss: 0.2512
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [8/30], Step [67/67], Train Loss: 0.2291
# Epoch [8/30], Train Accuracy: 0.8898
# Epoch [8/30], Validation Accuracy: 0.8439, Validation Loss: 0.2539
# Epoch [9/30], Step [10/67], Train Loss: 0.1960
# Epoch [9/30], Train Accuracy: 0.9039
# Epoch [9/30], Validation Accuracy: 0.8420, Validation Loss: 0.2535
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [9/30], Step [20/67], Train Loss: 0.2165
# Epoch [9/30], Train Accuracy: 0.9020
# Epoch [9/30], Validation Accuracy: 0.8458, Validation Loss: 0.2551
# Epoch [9/30], Step [30/67], Train Loss: 0.1914
# Epoch [9/30], Train Accuracy: 0.8964
# Epoch [9/30], Validation Accuracy: 0.8416, Validation Loss: 0.2547
# Epoch [9/30], Step [40/67], Train Loss: 0.2231
# Epoch [9/30], Train Accuracy: 0.8976
# Epoch [9/30], Validation Accuracy: 0.8490, Validation Loss: 0.2559
# Epoch [9/30], Step [50/67], Train Loss: 0.2204
# Epoch [9/30], Train Accuracy: 0.8959
# Epoch [9/30], Validation Accuracy: 0.8462, Validation Loss: 0.2518
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [9/30], Step [60/67], Train Loss: 0.2473
# Epoch [9/30], Train Accuracy: 0.8952
# Epoch [9/30], Validation Accuracy: 0.8467, Validation Loss: 0.2505
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [9/30], Step [67/67], Train Loss: 0.2729
# Epoch [9/30], Train Accuracy: 0.8929
# Epoch [9/30], Validation Accuracy: 0.8332, Validation Loss: 0.2664
# Epoch [10/30], Step [10/67], Train Loss: 0.1895
# Epoch [10/30], Train Accuracy: 0.9133
# Epoch [10/30], Validation Accuracy: 0.8472, Validation Loss: 0.2516
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [10/30], Step [20/67], Train Loss: 0.2175
# Epoch [10/30], Train Accuracy: 0.9070
# Epoch [10/30], Validation Accuracy: 0.8397, Validation Loss: 0.2659
# Epoch [10/30], Step [30/67], Train Loss: 0.1814
# Epoch [10/30], Train Accuracy: 0.9018
# Epoch [10/30], Validation Accuracy: 0.8448, Validation Loss: 0.2522
# Epoch [10/30], Step [40/67], Train Loss: 0.2161
# Epoch [10/30], Train Accuracy: 0.9037
# Epoch [10/30], Validation Accuracy: 0.8504, Validation Loss: 0.2542
# Epoch [10/30], Step [50/67], Train Loss: 0.2127
# Epoch [10/30], Train Accuracy: 0.9020
# Epoch [10/30], Validation Accuracy: 0.8453, Validation Loss: 0.2510
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [10/30], Step [60/67], Train Loss: 0.2518
# Epoch [10/30], Train Accuracy: 0.9011
# Epoch [10/30], Validation Accuracy: 0.8416, Validation Loss: 0.2559
# Epoch [10/30], Step [67/67], Train Loss: 0.2567
# Epoch [10/30], Train Accuracy: 0.8984
# Epoch [10/30], Validation Accuracy: 0.8444, Validation Loss: 0.2591
# Epoch [11/30], Step [10/67], Train Loss: 0.1824
# Epoch [11/30], Train Accuracy: 0.9172
# Epoch [11/30], Validation Accuracy: 0.8495, Validation Loss: 0.2503
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [11/30], Step [20/67], Train Loss: 0.2034
# Epoch [11/30], Train Accuracy: 0.9125
# Epoch [11/30], Validation Accuracy: 0.8444, Validation Loss: 0.2543
# Epoch [11/30], Step [30/67], Train Loss: 0.1760
# Epoch [11/30], Train Accuracy: 0.9069
# Epoch [11/30], Validation Accuracy: 0.8444, Validation Loss: 0.2528
# Epoch [11/30], Step [40/67], Train Loss: 0.2080
# Epoch [11/30], Train Accuracy: 0.9091
# Epoch [11/30], Validation Accuracy: 0.8537, Validation Loss: 0.2528
# Epoch [11/30], Step [50/67], Train Loss: 0.2039
# Epoch [11/30], Train Accuracy: 0.9070
# Epoch [11/30], Validation Accuracy: 0.8472, Validation Loss: 0.2492
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [11/30], Step [60/67], Train Loss: 0.2391
# Epoch [11/30], Train Accuracy: 0.9054
# Epoch [11/30], Validation Accuracy: 0.8495, Validation Loss: 0.2506
# Epoch [11/30], Step [67/67], Train Loss: 0.2039
# Epoch [11/30], Train Accuracy: 0.9037
# Epoch [11/30], Validation Accuracy: 0.8439, Validation Loss: 0.2541
# Epoch [12/30], Step [10/67], Train Loss: 0.1754
# Epoch [12/30], Train Accuracy: 0.9152
# Epoch [12/30], Validation Accuracy: 0.8504, Validation Loss: 0.2499
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [12/30], Step [20/67], Train Loss: 0.1912
# Epoch [12/30], Train Accuracy: 0.9129
# Epoch [12/30], Validation Accuracy: 0.8495, Validation Loss: 0.2469
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [12/30], Step [30/67], Train Loss: 0.1727
# Epoch [12/30], Train Accuracy: 0.9081
# Epoch [12/30], Validation Accuracy: 0.8411, Validation Loss: 0.2539
# Epoch [12/30], Step [40/67], Train Loss: 0.1999
# Epoch [12/30], Train Accuracy: 0.9108
# Epoch [12/30], Validation Accuracy: 0.8541, Validation Loss: 0.2515
# Epoch [12/30], Step [50/67], Train Loss: 0.1961
# Epoch [12/30], Train Accuracy: 0.9091
# Epoch [12/30], Validation Accuracy: 0.8500, Validation Loss: 0.2487
# Epoch [12/30], Step [60/67], Train Loss: 0.2328
# Epoch [12/30], Train Accuracy: 0.9071
# Epoch [12/30], Validation Accuracy: 0.8518, Validation Loss: 0.2512
# Epoch [12/30], Step [67/67], Train Loss: 0.1989
# Epoch [12/30], Train Accuracy: 0.9053
# Epoch [12/30], Validation Accuracy: 0.8481, Validation Loss: 0.2490
# Epoch [13/30], Step [10/67], Train Loss: 0.1770
# Epoch [13/30], Train Accuracy: 0.9234
# Epoch [13/30], Validation Accuracy: 0.8383, Validation Loss: 0.2650
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [13/30], Step [20/67], Train Loss: 0.2004
# Epoch [13/30], Train Accuracy: 0.9166
# Epoch [13/30], Validation Accuracy: 0.8369, Validation Loss: 0.2710
# Epoch [13/30], Step [30/67], Train Loss: 0.1572
# Epoch [13/30], Train Accuracy: 0.9111
# Epoch [13/30], Validation Accuracy: 0.8458, Validation Loss: 0.2514
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [13/30], Step [40/67], Train Loss: 0.1950
# Epoch [13/30], Train Accuracy: 0.9143
# Epoch [13/30], Validation Accuracy: 0.8537, Validation Loss: 0.2515
# Epoch [13/30], Step [50/67], Train Loss: 0.1931
# Epoch [13/30], Train Accuracy: 0.9128
# Epoch [13/30], Validation Accuracy: 0.8434, Validation Loss: 0.2570
# Epoch [13/30], Step [60/67], Train Loss: 0.2434
# Epoch [13/30], Train Accuracy: 0.9113
# Epoch [13/30], Validation Accuracy: 0.8500, Validation Loss: 0.2546
# Epoch [13/30], Step [67/67], Train Loss: 0.1808
# Epoch [13/30], Train Accuracy: 0.9102
# Epoch [13/30], Validation Accuracy: 0.8467, Validation Loss: 0.2535
# Epoch [14/30], Step [10/67], Train Loss: 0.1627
# Epoch [14/30], Train Accuracy: 0.9238
# Epoch [14/30], Validation Accuracy: 0.8518, Validation Loss: 0.2508
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [14/30], Step [20/67], Train Loss: 0.1749
# Epoch [14/30], Train Accuracy: 0.9203
# Epoch [14/30], Validation Accuracy: 0.8495, Validation Loss: 0.2466
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [14/30], Step [30/67], Train Loss: 0.1615
# Epoch [14/30], Train Accuracy: 0.9137
# Epoch [14/30], Validation Accuracy: 0.8439, Validation Loss: 0.2531
# Epoch [14/30], Step [40/67], Train Loss: 0.1880
# Epoch [14/30], Train Accuracy: 0.9167
# Epoch [14/30], Validation Accuracy: 0.8514, Validation Loss: 0.2510
# Epoch [14/30], Step [50/67], Train Loss: 0.1804
# Epoch [14/30], Train Accuracy: 0.9162
# Epoch [14/30], Validation Accuracy: 0.8504, Validation Loss: 0.2520
# Epoch [14/30], Step [60/67], Train Loss: 0.2263
# Epoch [14/30], Train Accuracy: 0.9153
# Epoch [14/30], Validation Accuracy: 0.8523, Validation Loss: 0.2513
# Epoch [14/30], Step [67/67], Train Loss: 0.1944
# Epoch [14/30], Train Accuracy: 0.9137
# Epoch [14/30], Validation Accuracy: 0.8075, Validation Loss: 0.2907
# Epoch [15/30], Step [10/67], Train Loss: 0.1558
# Epoch [15/30], Train Accuracy: 0.9254
# Epoch [15/30], Validation Accuracy: 0.8514, Validation Loss: 0.2514
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [15/30], Step [20/67], Train Loss: 0.1655
# Epoch [15/30], Train Accuracy: 0.9244
# Epoch [15/30], Validation Accuracy: 0.8490, Validation Loss: 0.2468
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [15/30], Step [30/67], Train Loss: 0.1457
# Epoch [15/30], Train Accuracy: 0.9227
# Epoch [15/30], Validation Accuracy: 0.8388, Validation Loss: 0.2587
# Epoch [15/30], Step [40/67], Train Loss: 0.1832
# Epoch [15/30], Train Accuracy: 0.9232
# Epoch [15/30], Validation Accuracy: 0.8514, Validation Loss: 0.2523
# Epoch [15/30], Step [50/67], Train Loss: 0.1693
# Epoch [15/30], Train Accuracy: 0.9219
# Epoch [15/30], Validation Accuracy: 0.8514, Validation Loss: 0.2487
# Epoch [15/30], Step [60/67], Train Loss: 0.2140
# Epoch [15/30], Train Accuracy: 0.9196
# Epoch [15/30], Validation Accuracy: 0.8514, Validation Loss: 0.2514
# Epoch [15/30], Step [67/67], Train Loss: 0.1769
# Epoch [15/30], Train Accuracy: 0.9179
# Epoch [15/30], Validation Accuracy: 0.8248, Validation Loss: 0.2795
# Epoch [16/30], Step [10/67], Train Loss: 0.1511
# Epoch [16/30], Train Accuracy: 0.9320
# Epoch [16/30], Validation Accuracy: 0.8504, Validation Loss: 0.2560
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [16/30], Step [20/67], Train Loss: 0.1815
# Epoch [16/30], Train Accuracy: 0.9287
# Epoch [16/30], Validation Accuracy: 0.8332, Validation Loss: 0.2870
# Epoch [16/30], Step [30/67], Train Loss: 0.1336
# Epoch [16/30], Train Accuracy: 0.9254
# Epoch [16/30], Validation Accuracy: 0.8481, Validation Loss: 0.2532
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [16/30], Step [40/67], Train Loss: 0.1749
# Epoch [16/30], Train Accuracy: 0.9270
# Epoch [16/30], Validation Accuracy: 0.8514, Validation Loss: 0.2521
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [16/30], Step [50/67], Train Loss: 0.1700
# Epoch [16/30], Train Accuracy: 0.9263
# Epoch [16/30], Validation Accuracy: 0.8430, Validation Loss: 0.2607
# Epoch [16/30], Step [60/67], Train Loss: 0.2230
# Epoch [16/30], Train Accuracy: 0.9248
# Epoch [16/30], Validation Accuracy: 0.8434, Validation Loss: 0.2616
# Epoch [16/30], Step [67/67], Train Loss: 0.1589
# Epoch [16/30], Train Accuracy: 0.9232
# Epoch [16/30], Validation Accuracy: 0.8425, Validation Loss: 0.2592
# Epoch [17/30], Step [10/67], Train Loss: 0.1477
# Epoch [17/30], Train Accuracy: 0.9391
# Epoch [17/30], Validation Accuracy: 0.8462, Validation Loss: 0.2581
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [17/30], Step [20/67], Train Loss: 0.1522
# Epoch [17/30], Train Accuracy: 0.9371
# Epoch [17/30], Validation Accuracy: 0.8486, Validation Loss: 0.2563
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [17/30], Step [30/67], Train Loss: 0.1527
# Epoch [17/30], Train Accuracy: 0.9314
# Epoch [17/30], Validation Accuracy: 0.8360, Validation Loss: 0.2652
# Epoch [17/30], Step [40/67], Train Loss: 0.1551
# Epoch [17/30], Train Accuracy: 0.9338
# Epoch [17/30], Validation Accuracy: 0.8500, Validation Loss: 0.2511
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [17/30], Step [50/67], Train Loss: 0.1544
# Epoch [17/30], Train Accuracy: 0.9337
# Epoch [17/30], Validation Accuracy: 0.8350, Validation Loss: 0.2623
# Epoch [17/30], Step [60/67], Train Loss: 0.2018
# Epoch [17/30], Train Accuracy: 0.9326
# Epoch [17/30], Validation Accuracy: 0.8332, Validation Loss: 0.2716
# Epoch [17/30], Step [67/67], Train Loss: 0.2319
# Epoch [17/30], Train Accuracy: 0.9299
# Epoch [17/30], Validation Accuracy: 0.8103, Validation Loss: 0.3051
# Epoch [18/30], Step [10/67], Train Loss: 0.1356
# Epoch [18/30], Train Accuracy: 0.9402
# Epoch [18/30], Validation Accuracy: 0.8490, Validation Loss: 0.2554
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [18/30], Step [20/67], Train Loss: 0.1376
# Epoch [18/30], Train Accuracy: 0.9393
# Epoch [18/30], Validation Accuracy: 0.8504, Validation Loss: 0.2544
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [18/30], Step [30/67], Train Loss: 0.1236
# Epoch [18/30], Train Accuracy: 0.9357
# Epoch [18/30], Validation Accuracy: 0.8430, Validation Loss: 0.2576
# Epoch [18/30], Step [40/67], Train Loss: 0.1564
# Epoch [18/30], Train Accuracy: 0.9354
# Epoch [18/30], Validation Accuracy: 0.8472, Validation Loss: 0.2560
# Epoch [18/30], Step [50/67], Train Loss: 0.1415
# Epoch [18/30], Train Accuracy: 0.9352
# Epoch [18/30], Validation Accuracy: 0.8486, Validation Loss: 0.2555
# Epoch [18/30], Step [60/67], Train Loss: 0.2019
# Epoch [18/30], Train Accuracy: 0.9328
# Epoch [18/30], Validation Accuracy: 0.8476, Validation Loss: 0.2627
# Epoch [18/30], Step [67/67], Train Loss: 0.1394
# Epoch [18/30], Train Accuracy: 0.9308
# Epoch [18/30], Validation Accuracy: 0.8308, Validation Loss: 0.2737
# Epoch [19/30], Step [10/67], Train Loss: 0.1301
# Epoch [19/30], Train Accuracy: 0.9410
# Epoch [19/30], Validation Accuracy: 0.8411, Validation Loss: 0.2634
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [19/30], Step [20/67], Train Loss: 0.1296
# Epoch [19/30], Train Accuracy: 0.9418
# Epoch [19/30], Validation Accuracy: 0.8495, Validation Loss: 0.2585
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [19/30], Step [30/67], Train Loss: 0.1134
# Epoch [19/30], Train Accuracy: 0.9405
# Epoch [19/30], Validation Accuracy: 0.8420, Validation Loss: 0.2637
# Epoch [19/30], Step [40/67], Train Loss: 0.1439
# Epoch [19/30], Train Accuracy: 0.9410
# Epoch [19/30], Validation Accuracy: 0.8546, Validation Loss: 0.2560
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [19/30], Step [50/67], Train Loss: 0.1418
# Epoch [19/30], Train Accuracy: 0.9405
# Epoch [19/30], Validation Accuracy: 0.8332, Validation Loss: 0.2710
# Epoch [19/30], Step [60/67], Train Loss: 0.1763
# Epoch [19/30], Train Accuracy: 0.9402
# Epoch [19/30], Validation Accuracy: 0.8434, Validation Loss: 0.2648
# Epoch [19/30], Step [67/67], Train Loss: 0.1570
# Epoch [19/30], Train Accuracy: 0.9374
# Epoch [19/30], Validation Accuracy: 0.8411, Validation Loss: 0.2715
# Epoch [20/30], Step [10/67], Train Loss: 0.1264
# Epoch [20/30], Train Accuracy: 0.9492
# Epoch [20/30], Validation Accuracy: 0.8383, Validation Loss: 0.2737
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [20/30], Step [20/67], Train Loss: 0.1417
# Epoch [20/30], Train Accuracy: 0.9420
# Epoch [20/30], Validation Accuracy: 0.8374, Validation Loss: 0.2756
# Epoch [20/30], Step [30/67], Train Loss: 0.1314
# Epoch [20/30], Train Accuracy: 0.9404
# Epoch [20/30], Validation Accuracy: 0.8322, Validation Loss: 0.2758
# Epoch [20/30], Step [40/67], Train Loss: 0.1424
# Epoch [20/30], Train Accuracy: 0.9432
# Epoch [20/30], Validation Accuracy: 0.8481, Validation Loss: 0.2721
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [20/30], Step [50/67], Train Loss: 0.1338
# Epoch [20/30], Train Accuracy: 0.9423
# Epoch [20/30], Validation Accuracy: 0.8304, Validation Loss: 0.2786
# Epoch [20/30], Step [60/67], Train Loss: 0.1964
# Epoch [20/30], Train Accuracy: 0.9418
# Epoch [20/30], Validation Accuracy: 0.8392, Validation Loss: 0.2808
# Epoch [20/30], Step [67/67], Train Loss: 0.1164
# Epoch [20/30], Train Accuracy: 0.9395
# Epoch [20/30], Validation Accuracy: 0.8444, Validation Loss: 0.2656
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [21/30], Step [10/67], Train Loss: 0.1108
# Epoch [21/30], Train Accuracy: 0.9605
# Epoch [21/30], Validation Accuracy: 0.8453, Validation Loss: 0.2671
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [21/30], Step [20/67], Train Loss: 0.1096
# Epoch [21/30], Train Accuracy: 0.9584
# Epoch [21/30], Validation Accuracy: 0.8472, Validation Loss: 0.2673
# Epoch [21/30], Step [30/67], Train Loss: 0.1138
# Epoch [21/30], Train Accuracy: 0.9516
# Epoch [21/30], Validation Accuracy: 0.8448, Validation Loss: 0.2706
# Epoch [21/30], Step [40/67], Train Loss: 0.1266
# Epoch [21/30], Train Accuracy: 0.9524
# Epoch [21/30], Validation Accuracy: 0.8378, Validation Loss: 0.2741
# Epoch [21/30], Step [50/67], Train Loss: 0.1165
# Epoch [21/30], Train Accuracy: 0.9513
# Epoch [21/30], Validation Accuracy: 0.8350, Validation Loss: 0.2774
# Epoch [21/30], Step [60/67], Train Loss: 0.1739
# Epoch [21/30], Train Accuracy: 0.9495
# Epoch [21/30], Validation Accuracy: 0.8406, Validation Loss: 0.2804
# Epoch [21/30], Step [67/67], Train Loss: 0.1722
# Epoch [21/30], Train Accuracy: 0.9465
# Epoch [21/30], Validation Accuracy: 0.8192, Validation Loss: 0.3070
# Epoch [22/30], Step [10/67], Train Loss: 0.1030
# Epoch [22/30], Train Accuracy: 0.9621
# Epoch [22/30], Validation Accuracy: 0.8383, Validation Loss: 0.2725
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [22/30], Step [20/67], Train Loss: 0.1025
# Epoch [22/30], Train Accuracy: 0.9623
# Epoch [22/30], Validation Accuracy: 0.8439, Validation Loss: 0.2729
# Epoch [22/30], Step [30/67], Train Loss: 0.1113
# Epoch [22/30], Train Accuracy: 0.9586
# Epoch [22/30], Validation Accuracy: 0.8299, Validation Loss: 0.2867
# Epoch [22/30], Step [40/67], Train Loss: 0.1143
# Epoch [22/30], Train Accuracy: 0.9586
# Epoch [22/30], Validation Accuracy: 0.8420, Validation Loss: 0.2689
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [22/30], Step [50/67], Train Loss: 0.1095
# Epoch [22/30], Train Accuracy: 0.9586
# Epoch [22/30], Validation Accuracy: 0.8304, Validation Loss: 0.2868
# Epoch [22/30], Step [60/67], Train Loss: 0.1487
# Epoch [22/30], Train Accuracy: 0.9574
# Epoch [22/30], Validation Accuracy: 0.8378, Validation Loss: 0.2783
# Epoch [22/30], Step [67/67], Train Loss: 0.1603
# Epoch [22/30], Train Accuracy: 0.9545
# Epoch [22/30], Validation Accuracy: 0.8295, Validation Loss: 0.2907
# Epoch [23/30], Step [10/67], Train Loss: 0.0962
# Epoch [23/30], Train Accuracy: 0.9648
# Epoch [23/30], Validation Accuracy: 0.8360, Validation Loss: 0.2803
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [23/30], Step [20/67], Train Loss: 0.1108
# Epoch [23/30], Train Accuracy: 0.9648
# Epoch [23/30], Validation Accuracy: 0.8267, Validation Loss: 0.2961
# Epoch [23/30], Step [30/67], Train Loss: 0.0907
# Epoch [23/30], Train Accuracy: 0.9626
# Epoch [23/30], Validation Accuracy: 0.8397, Validation Loss: 0.2826
# Epoch [23/30], Step [40/67], Train Loss: 0.1119
# Epoch [23/30], Train Accuracy: 0.9626
# Epoch [23/30], Validation Accuracy: 0.8336, Validation Loss: 0.2869
# Epoch [23/30], Step [50/67], Train Loss: 0.1063
# Epoch [23/30], Train Accuracy: 0.9624
# Epoch [23/30], Validation Accuracy: 0.8136, Validation Loss: 0.3048
# Epoch [23/30], Step [60/67], Train Loss: 0.1622
# Epoch [23/30], Train Accuracy: 0.9609
# Epoch [23/30], Validation Accuracy: 0.8299, Validation Loss: 0.2877
# Epoch [23/30], Step [67/67], Train Loss: 0.0973
# Epoch [23/30], Train Accuracy: 0.9586
# Epoch [23/30], Validation Accuracy: 0.8308, Validation Loss: 0.2954
# Epoch [24/30], Step [10/67], Train Loss: 0.0914
# Epoch [24/30], Train Accuracy: 0.9707
# Epoch [24/30], Validation Accuracy: 0.8248, Validation Loss: 0.2924
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [24/30], Step [20/67], Train Loss: 0.0867
# Epoch [24/30], Train Accuracy: 0.9701
# Epoch [24/30], Validation Accuracy: 0.8346, Validation Loss: 0.2876
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [24/30], Step [30/67], Train Loss: 0.0790
# Epoch [24/30], Train Accuracy: 0.9648
# Epoch [24/30], Validation Accuracy: 0.8364, Validation Loss: 0.2815
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [24/30], Step [40/67], Train Loss: 0.1269
# Epoch [24/30], Train Accuracy: 0.9653
# Epoch [24/30], Validation Accuracy: 0.8416, Validation Loss: 0.2805
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [24/30], Step [50/67], Train Loss: 0.0967
# Epoch [24/30], Train Accuracy: 0.9643
# Epoch [24/30], Validation Accuracy: 0.8308, Validation Loss: 0.2893
# Epoch [24/30], Step [60/67], Train Loss: 0.1496
# Epoch [24/30], Train Accuracy: 0.9636
# Epoch [24/30], Validation Accuracy: 0.8262, Validation Loss: 0.3258
# Epoch [24/30], Step [67/67], Train Loss: 0.1253
# Epoch [24/30], Train Accuracy: 0.9601
# Epoch [24/30], Validation Accuracy: 0.8295, Validation Loss: 0.3067
# Epoch [25/30], Step [10/67], Train Loss: 0.0848
# Epoch [25/30], Train Accuracy: 0.9738
# Epoch [25/30], Validation Accuracy: 0.8388, Validation Loss: 0.2916
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [25/30], Step [20/67], Train Loss: 0.0804
# Epoch [25/30], Train Accuracy: 0.9662
# Epoch [25/30], Validation Accuracy: 0.8364, Validation Loss: 0.2875
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [25/30], Step [30/67], Train Loss: 0.0796
# Epoch [25/30], Train Accuracy: 0.9654
# Epoch [25/30], Validation Accuracy: 0.8350, Validation Loss: 0.2936
# Epoch [25/30], Step [40/67], Train Loss: 0.0820
# Epoch [25/30], Train Accuracy: 0.9677
# Epoch [25/30], Validation Accuracy: 0.8392, Validation Loss: 0.2875
# Epoch [25/30], Step [50/67], Train Loss: 0.1045
# Epoch [25/30], Train Accuracy: 0.9666
# Epoch [25/30], Validation Accuracy: 0.8239, Validation Loss: 0.3270
# Epoch [25/30], Step [60/67], Train Loss: 0.1269
# Epoch [25/30], Train Accuracy: 0.9667
# Epoch [25/30], Validation Accuracy: 0.8080, Validation Loss: 0.3144
# Epoch [25/30], Step [67/67], Train Loss: 0.0751
# Epoch [25/30], Train Accuracy: 0.9655
# Epoch [25/30], Validation Accuracy: 0.8304, Validation Loss: 0.2989
# Epoch [26/30], Step [10/67], Train Loss: 0.0712
# Epoch [26/30], Train Accuracy: 0.9809
# Epoch [26/30], Validation Accuracy: 0.8271, Validation Loss: 0.3010
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [26/30], Step [20/67], Train Loss: 0.0686
# Epoch [26/30], Train Accuracy: 0.9799
# Epoch [26/30], Validation Accuracy: 0.8299, Validation Loss: 0.3015
# Epoch [26/30], Step [30/67], Train Loss: 0.0946
# Epoch [26/30], Train Accuracy: 0.9753
# Epoch [26/30], Validation Accuracy: 0.8211, Validation Loss: 0.3052
# Epoch [26/30], Step [40/67], Train Loss: 0.0790
# Epoch [26/30], Train Accuracy: 0.9748
# Epoch [26/30], Validation Accuracy: 0.8322, Validation Loss: 0.2956
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [26/30], Step [50/67], Train Loss: 0.1346
# Epoch [26/30], Train Accuracy: 0.9727
# Epoch [26/30], Validation Accuracy: 0.8010, Validation Loss: 0.3280
# Epoch [26/30], Step [60/67], Train Loss: 0.1114
# Epoch [26/30], Train Accuracy: 0.9726
# Epoch [26/30], Validation Accuracy: 0.8308, Validation Loss: 0.3077
# Epoch [26/30], Step [67/67], Train Loss: 0.0983
# Epoch [26/30], Train Accuracy: 0.9697
# Epoch [26/30], Validation Accuracy: 0.8290, Validation Loss: 0.3082
# Epoch [27/30], Step [10/67], Train Loss: 0.0662
# Epoch [27/30], Train Accuracy: 0.9809
# Epoch [27/30], Validation Accuracy: 0.8313, Validation Loss: 0.3003
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [27/30], Step [20/67], Train Loss: 0.0981
# Epoch [27/30], Train Accuracy: 0.9777
# Epoch [27/30], Validation Accuracy: 0.8220, Validation Loss: 0.3311
# Epoch [27/30], Step [30/67], Train Loss: 0.0615
# Epoch [27/30], Train Accuracy: 0.9770
# Epoch [27/30], Validation Accuracy: 0.8276, Validation Loss: 0.3037
# Epoch [27/30], Step [40/67], Train Loss: 0.0701
# Epoch [27/30], Train Accuracy: 0.9783
# Epoch [27/30], Validation Accuracy: 0.8318, Validation Loss: 0.2976
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [27/30], Step [50/67], Train Loss: 0.0787
# Epoch [27/30], Train Accuracy: 0.9764
# Epoch [27/30], Validation Accuracy: 0.8313, Validation Loss: 0.3028
# Epoch [27/30], Step [60/67], Train Loss: 0.0819
# Epoch [27/30], Train Accuracy: 0.9770
# Epoch [27/30], Validation Accuracy: 0.8299, Validation Loss: 0.3102
# Epoch [27/30], Step [67/67], Train Loss: 0.1114
# Epoch [27/30], Train Accuracy: 0.9740
# Epoch [27/30], Validation Accuracy: 0.8089, Validation Loss: 0.3759
# Epoch [28/30], Step [10/67], Train Loss: 0.0614
# Epoch [28/30], Train Accuracy: 0.9840
# Epoch [28/30], Validation Accuracy: 0.8215, Validation Loss: 0.3159
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [28/30], Step [20/67], Train Loss: 0.0655
# Epoch [28/30], Train Accuracy: 0.9832
# Epoch [28/30], Validation Accuracy: 0.8094, Validation Loss: 0.3340
# Epoch [28/30], Step [30/67], Train Loss: 0.0555
# Epoch [28/30], Train Accuracy: 0.9786
# Epoch [28/30], Validation Accuracy: 0.8229, Validation Loss: 0.3101
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [28/30], Step [40/67], Train Loss: 0.0836
# Epoch [28/30], Train Accuracy: 0.9801
# Epoch [28/30], Validation Accuracy: 0.8239, Validation Loss: 0.3186
# Epoch [28/30], Step [50/67], Train Loss: 0.0676
# Epoch [28/30], Train Accuracy: 0.9805
# Epoch [28/30], Validation Accuracy: 0.8201, Validation Loss: 0.3173
# Epoch [28/30], Step [60/67], Train Loss: 0.0833
# Epoch [28/30], Train Accuracy: 0.9809
# Epoch [28/30], Validation Accuracy: 0.8159, Validation Loss: 0.3308
# Epoch [28/30], Step [67/67], Train Loss: 0.1096
# Epoch [28/30], Train Accuracy: 0.9776
# Epoch [28/30], Validation Accuracy: 0.8295, Validation Loss: 0.3254
# Epoch [29/30], Step [10/67], Train Loss: 0.0627
# Epoch [29/30], Train Accuracy: 0.9848
# Epoch [29/30], Validation Accuracy: 0.8295, Validation Loss: 0.3187
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [29/30], Step [20/67], Train Loss: 0.0532
# Epoch [29/30], Train Accuracy: 0.9852
# Epoch [29/30], Validation Accuracy: 0.8253, Validation Loss: 0.3196
# Epoch [29/30], Step [30/67], Train Loss: 0.0558
# Epoch [29/30], Train Accuracy: 0.9844
# Epoch [29/30], Validation Accuracy: 0.8234, Validation Loss: 0.3228
# Epoch [29/30], Step [40/67], Train Loss: 0.0564
# Epoch [29/30], Train Accuracy: 0.9857
# Epoch [29/30], Validation Accuracy: 0.8295, Validation Loss: 0.3129
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [29/30], Step [50/67], Train Loss: 0.0680
# Epoch [29/30], Train Accuracy: 0.9849
# Epoch [29/30], Validation Accuracy: 0.8206, Validation Loss: 0.3338
# Epoch [29/30], Step [60/67], Train Loss: 0.0694
# Epoch [29/30], Train Accuracy: 0.9851
# Epoch [29/30], Validation Accuracy: 0.8117, Validation Loss: 0.3411
# Epoch [29/30], Step [67/67], Train Loss: 0.0491
# Epoch [29/30], Train Accuracy: 0.9832
# Epoch [29/30], Validation Accuracy: 0.8299, Validation Loss: 0.3170
# Epoch [30/30], Step [10/67], Train Loss: 0.0569
# Epoch [30/30], Train Accuracy: 0.9906
# Epoch [30/30], Validation Accuracy: 0.7996, Validation Loss: 0.3621
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [30/30], Step [20/67], Train Loss: 0.0483
# Epoch [30/30], Train Accuracy: 0.9795
# Epoch [30/30], Validation Accuracy: 0.8192, Validation Loss: 0.3226
# Model saved to ==> ./model_saves/model_MMCNN_SUM_epoch_30.pt
# Epoch [30/30], Step [30/67], Train Loss: 0.0420
# Epoch [30/30], Train Accuracy: 0.9831
# Epoch [30/30], Validation Accuracy: 0.8206, Validation Loss: 0.3272
# Epoch [30/30], Step [40/67], Train Loss: 0.0712
# Epoch [30/30], Train Accuracy: 0.9848
# Epoch [30/30], Validation Accuracy: 0.8089, Validation Loss: 0.3574
# Epoch [30/30], Step [50/67], Train Loss: 0.0535
# Epoch [30/30], Train Accuracy: 0.9841
# Epoch [30/30], Validation Accuracy: 0.8308, Validation Loss: 0.3252
# Epoch [30/30], Step [60/67], Train Loss: 0.0826
# Epoch [30/30], Train Accuracy: 0.9848
# Epoch [30/30], Validation Accuracy: 0.8099, Validation Loss: 0.3493
# Epoch [30/30], Step [67/67], Train Loss: 0.0572
# Epoch [30/30], Train Accuracy: 0.9829
# Epoch [30/30], Validation Accuracy: 0.8262, Validation Loss: 0.3303
# Ended Training, Test Accuracy: 0.8336

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)

# %% [markdown]
# # Loading the Undersampled Dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    data, labels, y = undersample(data, labels, y)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)
# Out:
# Start loading
# done loading
# c:\Users\ptejd\Documents\Deep_Learning\Deep_Learning_ECGclassification\preprocess\preprocess.py:93: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_cls'] = df['superdiagnostic'].apply(lambda x: cls in x)
# c:\Users\ptejd\Documents\Deep_Learning\Deep_Learning_ECGclassification\preprocess\preprocess.py:94: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['is_only_cls'] = df['superdiagnostic'].apply(

# %% [markdown]
# # Redefine Some Options

# %%
SAVE_DIR = './model_saves_undersampled/'

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = MMCNN_SUM().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
# cuda
# Epoch [1/30], Step [10/55], Train Loss: 0.5253
# Epoch [1/30], Train Accuracy: 0.5445
# Epoch [1/30], Validation Accuracy: 0.4679, Validation Loss: 0.6015
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [20/55], Train Loss: 0.4296
# Epoch [1/30], Train Accuracy: 0.6035
# Epoch [1/30], Validation Accuracy: 0.6885, Validation Loss: 0.4483
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [30/55], Train Loss: 0.3752
# Epoch [1/30], Train Accuracy: 0.6565
# Epoch [1/30], Validation Accuracy: 0.6983, Validation Loss: 0.4235
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [40/55], Train Loss: 0.3520
# Epoch [1/30], Train Accuracy: 0.6905
# Epoch [1/30], Validation Accuracy: 0.6960, Validation Loss: 0.4143
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [50/55], Train Loss: 0.3322
# Epoch [1/30], Train Accuracy: 0.7124
# Epoch [1/30], Validation Accuracy: 0.7481, Validation Loss: 0.3866
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [1/30], Step [55/55], Train Loss: 0.3422
# Epoch [1/30], Train Accuracy: 0.7175
# Epoch [1/30], Validation Accuracy: 0.7099, Validation Loss: 0.3965
# Epoch [2/30], Step [10/55], Train Loss: 0.4088
# Epoch [2/30], Train Accuracy: 0.7703
# Epoch [2/30], Validation Accuracy: 0.7556, Validation Loss: 0.3854
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [20/55], Train Loss: 0.3192
# Epoch [2/30], Train Accuracy: 0.7912
# Epoch [2/30], Validation Accuracy: 0.7713, Validation Loss: 0.3634
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [30/55], Train Loss: 0.3062
# Epoch [2/30], Train Accuracy: 0.8031
# Epoch [2/30], Validation Accuracy: 0.7603, Validation Loss: 0.3614
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [40/55], Train Loss: 0.3069
# Epoch [2/30], Train Accuracy: 0.8117
# Epoch [2/30], Validation Accuracy: 0.7597, Validation Loss: 0.3659
# Epoch [2/30], Step [50/55], Train Loss: 0.2699
# Epoch [2/30], Train Accuracy: 0.8171
# Epoch [2/30], Validation Accuracy: 0.7695, Validation Loss: 0.3570
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [2/30], Step [55/55], Train Loss: 0.3135
# Epoch [2/30], Train Accuracy: 0.8170
# Epoch [2/30], Validation Accuracy: 0.7701, Validation Loss: 0.3545
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [10/55], Train Loss: 0.3660
# Epoch [3/30], Train Accuracy: 0.8250
# Epoch [3/30], Validation Accuracy: 0.7892, Validation Loss: 0.3539
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [20/55], Train Loss: 0.2876
# Epoch [3/30], Train Accuracy: 0.8303
# Epoch [3/30], Validation Accuracy: 0.7991, Validation Loss: 0.3374
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [3/30], Step [30/55], Train Loss: 0.2804
# Epoch [3/30], Train Accuracy: 0.8333
# Epoch [3/30], Validation Accuracy: 0.7776, Validation Loss: 0.3389
# Epoch [3/30], Step [40/55], Train Loss: 0.2888
# Epoch [3/30], Train Accuracy: 0.8373
# Epoch [3/30], Validation Accuracy: 0.7887, Validation Loss: 0.3413
# Epoch [3/30], Step [50/55], Train Loss: 0.2479
# Epoch [3/30], Train Accuracy: 0.8390
# Epoch [3/30], Validation Accuracy: 0.7887, Validation Loss: 0.3376
# Epoch [3/30], Step [55/55], Train Loss: 0.2936
# Epoch [3/30], Train Accuracy: 0.8384
# Epoch [3/30], Validation Accuracy: 0.7892, Validation Loss: 0.3383
# Epoch [4/30], Step [10/55], Train Loss: 0.3430
# Epoch [4/30], Train Accuracy: 0.8402
# Epoch [4/30], Validation Accuracy: 0.8043, Validation Loss: 0.3389
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [4/30], Step [20/55], Train Loss: 0.2719
# Epoch [4/30], Train Accuracy: 0.8434
# Epoch [4/30], Validation Accuracy: 0.8083, Validation Loss: 0.3230
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [4/30], Step [30/55], Train Loss: 0.2657
# Epoch [4/30], Train Accuracy: 0.8456
# Epoch [4/30], Validation Accuracy: 0.7887, Validation Loss: 0.3266
# Epoch [4/30], Step [40/55], Train Loss: 0.2774
# Epoch [4/30], Train Accuracy: 0.8472
# Epoch [4/30], Validation Accuracy: 0.7962, Validation Loss: 0.3296
# Epoch [4/30], Step [50/55], Train Loss: 0.2350
# Epoch [4/30], Train Accuracy: 0.8484
# Epoch [4/30], Validation Accuracy: 0.7962, Validation Loss: 0.3237
# Epoch [4/30], Step [55/55], Train Loss: 0.2799
# Epoch [4/30], Train Accuracy: 0.8470
# Epoch [4/30], Validation Accuracy: 0.7997, Validation Loss: 0.3308
# Epoch [5/30], Step [10/55], Train Loss: 0.3270
# Epoch [5/30], Train Accuracy: 0.8516
# Epoch [5/30], Validation Accuracy: 0.8124, Validation Loss: 0.3282
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [5/30], Step [20/55], Train Loss: 0.2601
# Epoch [5/30], Train Accuracy: 0.8527
# Epoch [5/30], Validation Accuracy: 0.8135, Validation Loss: 0.3132
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [5/30], Step [30/55], Train Loss: 0.2548
# Epoch [5/30], Train Accuracy: 0.8547
# Epoch [5/30], Validation Accuracy: 0.7973, Validation Loss: 0.3179
# Epoch [5/30], Step [40/55], Train Loss: 0.2687
# Epoch [5/30], Train Accuracy: 0.8561
# Epoch [5/30], Validation Accuracy: 0.8066, Validation Loss: 0.3221
# Epoch [5/30], Step [50/55], Train Loss: 0.2254
# Epoch [5/30], Train Accuracy: 0.8568
# Epoch [5/30], Validation Accuracy: 0.8089, Validation Loss: 0.3147
# Epoch [5/30], Step [55/55], Train Loss: 0.2683
# Epoch [5/30], Train Accuracy: 0.8554
# Epoch [5/30], Validation Accuracy: 0.8054, Validation Loss: 0.3276
# Epoch [6/30], Step [10/55], Train Loss: 0.3147
# Epoch [6/30], Train Accuracy: 0.8602
# Epoch [6/30], Validation Accuracy: 0.8193, Validation Loss: 0.3201
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [6/30], Step [20/55], Train Loss: 0.2501
# Epoch [6/30], Train Accuracy: 0.8611
# Epoch [6/30], Validation Accuracy: 0.8193, Validation Loss: 0.3059
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [6/30], Step [30/55], Train Loss: 0.2462
# Epoch [6/30], Train Accuracy: 0.8615
# Epoch [6/30], Validation Accuracy: 0.8054, Validation Loss: 0.3115
# Epoch [6/30], Step [40/55], Train Loss: 0.2615
# Epoch [6/30], Train Accuracy: 0.8626
# Epoch [6/30], Validation Accuracy: 0.8124, Validation Loss: 0.3177
# Epoch [6/30], Step [50/55], Train Loss: 0.2183
# Epoch [6/30], Train Accuracy: 0.8634
# Epoch [6/30], Validation Accuracy: 0.8130, Validation Loss: 0.3094
# Epoch [6/30], Step [55/55], Train Loss: 0.2567
# Epoch [6/30], Train Accuracy: 0.8616
# Epoch [6/30], Validation Accuracy: 0.8135, Validation Loss: 0.3223
# Epoch [7/30], Step [10/55], Train Loss: 0.3040
# Epoch [7/30], Train Accuracy: 0.8691
# Epoch [7/30], Validation Accuracy: 0.8211, Validation Loss: 0.3146
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [7/30], Step [20/55], Train Loss: 0.2414
# Epoch [7/30], Train Accuracy: 0.8676
# Epoch [7/30], Validation Accuracy: 0.8228, Validation Loss: 0.3009
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [7/30], Step [30/55], Train Loss: 0.2380
# Epoch [7/30], Train Accuracy: 0.8667
# Epoch [7/30], Validation Accuracy: 0.8083, Validation Loss: 0.3067
# Epoch [7/30], Step [40/55], Train Loss: 0.2553
# Epoch [7/30], Train Accuracy: 0.8675
# Epoch [7/30], Validation Accuracy: 0.8164, Validation Loss: 0.3148
# Epoch [7/30], Step [50/55], Train Loss: 0.2122
# Epoch [7/30], Train Accuracy: 0.8689
# Epoch [7/30], Validation Accuracy: 0.8147, Validation Loss: 0.3059
# Epoch [7/30], Step [55/55], Train Loss: 0.2460
# Epoch [7/30], Train Accuracy: 0.8672
# Epoch [7/30], Validation Accuracy: 0.8170, Validation Loss: 0.3188
# Epoch [8/30], Step [10/55], Train Loss: 0.2958
# Epoch [8/30], Train Accuracy: 0.8754
# Epoch [8/30], Validation Accuracy: 0.8217, Validation Loss: 0.3102
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [8/30], Step [20/55], Train Loss: 0.2326
# Epoch [8/30], Train Accuracy: 0.8715
# Epoch [8/30], Validation Accuracy: 0.8251, Validation Loss: 0.2963
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [8/30], Step [30/55], Train Loss: 0.2301
# Epoch [8/30], Train Accuracy: 0.8715
# Epoch [8/30], Validation Accuracy: 0.8135, Validation Loss: 0.3023
# Epoch [8/30], Step [40/55], Train Loss: 0.2496
# Epoch [8/30], Train Accuracy: 0.8715
# Epoch [8/30], Validation Accuracy: 0.8188, Validation Loss: 0.3129
# Epoch [8/30], Step [50/55], Train Loss: 0.2058
# Epoch [8/30], Train Accuracy: 0.8729
# Epoch [8/30], Validation Accuracy: 0.8159, Validation Loss: 0.3026
# Epoch [8/30], Step [55/55], Train Loss: 0.2358
# Epoch [8/30], Train Accuracy: 0.8713
# Epoch [8/30], Validation Accuracy: 0.8159, Validation Loss: 0.3165
# Epoch [9/30], Step [10/55], Train Loss: 0.2871
# Epoch [9/30], Train Accuracy: 0.8816
# Epoch [9/30], Validation Accuracy: 0.8240, Validation Loss: 0.3061
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [9/30], Step [20/55], Train Loss: 0.2255
# Epoch [9/30], Train Accuracy: 0.8793
# Epoch [9/30], Validation Accuracy: 0.8286, Validation Loss: 0.2926
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [9/30], Step [30/55], Train Loss: 0.2225
# Epoch [9/30], Train Accuracy: 0.8794
# Epoch [9/30], Validation Accuracy: 0.8135, Validation Loss: 0.2988
# Epoch [9/30], Step [40/55], Train Loss: 0.2442
# Epoch [9/30], Train Accuracy: 0.8790
# Epoch [9/30], Validation Accuracy: 0.8188, Validation Loss: 0.3105
# Epoch [9/30], Step [50/55], Train Loss: 0.2005
# Epoch [9/30], Train Accuracy: 0.8800
# Epoch [9/30], Validation Accuracy: 0.8182, Validation Loss: 0.3003
# Epoch [9/30], Step [55/55], Train Loss: 0.2240
# Epoch [9/30], Train Accuracy: 0.8785
# Epoch [9/30], Validation Accuracy: 0.8130, Validation Loss: 0.3162
# Epoch [10/30], Step [10/55], Train Loss: 0.2804
# Epoch [10/30], Train Accuracy: 0.8863
# Epoch [10/30], Validation Accuracy: 0.8240, Validation Loss: 0.3028
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [10/30], Step [20/55], Train Loss: 0.2189
# Epoch [10/30], Train Accuracy: 0.8834
# Epoch [10/30], Validation Accuracy: 0.8309, Validation Loss: 0.2898
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [10/30], Step [30/55], Train Loss: 0.2157
# Epoch [10/30], Train Accuracy: 0.8842
# Epoch [10/30], Validation Accuracy: 0.8217, Validation Loss: 0.2956
# Epoch [10/30], Step [40/55], Train Loss: 0.2388
# Epoch [10/30], Train Accuracy: 0.8832
# Epoch [10/30], Validation Accuracy: 0.8159, Validation Loss: 0.3104
# Epoch [10/30], Step [50/55], Train Loss: 0.1952
# Epoch [10/30], Train Accuracy: 0.8840
# Epoch [10/30], Validation Accuracy: 0.8222, Validation Loss: 0.2976
# Epoch [10/30], Step [55/55], Train Loss: 0.2147
# Epoch [10/30], Train Accuracy: 0.8828
# Epoch [10/30], Validation Accuracy: 0.8043, Validation Loss: 0.3255
# Epoch [11/30], Step [10/55], Train Loss: 0.2738
# Epoch [11/30], Train Accuracy: 0.8820
# Epoch [11/30], Validation Accuracy: 0.8251, Validation Loss: 0.3002
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [11/30], Step [20/55], Train Loss: 0.2116
# Epoch [11/30], Train Accuracy: 0.8838
# Epoch [11/30], Validation Accuracy: 0.8327, Validation Loss: 0.2873
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [11/30], Step [30/55], Train Loss: 0.2080
# Epoch [11/30], Train Accuracy: 0.8863
# Epoch [11/30], Validation Accuracy: 0.8222, Validation Loss: 0.2928
# Epoch [11/30], Step [40/55], Train Loss: 0.2336
# Epoch [11/30], Train Accuracy: 0.8854
# Epoch [11/30], Validation Accuracy: 0.8164, Validation Loss: 0.3087
# Epoch [11/30], Step [50/55], Train Loss: 0.1908
# Epoch [11/30], Train Accuracy: 0.8863
# Epoch [11/30], Validation Accuracy: 0.8269, Validation Loss: 0.2945
# Epoch [11/30], Step [55/55], Train Loss: 0.2123
# Epoch [11/30], Train Accuracy: 0.8849
# Epoch [11/30], Validation Accuracy: 0.7707, Validation Loss: 0.3421
# Epoch [12/30], Step [10/55], Train Loss: 0.2664
# Epoch [12/30], Train Accuracy: 0.8809
# Epoch [12/30], Validation Accuracy: 0.8298, Validation Loss: 0.2980
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [12/30], Step [20/55], Train Loss: 0.2052
# Epoch [12/30], Train Accuracy: 0.8869
# Epoch [12/30], Validation Accuracy: 0.8356, Validation Loss: 0.2848
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [12/30], Step [30/55], Train Loss: 0.2011
# Epoch [12/30], Train Accuracy: 0.8892
# Epoch [12/30], Validation Accuracy: 0.8251, Validation Loss: 0.2903
# Epoch [12/30], Step [40/55], Train Loss: 0.2257
# Epoch [12/30], Train Accuracy: 0.8889
# Epoch [12/30], Validation Accuracy: 0.8193, Validation Loss: 0.3054
# Epoch [12/30], Step [50/55], Train Loss: 0.1880
# Epoch [12/30], Train Accuracy: 0.8897
# Epoch [12/30], Validation Accuracy: 0.8321, Validation Loss: 0.2905
# Epoch [12/30], Step [55/55], Train Loss: 0.2082
# Epoch [12/30], Train Accuracy: 0.8884
# Epoch [12/30], Validation Accuracy: 0.7933, Validation Loss: 0.3285
# Epoch [13/30], Step [10/55], Train Loss: 0.2599
# Epoch [13/30], Train Accuracy: 0.8824
# Epoch [13/30], Validation Accuracy: 0.8309, Validation Loss: 0.2967
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [13/30], Step [20/55], Train Loss: 0.1997
# Epoch [13/30], Train Accuracy: 0.8891
# Epoch [13/30], Validation Accuracy: 0.8408, Validation Loss: 0.2832
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [13/30], Step [30/55], Train Loss: 0.1945
# Epoch [13/30], Train Accuracy: 0.8923
# Epoch [13/30], Validation Accuracy: 0.8251, Validation Loss: 0.2880
# Epoch [13/30], Step [40/55], Train Loss: 0.2190
# Epoch [13/30], Train Accuracy: 0.8923
# Epoch [13/30], Validation Accuracy: 0.8205, Validation Loss: 0.3044
# Epoch [13/30], Step [50/55], Train Loss: 0.1871
# Epoch [13/30], Train Accuracy: 0.8927
# Epoch [13/30], Validation Accuracy: 0.8356, Validation Loss: 0.2889
# Epoch [13/30], Step [55/55], Train Loss: 0.1893
# Epoch [13/30], Train Accuracy: 0.8914
# Epoch [13/30], Validation Accuracy: 0.8078, Validation Loss: 0.3122
# Epoch [14/30], Step [10/55], Train Loss: 0.2533
# Epoch [14/30], Train Accuracy: 0.8867
# Epoch [14/30], Validation Accuracy: 0.8309, Validation Loss: 0.2948
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [14/30], Step [20/55], Train Loss: 0.1941
# Epoch [14/30], Train Accuracy: 0.8928
# Epoch [14/30], Validation Accuracy: 0.8390, Validation Loss: 0.2824
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [14/30], Step [30/55], Train Loss: 0.1884
# Epoch [14/30], Train Accuracy: 0.8961
# Epoch [14/30], Validation Accuracy: 0.8274, Validation Loss: 0.2863
# Epoch [14/30], Step [40/55], Train Loss: 0.2109
# Epoch [14/30], Train Accuracy: 0.8970
# Epoch [14/30], Validation Accuracy: 0.8257, Validation Loss: 0.3021
# Epoch [14/30], Step [50/55], Train Loss: 0.1793
# Epoch [14/30], Train Accuracy: 0.8980
# Epoch [14/30], Validation Accuracy: 0.8373, Validation Loss: 0.2930
# Epoch [14/30], Step [55/55], Train Loss: 0.1744
# Epoch [14/30], Train Accuracy: 0.8969
# Epoch [14/30], Validation Accuracy: 0.8315, Validation Loss: 0.2977
# Epoch [15/30], Step [10/55], Train Loss: 0.2475
# Epoch [15/30], Train Accuracy: 0.9031
# Epoch [15/30], Validation Accuracy: 0.8309, Validation Loss: 0.2998
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [15/30], Step [20/55], Train Loss: 0.1881
# Epoch [15/30], Train Accuracy: 0.9018
# Epoch [15/30], Validation Accuracy: 0.8390, Validation Loss: 0.2820
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [15/30], Step [30/55], Train Loss: 0.1819
# Epoch [15/30], Train Accuracy: 0.9029
# Epoch [15/30], Validation Accuracy: 0.8327, Validation Loss: 0.2856
# Epoch [15/30], Step [40/55], Train Loss: 0.2032
# Epoch [15/30], Train Accuracy: 0.9031
# Epoch [15/30], Validation Accuracy: 0.8269, Validation Loss: 0.2998
# Epoch [15/30], Step [50/55], Train Loss: 0.1689
# Epoch [15/30], Train Accuracy: 0.9037
# Epoch [15/30], Validation Accuracy: 0.8292, Validation Loss: 0.2963
# Epoch [15/30], Step [55/55], Train Loss: 0.1880
# Epoch [15/30], Train Accuracy: 0.9022
# Epoch [15/30], Validation Accuracy: 0.8356, Validation Loss: 0.2997
# Epoch [16/30], Step [10/55], Train Loss: 0.2407
# Epoch [16/30], Train Accuracy: 0.9070
# Epoch [16/30], Validation Accuracy: 0.8292, Validation Loss: 0.3002
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [16/30], Step [20/55], Train Loss: 0.1818
# Epoch [16/30], Train Accuracy: 0.9086
# Epoch [16/30], Validation Accuracy: 0.8367, Validation Loss: 0.2832
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [16/30], Step [30/55], Train Loss: 0.1762
# Epoch [16/30], Train Accuracy: 0.9094
# Epoch [16/30], Validation Accuracy: 0.8373, Validation Loss: 0.2825
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [16/30], Step [40/55], Train Loss: 0.1911
# Epoch [16/30], Train Accuracy: 0.9095
# Epoch [16/30], Validation Accuracy: 0.8373, Validation Loss: 0.2877
# Epoch [16/30], Step [50/55], Train Loss: 0.2527
# Epoch [16/30], Train Accuracy: 0.9064
# Epoch [16/30], Validation Accuracy: 0.8390, Validation Loss: 0.2888
# Epoch [16/30], Step [55/55], Train Loss: 0.1474
# Epoch [16/30], Train Accuracy: 0.9048
# Epoch [16/30], Validation Accuracy: 0.8269, Validation Loss: 0.3040
# Epoch [17/30], Step [10/55], Train Loss: 0.2329
# Epoch [17/30], Train Accuracy: 0.9070
# Epoch [17/30], Validation Accuracy: 0.8332, Validation Loss: 0.2943
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [17/30], Step [20/55], Train Loss: 0.1758
# Epoch [17/30], Train Accuracy: 0.9102
# Epoch [17/30], Validation Accuracy: 0.8396, Validation Loss: 0.2818
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [17/30], Step [30/55], Train Loss: 0.1705
# Epoch [17/30], Train Accuracy: 0.9128
# Epoch [17/30], Validation Accuracy: 0.8373, Validation Loss: 0.2821
# Epoch [17/30], Step [40/55], Train Loss: 0.1959
# Epoch [17/30], Train Accuracy: 0.9134
# Epoch [17/30], Validation Accuracy: 0.8217, Validation Loss: 0.3051
# Epoch [17/30], Step [50/55], Train Loss: 0.1809
# Epoch [17/30], Train Accuracy: 0.9127
# Epoch [17/30], Validation Accuracy: 0.8379, Validation Loss: 0.2889
# Epoch [17/30], Step [55/55], Train Loss: 0.1514
# Epoch [17/30], Train Accuracy: 0.9114
# Epoch [17/30], Validation Accuracy: 0.8153, Validation Loss: 0.3065
# Epoch [18/30], Step [10/55], Train Loss: 0.2263
# Epoch [18/30], Train Accuracy: 0.9051
# Epoch [18/30], Validation Accuracy: 0.8327, Validation Loss: 0.2935
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [18/30], Step [20/55], Train Loss: 0.1694
# Epoch [18/30], Train Accuracy: 0.9092
# Epoch [18/30], Validation Accuracy: 0.8413, Validation Loss: 0.2817
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [18/30], Step [30/55], Train Loss: 0.1643
# Epoch [18/30], Train Accuracy: 0.9137
# Epoch [18/30], Validation Accuracy: 0.8373, Validation Loss: 0.2846
# Epoch [18/30], Step [40/55], Train Loss: 0.1847
# Epoch [18/30], Train Accuracy: 0.9153
# Epoch [18/30], Validation Accuracy: 0.8292, Validation Loss: 0.2980
# Epoch [18/30], Step [50/55], Train Loss: 0.1607
# Epoch [18/30], Train Accuracy: 0.9168
# Epoch [18/30], Validation Accuracy: 0.8390, Validation Loss: 0.2861
# Epoch [18/30], Step [55/55], Train Loss: 0.1377
# Epoch [18/30], Train Accuracy: 0.9151
# Epoch [18/30], Validation Accuracy: 0.8222, Validation Loss: 0.3032
# Epoch [19/30], Step [10/55], Train Loss: 0.2166
# Epoch [19/30], Train Accuracy: 0.9082
# Epoch [19/30], Validation Accuracy: 0.8327, Validation Loss: 0.2961
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [19/30], Step [20/55], Train Loss: 0.1629
# Epoch [19/30], Train Accuracy: 0.9150
# Epoch [19/30], Validation Accuracy: 0.8419, Validation Loss: 0.2826
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [19/30], Step [30/55], Train Loss: 0.1572
# Epoch [19/30], Train Accuracy: 0.9198
# Epoch [19/30], Validation Accuracy: 0.8344, Validation Loss: 0.2865
# Epoch [19/30], Step [40/55], Train Loss: 0.1743
# Epoch [19/30], Train Accuracy: 0.9207
# Epoch [19/30], Validation Accuracy: 0.8303, Validation Loss: 0.2951
# Epoch [19/30], Step [50/55], Train Loss: 0.1719
# Epoch [19/30], Train Accuracy: 0.9211
# Epoch [19/30], Validation Accuracy: 0.8402, Validation Loss: 0.2883
# Epoch [19/30], Step [55/55], Train Loss: 0.1223
# Epoch [19/30], Train Accuracy: 0.9199
# Epoch [19/30], Validation Accuracy: 0.8257, Validation Loss: 0.3033
# Epoch [20/30], Step [10/55], Train Loss: 0.2428
# Epoch [20/30], Train Accuracy: 0.9191
# Epoch [20/30], Validation Accuracy: 0.8240, Validation Loss: 0.3209
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [20/30], Step [20/55], Train Loss: 0.1584
# Epoch [20/30], Train Accuracy: 0.9154
# Epoch [20/30], Validation Accuracy: 0.8396, Validation Loss: 0.2839
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [20/30], Step [30/55], Train Loss: 0.1518
# Epoch [20/30], Train Accuracy: 0.9211
# Epoch [20/30], Validation Accuracy: 0.8373, Validation Loss: 0.2848
# Epoch [20/30], Step [40/55], Train Loss: 0.1627
# Epoch [20/30], Train Accuracy: 0.9237
# Epoch [20/30], Validation Accuracy: 0.8442, Validation Loss: 0.2865
# Epoch [20/30], Step [50/55], Train Loss: 0.2005
# Epoch [20/30], Train Accuracy: 0.9205
# Epoch [20/30], Validation Accuracy: 0.8466, Validation Loss: 0.2872
# Epoch [20/30], Step [55/55], Train Loss: 0.1228
# Epoch [20/30], Train Accuracy: 0.9200
# Epoch [20/30], Validation Accuracy: 0.8361, Validation Loss: 0.2995
# Epoch [21/30], Step [10/55], Train Loss: 0.2038
# Epoch [21/30], Train Accuracy: 0.9234
# Epoch [21/30], Validation Accuracy: 0.8379, Validation Loss: 0.3005
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [21/30], Step [20/55], Train Loss: 0.1519
# Epoch [21/30], Train Accuracy: 0.9246
# Epoch [21/30], Validation Accuracy: 0.8448, Validation Loss: 0.2864
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [21/30], Step [30/55], Train Loss: 0.1492
# Epoch [21/30], Train Accuracy: 0.9276
# Epoch [21/30], Validation Accuracy: 0.8408, Validation Loss: 0.2839
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [21/30], Step [40/55], Train Loss: 0.1546
# Epoch [21/30], Train Accuracy: 0.9301
# Epoch [21/30], Validation Accuracy: 0.8367, Validation Loss: 0.2888
# Epoch [21/30], Step [50/55], Train Loss: 0.1397
# Epoch [21/30], Train Accuracy: 0.9294
# Epoch [21/30], Validation Accuracy: 0.8332, Validation Loss: 0.2918
# Epoch [21/30], Step [55/55], Train Loss: 0.1316
# Epoch [21/30], Train Accuracy: 0.9294
# Epoch [21/30], Validation Accuracy: 0.8303, Validation Loss: 0.3007
# Epoch [22/30], Step [10/55], Train Loss: 0.1947
# Epoch [22/30], Train Accuracy: 0.9316
# Epoch [22/30], Validation Accuracy: 0.8396, Validation Loss: 0.3009
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [22/30], Step [20/55], Train Loss: 0.1453
# Epoch [22/30], Train Accuracy: 0.9320
# Epoch [22/30], Validation Accuracy: 0.8390, Validation Loss: 0.2891
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [22/30], Step [30/55], Train Loss: 0.1393
# Epoch [22/30], Train Accuracy: 0.9349
# Epoch [22/30], Validation Accuracy: 0.8338, Validation Loss: 0.2884
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [22/30], Step [40/55], Train Loss: 0.1788
# Epoch [22/30], Train Accuracy: 0.9351
# Epoch [22/30], Validation Accuracy: 0.7939, Validation Loss: 0.3357
# Epoch [22/30], Step [50/55], Train Loss: 0.1693
# Epoch [22/30], Train Accuracy: 0.9329
# Epoch [22/30], Validation Accuracy: 0.8413, Validation Loss: 0.2911
# Epoch [22/30], Step [55/55], Train Loss: 0.0899
# Epoch [22/30], Train Accuracy: 0.9321
# Epoch [22/30], Validation Accuracy: 0.8292, Validation Loss: 0.3025
# Epoch [23/30], Step [10/55], Train Loss: 0.2377
# Epoch [23/30], Train Accuracy: 0.9242
# Epoch [23/30], Validation Accuracy: 0.8240, Validation Loss: 0.3201
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [23/30], Step [20/55], Train Loss: 0.1365
# Epoch [23/30], Train Accuracy: 0.9236
# Epoch [23/30], Validation Accuracy: 0.8419, Validation Loss: 0.2864
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [23/30], Step [30/55], Train Loss: 0.1349
# Epoch [23/30], Train Accuracy: 0.9303
# Epoch [23/30], Validation Accuracy: 0.8344, Validation Loss: 0.2897
# Epoch [23/30], Step [40/55], Train Loss: 0.1404
# Epoch [23/30], Train Accuracy: 0.9340
# Epoch [23/30], Validation Accuracy: 0.8338, Validation Loss: 0.2934
# Epoch [23/30], Step [50/55], Train Loss: 0.1932
# Epoch [23/30], Train Accuracy: 0.9332
# Epoch [23/30], Validation Accuracy: 0.8384, Validation Loss: 0.3050
# Epoch [23/30], Step [55/55], Train Loss: 0.0890
# Epoch [23/30], Train Accuracy: 0.9326
# Epoch [23/30], Validation Accuracy: 0.8303, Validation Loss: 0.3016
# Epoch [24/30], Step [10/55], Train Loss: 0.2026
# Epoch [24/30], Train Accuracy: 0.9340
# Epoch [24/30], Validation Accuracy: 0.8303, Validation Loss: 0.3088
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [24/30], Step [20/55], Train Loss: 0.1298
# Epoch [24/30], Train Accuracy: 0.9354
# Epoch [24/30], Validation Accuracy: 0.8402, Validation Loss: 0.2895
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [24/30], Step [30/55], Train Loss: 0.1278
# Epoch [24/30], Train Accuracy: 0.9408
# Epoch [24/30], Validation Accuracy: 0.8338, Validation Loss: 0.2920
# Epoch [24/30], Step [40/55], Train Loss: 0.1319
# Epoch [24/30], Train Accuracy: 0.9432
# Epoch [24/30], Validation Accuracy: 0.8350, Validation Loss: 0.2947
# Epoch [24/30], Step [50/55], Train Loss: 0.1533
# Epoch [24/30], Train Accuracy: 0.9429
# Epoch [24/30], Validation Accuracy: 0.8361, Validation Loss: 0.3014
# Epoch [24/30], Step [55/55], Train Loss: 0.0713
# Epoch [24/30], Train Accuracy: 0.9425
# Epoch [24/30], Validation Accuracy: 0.8246, Validation Loss: 0.3047
# Epoch [25/30], Step [10/55], Train Loss: 0.1688
# Epoch [25/30], Train Accuracy: 0.9418
# Epoch [25/30], Validation Accuracy: 0.8356, Validation Loss: 0.3073
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [25/30], Step [20/55], Train Loss: 0.1260
# Epoch [25/30], Train Accuracy: 0.9416
# Epoch [25/30], Validation Accuracy: 0.8367, Validation Loss: 0.2955
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [25/30], Step [30/55], Train Loss: 0.1219
# Epoch [25/30], Train Accuracy: 0.9454
# Epoch [25/30], Validation Accuracy: 0.8344, Validation Loss: 0.2926
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [25/30], Step [40/55], Train Loss: 0.1316
# Epoch [25/30], Train Accuracy: 0.9453
# Epoch [25/30], Validation Accuracy: 0.8396, Validation Loss: 0.3002
# Epoch [25/30], Step [50/55], Train Loss: 0.1470
# Epoch [25/30], Train Accuracy: 0.9468
# Epoch [25/30], Validation Accuracy: 0.8031, Validation Loss: 0.3341
# Epoch [25/30], Step [55/55], Train Loss: 0.1196
# Epoch [25/30], Train Accuracy: 0.9451
# Epoch [25/30], Validation Accuracy: 0.8199, Validation Loss: 0.3240
# Epoch [26/30], Step [10/55], Train Loss: 0.1850
# Epoch [26/30], Train Accuracy: 0.9434
# Epoch [26/30], Validation Accuracy: 0.8217, Validation Loss: 0.3380
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [26/30], Step [20/55], Train Loss: 0.1182
# Epoch [26/30], Train Accuracy: 0.9410
# Epoch [26/30], Validation Accuracy: 0.8402, Validation Loss: 0.2925
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [26/30], Step [30/55], Train Loss: 0.1141
# Epoch [26/30], Train Accuracy: 0.9467
# Epoch [26/30], Validation Accuracy: 0.8228, Validation Loss: 0.3047
# Epoch [26/30], Step [40/55], Train Loss: 0.1253
# Epoch [26/30], Train Accuracy: 0.9471
# Epoch [26/30], Validation Accuracy: 0.8217, Validation Loss: 0.3057
# Epoch [26/30], Step [50/55], Train Loss: 0.1122
# Epoch [26/30], Train Accuracy: 0.9491
# Epoch [26/30], Validation Accuracy: 0.8130, Validation Loss: 0.3167
# Epoch [26/30], Step [55/55], Train Loss: 0.1083
# Epoch [26/30], Train Accuracy: 0.9491
# Epoch [26/30], Validation Accuracy: 0.8222, Validation Loss: 0.3334
# Epoch [27/30], Step [10/55], Train Loss: 0.1779
# Epoch [27/30], Train Accuracy: 0.9453
# Epoch [27/30], Validation Accuracy: 0.8217, Validation Loss: 0.3269
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [27/30], Step [20/55], Train Loss: 0.1082
# Epoch [27/30], Train Accuracy: 0.9430
# Epoch [27/30], Validation Accuracy: 0.8350, Validation Loss: 0.2965
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [27/30], Step [30/55], Train Loss: 0.1093
# Epoch [27/30], Train Accuracy: 0.9490
# Epoch [27/30], Validation Accuracy: 0.8280, Validation Loss: 0.2995
# Epoch [27/30], Step [40/55], Train Loss: 0.1107
# Epoch [27/30], Train Accuracy: 0.9524
# Epoch [27/30], Validation Accuracy: 0.8286, Validation Loss: 0.3056
# Epoch [27/30], Step [50/55], Train Loss: 0.1279
# Epoch [27/30], Train Accuracy: 0.9519
# Epoch [27/30], Validation Accuracy: 0.8408, Validation Loss: 0.3046
# Epoch [27/30], Step [55/55], Train Loss: 0.0704
# Epoch [27/30], Train Accuracy: 0.9517
# Epoch [27/30], Validation Accuracy: 0.8072, Validation Loss: 0.3227
# Epoch [28/30], Step [10/55], Train Loss: 0.1551
# Epoch [28/30], Train Accuracy: 0.9363
# Epoch [28/30], Validation Accuracy: 0.8315, Validation Loss: 0.3176
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [28/30], Step [20/55], Train Loss: 0.1005
# Epoch [28/30], Train Accuracy: 0.9449
# Epoch [28/30], Validation Accuracy: 0.8338, Validation Loss: 0.2994
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [28/30], Step [30/55], Train Loss: 0.1002
# Epoch [28/30], Train Accuracy: 0.9520
# Epoch [28/30], Validation Accuracy: 0.8199, Validation Loss: 0.3153
# Epoch [28/30], Step [40/55], Train Loss: 0.1109
# Epoch [28/30], Train Accuracy: 0.9552
# Epoch [28/30], Validation Accuracy: 0.8199, Validation Loss: 0.3137
# Epoch [28/30], Step [50/55], Train Loss: 0.1030
# Epoch [28/30], Train Accuracy: 0.9539
# Epoch [28/30], Validation Accuracy: 0.8303, Validation Loss: 0.3090
# Epoch [28/30], Step [55/55], Train Loss: 0.0961
# Epoch [28/30], Train Accuracy: 0.9536
# Epoch [28/30], Validation Accuracy: 0.8298, Validation Loss: 0.3116
# Epoch [29/30], Step [10/55], Train Loss: 0.2366
# Epoch [29/30], Train Accuracy: 0.9578
# Epoch [29/30], Validation Accuracy: 0.8025, Validation Loss: 0.3792
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [29/30], Step [20/55], Train Loss: 0.0948
# Epoch [29/30], Train Accuracy: 0.9576
# Epoch [29/30], Validation Accuracy: 0.8332, Validation Loss: 0.3013
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [29/30], Step [30/55], Train Loss: 0.0933
# Epoch [29/30], Train Accuracy: 0.9617
# Epoch [29/30], Validation Accuracy: 0.8251, Validation Loss: 0.3078
# Epoch [29/30], Step [40/55], Train Loss: 0.0966
# Epoch [29/30], Train Accuracy: 0.9640
# Epoch [29/30], Validation Accuracy: 0.8309, Validation Loss: 0.3119
# Epoch [29/30], Step [50/55], Train Loss: 0.1416
# Epoch [29/30], Train Accuracy: 0.9627
# Epoch [29/30], Validation Accuracy: 0.8257, Validation Loss: 0.3249
# Epoch [29/30], Step [55/55], Train Loss: 0.0525
# Epoch [29/30], Train Accuracy: 0.9616
# Epoch [29/30], Validation Accuracy: 0.8199, Validation Loss: 0.3253
# Epoch [30/30], Step [10/55], Train Loss: 0.2119
# Epoch [30/30], Train Accuracy: 0.9539
# Epoch [30/30], Validation Accuracy: 0.8095, Validation Loss: 0.3451
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [30/30], Step [20/55], Train Loss: 0.0855
# Epoch [30/30], Train Accuracy: 0.9566
# Epoch [30/30], Validation Accuracy: 0.8309, Validation Loss: 0.3067
# Model saved to ==> ./model_saves_undersampled/model_MMCNN_SUM_epoch_30.pt
# Epoch [30/30], Step [30/55], Train Loss: 0.0880
# Epoch [30/30], Train Accuracy: 0.9621
# Epoch [30/30], Validation Accuracy: 0.8292, Validation Loss: 0.3096
# Epoch [30/30], Step [40/55], Train Loss: 0.0847
# Epoch [30/30], Train Accuracy: 0.9658
# Epoch [30/30], Validation Accuracy: 0.8240, Validation Loss: 0.3163
# Epoch [30/30], Step [50/55], Train Loss: 0.1487
# Epoch [30/30], Train Accuracy: 0.9642
# Epoch [30/30], Validation Accuracy: 0.8095, Validation Loss: 0.3394
# Epoch [30/30], Step [55/55], Train Loss: 0.0679
# Epoch [30/30], Train Accuracy: 0.9639
# Epoch [30/30], Validation Accuracy: 0.8054, Validation Loss: 0.3401
# Ended Training, Test Accuracy: 0.8358

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)
