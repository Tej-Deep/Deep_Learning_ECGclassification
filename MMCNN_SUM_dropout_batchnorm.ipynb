# %%
from preprocess.preprocess import load_dataset, compute_label_agg, select_data, get_data_loaders, undersample

import torch
import torch.nn as nn
import torch.optim as optim

from models.CNN import MMCNN_SUM
from utils.trainer import trainer
from utils.RNN_utils import plot_losses, rename_with_acc

# %%
# Define device for torch
use_cuda = True
device = torch.device("cuda" if (
    use_cuda and torch.cuda.is_available()) else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Define options

# %%
LOAD_DATASET = False
TRAIN_PATH = './PTB_train.pt'
VALID_PATH = './PTB_valid.pt'
TEST_PATH = './PTB_test.pt'
SAVE_NAME = 'MMCNN_SUM_drop_bn_epoch_30'
SAVE_DIR = './model_saves/'
BATCH_SIZE = 256

# %% [markdown]
# # Loading the dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)
# Out:
# Start loading
# done loading

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = MMCNN_SUM().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)
# Out:
# cuda
# Epoch [1/30], Step [10/67], Train Loss: 0.4947
# Epoch [1/30], Train Accuracy: 0.4953
# Epoch [1/30], Validation Accuracy: 0.4730, Validation Loss: 0.5380
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [1/30], Step [20/67], Train Loss: 0.4479
# Epoch [1/30], Train Accuracy: 0.5596
# Epoch [1/30], Validation Accuracy: 0.6654, Validation Loss: 0.4321
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [1/30], Step [30/67], Train Loss: 0.3621
# Epoch [1/30], Train Accuracy: 0.6112
# Epoch [1/30], Validation Accuracy: 0.7265, Validation Loss: 0.3934
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [1/30], Step [40/67], Train Loss: 0.3593
# Epoch [1/30], Train Accuracy: 0.6458
# Epoch [1/30], Validation Accuracy: 0.7325, Validation Loss: 0.3790
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [1/30], Step [50/67], Train Loss: 0.3684
# Epoch [1/30], Train Accuracy: 0.6704
# Epoch [1/30], Validation Accuracy: 0.7572, Validation Loss: 0.3586
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [1/30], Step [60/67], Train Loss: 0.3599
# Epoch [1/30], Train Accuracy: 0.6932
# Epoch [1/30], Validation Accuracy: 0.7633, Validation Loss: 0.3523
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [1/30], Step [67/67], Train Loss: 0.3438
# Epoch [1/30], Train Accuracy: 0.7028
# Epoch [1/30], Validation Accuracy: 0.7637, Validation Loss: 0.3455
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [2/30], Step [10/67], Train Loss: 0.3729
# Epoch [2/30], Train Accuracy: 0.6941
# Epoch [2/30], Validation Accuracy: 0.7572, Validation Loss: 0.3561
# Epoch [2/30], Step [20/67], Train Loss: 0.3389
# Epoch [2/30], Train Accuracy: 0.7527
# Epoch [2/30], Validation Accuracy: 0.7833, Validation Loss: 0.3397
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [2/30], Step [30/67], Train Loss: 0.2856
# Epoch [2/30], Train Accuracy: 0.7710
# Epoch [2/30], Validation Accuracy: 0.7684, Validation Loss: 0.3326
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [2/30], Step [40/67], Train Loss: 0.3133
# Epoch [2/30], Train Accuracy: 0.7839
# Epoch [2/30], Validation Accuracy: 0.7759, Validation Loss: 0.3350
# Epoch [2/30], Step [50/67], Train Loss: 0.3248
# Epoch [2/30], Train Accuracy: 0.7901
# Epoch [2/30], Validation Accuracy: 0.7870, Validation Loss: 0.3210
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [2/30], Step [60/67], Train Loss: 0.3226
# Epoch [2/30], Train Accuracy: 0.7980
# Epoch [2/30], Validation Accuracy: 0.7866, Validation Loss: 0.3179
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [2/30], Step [67/67], Train Loss: 0.3149
# Epoch [2/30], Train Accuracy: 0.8003
# Epoch [2/30], Validation Accuracy: 0.7819, Validation Loss: 0.3156
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [3/30], Step [10/67], Train Loss: 0.3102
# Epoch [3/30], Train Accuracy: 0.8109
# Epoch [3/30], Validation Accuracy: 0.7819, Validation Loss: 0.3201
# Epoch [3/30], Step [20/67], Train Loss: 0.3049
# Epoch [3/30], Train Accuracy: 0.8215
# Epoch [3/30], Validation Accuracy: 0.8038, Validation Loss: 0.3129
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [3/30], Step [30/67], Train Loss: 0.2645
# Epoch [3/30], Train Accuracy: 0.8264
# Epoch [3/30], Validation Accuracy: 0.7777, Validation Loss: 0.3132
# Epoch [3/30], Step [40/67], Train Loss: 0.2914
# Epoch [3/30], Train Accuracy: 0.8316
# Epoch [3/30], Validation Accuracy: 0.8024, Validation Loss: 0.3140
# Epoch [3/30], Step [50/67], Train Loss: 0.3068
# Epoch [3/30], Train Accuracy: 0.8316
# Epoch [3/30], Validation Accuracy: 0.8015, Validation Loss: 0.3022
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [3/30], Step [60/67], Train Loss: 0.3030
# Epoch [3/30], Train Accuracy: 0.8346
# Epoch [3/30], Validation Accuracy: 0.7987, Validation Loss: 0.2987
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [3/30], Step [67/67], Train Loss: 0.2958
# Epoch [3/30], Train Accuracy: 0.8352
# Epoch [3/30], Validation Accuracy: 0.8001, Validation Loss: 0.2977
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [4/30], Step [10/67], Train Loss: 0.2842
# Epoch [4/30], Train Accuracy: 0.8266
# Epoch [4/30], Validation Accuracy: 0.7982, Validation Loss: 0.3041
# Epoch [4/30], Step [20/67], Train Loss: 0.2849
# Epoch [4/30], Train Accuracy: 0.8373
# Epoch [4/30], Validation Accuracy: 0.8141, Validation Loss: 0.2986
# Epoch [4/30], Step [30/67], Train Loss: 0.2500
# Epoch [4/30], Train Accuracy: 0.8409
# Epoch [4/30], Validation Accuracy: 0.7940, Validation Loss: 0.2969
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [4/30], Step [40/67], Train Loss: 0.2779
# Epoch [4/30], Train Accuracy: 0.8460
# Epoch [4/30], Validation Accuracy: 0.8131, Validation Loss: 0.3035
# Epoch [4/30], Step [50/67], Train Loss: 0.2912
# Epoch [4/30], Train Accuracy: 0.8457
# Epoch [4/30], Validation Accuracy: 0.8085, Validation Loss: 0.2916
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [4/30], Step [60/67], Train Loss: 0.2920
# Epoch [4/30], Train Accuracy: 0.8486
# Epoch [4/30], Validation Accuracy: 0.8099, Validation Loss: 0.2872
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [4/30], Step [67/67], Train Loss: 0.2823
# Epoch [4/30], Train Accuracy: 0.8491
# Epoch [4/30], Validation Accuracy: 0.8117, Validation Loss: 0.2876
# Epoch [5/30], Step [10/67], Train Loss: 0.2728
# Epoch [5/30], Train Accuracy: 0.8465
# Epoch [5/30], Validation Accuracy: 0.8080, Validation Loss: 0.2978
# Epoch [5/30], Step [20/67], Train Loss: 0.2721
# Epoch [5/30], Train Accuracy: 0.8529
# Epoch [5/30], Validation Accuracy: 0.8211, Validation Loss: 0.2889
# Epoch [5/30], Step [30/67], Train Loss: 0.2377
# Epoch [5/30], Train Accuracy: 0.8530
# Epoch [5/30], Validation Accuracy: 0.8048, Validation Loss: 0.2878
# Epoch [5/30], Step [40/67], Train Loss: 0.2694
# Epoch [5/30], Train Accuracy: 0.8571
# Epoch [5/30], Validation Accuracy: 0.8183, Validation Loss: 0.2974
# Epoch [5/30], Step [50/67], Train Loss: 0.2788
# Epoch [5/30], Train Accuracy: 0.8555
# Epoch [5/30], Validation Accuracy: 0.8150, Validation Loss: 0.2844
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [5/30], Step [60/67], Train Loss: 0.2823
# Epoch [5/30], Train Accuracy: 0.8576
# Epoch [5/30], Validation Accuracy: 0.8197, Validation Loss: 0.2799
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [5/30], Step [67/67], Train Loss: 0.2728
# Epoch [5/30], Train Accuracy: 0.8578
# Epoch [5/30], Validation Accuracy: 0.8164, Validation Loss: 0.2827
# Epoch [6/30], Step [10/67], Train Loss: 0.2599
# Epoch [6/30], Train Accuracy: 0.8531
# Epoch [6/30], Validation Accuracy: 0.8127, Validation Loss: 0.2903
# Epoch [6/30], Step [20/67], Train Loss: 0.2632
# Epoch [6/30], Train Accuracy: 0.8600
# Epoch [6/30], Validation Accuracy: 0.8253, Validation Loss: 0.2832
# Epoch [6/30], Step [30/67], Train Loss: 0.2255
# Epoch [6/30], Train Accuracy: 0.8600
# Epoch [6/30], Validation Accuracy: 0.8089, Validation Loss: 0.2806
# Epoch [6/30], Step [40/67], Train Loss: 0.2604
# Epoch [6/30], Train Accuracy: 0.8642
# Epoch [6/30], Validation Accuracy: 0.8257, Validation Loss: 0.2918
# Epoch [6/30], Step [50/67], Train Loss: 0.2673
# Epoch [6/30], Train Accuracy: 0.8631
# Epoch [6/30], Validation Accuracy: 0.8197, Validation Loss: 0.2789
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [6/30], Step [60/67], Train Loss: 0.2759
# Epoch [6/30], Train Accuracy: 0.8646
# Epoch [6/30], Validation Accuracy: 0.8229, Validation Loss: 0.2757
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [6/30], Step [67/67], Train Loss: 0.2637
# Epoch [6/30], Train Accuracy: 0.8646
# Epoch [6/30], Validation Accuracy: 0.8253, Validation Loss: 0.2787
# Epoch [7/30], Step [10/67], Train Loss: 0.2538
# Epoch [7/30], Train Accuracy: 0.8602
# Epoch [7/30], Validation Accuracy: 0.8220, Validation Loss: 0.2865
# Epoch [7/30], Step [20/67], Train Loss: 0.2541
# Epoch [7/30], Train Accuracy: 0.8664
# Epoch [7/30], Validation Accuracy: 0.8290, Validation Loss: 0.2777
# Epoch [7/30], Step [30/67], Train Loss: 0.2178
# Epoch [7/30], Train Accuracy: 0.8667
# Epoch [7/30], Validation Accuracy: 0.8136, Validation Loss: 0.2766
# Epoch [7/30], Step [40/67], Train Loss: 0.2509
# Epoch [7/30], Train Accuracy: 0.8707
# Epoch [7/30], Validation Accuracy: 0.8276, Validation Loss: 0.2910
# Epoch [7/30], Step [50/67], Train Loss: 0.2591
# Epoch [7/30], Train Accuracy: 0.8693
# Epoch [7/30], Validation Accuracy: 0.8220, Validation Loss: 0.2760
# Epoch [7/30], Step [60/67], Train Loss: 0.2664
# Epoch [7/30], Train Accuracy: 0.8706
# Epoch [7/30], Validation Accuracy: 0.8248, Validation Loss: 0.2717
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [7/30], Step [67/67], Train Loss: 0.2991
# Epoch [7/30], Train Accuracy: 0.8690
# Epoch [7/30], Validation Accuracy: 0.8239, Validation Loss: 0.2819
# Epoch [8/30], Step [10/67], Train Loss: 0.2466
# Epoch [8/30], Train Accuracy: 0.8617
# Epoch [8/30], Validation Accuracy: 0.8201, Validation Loss: 0.2810
# Epoch [8/30], Step [20/67], Train Loss: 0.2468
# Epoch [8/30], Train Accuracy: 0.8686
# Epoch [8/30], Validation Accuracy: 0.8336, Validation Loss: 0.2733
# Epoch [8/30], Step [30/67], Train Loss: 0.2097
# Epoch [8/30], Train Accuracy: 0.8704
# Epoch [8/30], Validation Accuracy: 0.8159, Validation Loss: 0.2732
# Epoch [8/30], Step [40/67], Train Loss: 0.2436
# Epoch [8/30], Train Accuracy: 0.8756
# Epoch [8/30], Validation Accuracy: 0.8253, Validation Loss: 0.2843
# Epoch [8/30], Step [50/67], Train Loss: 0.2491
# Epoch [8/30], Train Accuracy: 0.8747
# Epoch [8/30], Validation Accuracy: 0.8234, Validation Loss: 0.2724
# Epoch [8/30], Step [60/67], Train Loss: 0.2650
# Epoch [8/30], Train Accuracy: 0.8753
# Epoch [8/30], Validation Accuracy: 0.8290, Validation Loss: 0.2701
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [8/30], Step [67/67], Train Loss: 0.2438
# Epoch [8/30], Train Accuracy: 0.8749
# Epoch [8/30], Validation Accuracy: 0.8239, Validation Loss: 0.2783
# Epoch [9/30], Step [10/67], Train Loss: 0.2470
# Epoch [9/30], Train Accuracy: 0.8598
# Epoch [9/30], Validation Accuracy: 0.8243, Validation Loss: 0.2818
# Epoch [9/30], Step [20/67], Train Loss: 0.2375
# Epoch [9/30], Train Accuracy: 0.8699
# Epoch [9/30], Validation Accuracy: 0.8355, Validation Loss: 0.2701
# Epoch [9/30], Step [30/67], Train Loss: 0.2029
# Epoch [9/30], Train Accuracy: 0.8728
# Epoch [9/30], Validation Accuracy: 0.8211, Validation Loss: 0.2698
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [9/30], Step [40/67], Train Loss: 0.2328
# Epoch [9/30], Train Accuracy: 0.8790
# Epoch [9/30], Validation Accuracy: 0.8243, Validation Loss: 0.2840
# Epoch [9/30], Step [50/67], Train Loss: 0.2390
# Epoch [9/30], Train Accuracy: 0.8784
# Epoch [9/30], Validation Accuracy: 0.8243, Validation Loss: 0.2703
# Epoch [9/30], Step [60/67], Train Loss: 0.2641
# Epoch [9/30], Train Accuracy: 0.8800
# Epoch [9/30], Validation Accuracy: 0.8257, Validation Loss: 0.2704
# Epoch [9/30], Step [67/67], Train Loss: 0.2580
# Epoch [9/30], Train Accuracy: 0.8785
# Epoch [9/30], Validation Accuracy: 0.8318, Validation Loss: 0.2746
# Epoch [10/30], Step [10/67], Train Loss: 0.2440
# Epoch [10/30], Train Accuracy: 0.8621
# Epoch [10/30], Validation Accuracy: 0.8234, Validation Loss: 0.2801
# Epoch [10/30], Step [20/67], Train Loss: 0.2316
# Epoch [10/30], Train Accuracy: 0.8707
# Epoch [10/30], Validation Accuracy: 0.8355, Validation Loss: 0.2682
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [10/30], Step [30/67], Train Loss: 0.1971
# Epoch [10/30], Train Accuracy: 0.8749
# Epoch [10/30], Validation Accuracy: 0.8183, Validation Loss: 0.2701
# Epoch [10/30], Step [40/67], Train Loss: 0.2217
# Epoch [10/30], Train Accuracy: 0.8818
# Epoch [10/30], Validation Accuracy: 0.8281, Validation Loss: 0.2805
# Epoch [10/30], Step [50/67], Train Loss: 0.2301
# Epoch [10/30], Train Accuracy: 0.8820
# Epoch [10/30], Validation Accuracy: 0.8295, Validation Loss: 0.2687
# Epoch [10/30], Step [60/67], Train Loss: 0.2497
# Epoch [10/30], Train Accuracy: 0.8837
# Epoch [10/30], Validation Accuracy: 0.8350, Validation Loss: 0.2716
# Epoch [10/30], Step [67/67], Train Loss: 0.2220
# Epoch [10/30], Train Accuracy: 0.8828
# Epoch [10/30], Validation Accuracy: 0.8178, Validation Loss: 0.2776
# Epoch [11/30], Step [10/67], Train Loss: 0.2328
# Epoch [11/30], Train Accuracy: 0.8676
# Epoch [11/30], Validation Accuracy: 0.8239, Validation Loss: 0.2760
# Epoch [11/30], Step [20/67], Train Loss: 0.2253
# Epoch [11/30], Train Accuracy: 0.8783
# Epoch [11/30], Validation Accuracy: 0.8402, Validation Loss: 0.2691
# Epoch [11/30], Step [30/67], Train Loss: 0.1853
# Epoch [11/30], Train Accuracy: 0.8819
# Epoch [11/30], Validation Accuracy: 0.8253, Validation Loss: 0.2648
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [11/30], Step [40/67], Train Loss: 0.2142
# Epoch [11/30], Train Accuracy: 0.8889
# Epoch [11/30], Validation Accuracy: 0.8285, Validation Loss: 0.2802
# Epoch [11/30], Step [50/67], Train Loss: 0.2209
# Epoch [11/30], Train Accuracy: 0.8891
# Epoch [11/30], Validation Accuracy: 0.8350, Validation Loss: 0.2662
# Epoch [11/30], Step [60/67], Train Loss: 0.2403
# Epoch [11/30], Train Accuracy: 0.8906
# Epoch [11/30], Validation Accuracy: 0.8341, Validation Loss: 0.2695
# Epoch [11/30], Step [67/67], Train Loss: 0.2311
# Epoch [11/30], Train Accuracy: 0.8895
# Epoch [11/30], Validation Accuracy: 0.8285, Validation Loss: 0.2745
# Epoch [12/30], Step [10/67], Train Loss: 0.2281
# Epoch [12/30], Train Accuracy: 0.8676
# Epoch [12/30], Validation Accuracy: 0.8248, Validation Loss: 0.2787
# Epoch [12/30], Step [20/67], Train Loss: 0.2183
# Epoch [12/30], Train Accuracy: 0.8777
# Epoch [12/30], Validation Accuracy: 0.8374, Validation Loss: 0.2679
# Epoch [12/30], Step [30/67], Train Loss: 0.1767
# Epoch [12/30], Train Accuracy: 0.8835
# Epoch [12/30], Validation Accuracy: 0.8285, Validation Loss: 0.2661
# Epoch [12/30], Step [40/67], Train Loss: 0.1987
# Epoch [12/30], Train Accuracy: 0.8903
# Epoch [12/30], Validation Accuracy: 0.8271, Validation Loss: 0.2736
# Epoch [12/30], Step [50/67], Train Loss: 0.2181
# Epoch [12/30], Train Accuracy: 0.8916
# Epoch [12/30], Validation Accuracy: 0.8239, Validation Loss: 0.2733
# Epoch [12/30], Step [60/67], Train Loss: 0.2585
# Epoch [12/30], Train Accuracy: 0.8928
# Epoch [12/30], Validation Accuracy: 0.8290, Validation Loss: 0.2693
# Epoch [12/30], Step [67/67], Train Loss: 0.2336
# Epoch [12/30], Train Accuracy: 0.8910
# Epoch [12/30], Validation Accuracy: 0.8248, Validation Loss: 0.2773
# Epoch [13/30], Step [10/67], Train Loss: 0.2334
# Epoch [13/30], Train Accuracy: 0.8645
# Epoch [13/30], Validation Accuracy: 0.8257, Validation Loss: 0.2834
# Epoch [13/30], Step [20/67], Train Loss: 0.2112
# Epoch [13/30], Train Accuracy: 0.8771
# Epoch [13/30], Validation Accuracy: 0.8364, Validation Loss: 0.2656
# Epoch [13/30], Step [30/67], Train Loss: 0.1748
# Epoch [13/30], Train Accuracy: 0.8852
# Epoch [13/30], Validation Accuracy: 0.8197, Validation Loss: 0.2682
# Epoch [13/30], Step [40/67], Train Loss: 0.1945
# Epoch [13/30], Train Accuracy: 0.8933
# Epoch [13/30], Validation Accuracy: 0.8318, Validation Loss: 0.2769
# Epoch [13/30], Step [50/67], Train Loss: 0.2007
# Epoch [13/30], Train Accuracy: 0.8947
# Epoch [13/30], Validation Accuracy: 0.8336, Validation Loss: 0.2640
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [13/30], Step [60/67], Train Loss: 0.2346
# Epoch [13/30], Train Accuracy: 0.8972
# Epoch [13/30], Validation Accuracy: 0.8346, Validation Loss: 0.2674
# Epoch [13/30], Step [67/67], Train Loss: 0.2099
# Epoch [13/30], Train Accuracy: 0.8971
# Epoch [13/30], Validation Accuracy: 0.8225, Validation Loss: 0.2777
# Epoch [14/30], Step [10/67], Train Loss: 0.2282
# Epoch [14/30], Train Accuracy: 0.8711
# Epoch [14/30], Validation Accuracy: 0.8234, Validation Loss: 0.2764
# Epoch [14/30], Step [20/67], Train Loss: 0.2027
# Epoch [14/30], Train Accuracy: 0.8859
# Epoch [14/30], Validation Accuracy: 0.8364, Validation Loss: 0.2647
# Epoch [14/30], Step [30/67], Train Loss: 0.1600
# Epoch [14/30], Train Accuracy: 0.8930
# Epoch [14/30], Validation Accuracy: 0.8346, Validation Loss: 0.2614
# Model saved to ==> ./model_saves/model_MMCNN_SUM_drop_bn_epoch_30.pt
# Epoch [14/30], Step [40/67], Train Loss: 0.1782
# Epoch [14/30], Train Accuracy: 0.8992
# Epoch [14/30], Validation Accuracy: 0.8332, Validation Loss: 0.2688
# Epoch [14/30], Step [50/67], Train Loss: 0.2001
# Epoch [14/30], Train Accuracy: 0.9018
# Epoch [14/30], Validation Accuracy: 0.8355, Validation Loss: 0.2634
# Epoch [14/30], Step [60/67], Train Loss: 0.2195
# Epoch [14/30], Train Accuracy: 0.9045
# Epoch [14/30], Validation Accuracy: 0.8253, Validation Loss: 0.2673
# Epoch [14/30], Step [67/67], Train Loss: 0.2133
# Epoch [14/30], Train Accuracy: 0.9022
# Epoch [14/30], Validation Accuracy: 0.8350, Validation Loss: 0.2704
# Epoch [15/30], Step [10/67], Train Loss: 0.2203
# Epoch [15/30], Train Accuracy: 0.8645
# Epoch [15/30], Validation Accuracy: 0.8267, Validation Loss: 0.2758
# Epoch [15/30], Step [20/67], Train Loss: 0.1976
# Epoch [15/30], Train Accuracy: 0.8832
# Epoch [15/30], Validation Accuracy: 0.8392, Validation Loss: 0.2682
# Epoch [15/30], Step [30/67], Train Loss: 0.1642
# Epoch [15/30], Train Accuracy: 0.8922
# Epoch [15/30], Validation Accuracy: 0.8234, Validation Loss: 0.2672
# Epoch [15/30], Step [40/67], Train Loss: 0.1689
# Epoch [15/30], Train Accuracy: 0.9015
# Epoch [15/30], Validation Accuracy: 0.8322, Validation Loss: 0.2689
# Epoch [15/30], Step [50/67], Train Loss: 0.1860
# Epoch [15/30], Train Accuracy: 0.9038
# Epoch [15/30], Validation Accuracy: 0.8341, Validation Loss: 0.2646
# Epoch [15/30], Step [60/67], Train Loss: 0.2107
# Epoch [15/30], Train Accuracy: 0.9066
# Epoch [15/30], Validation Accuracy: 0.8308, Validation Loss: 0.2674
# Epoch [15/30], Step [67/67], Train Loss: 0.1799
# Epoch [15/30], Train Accuracy: 0.9063
# Epoch [15/30], Validation Accuracy: 0.8304, Validation Loss: 0.2686
# Epoch [16/30], Step [10/67], Train Loss: 0.2243
# Epoch [16/30], Train Accuracy: 0.8793
# Epoch [16/30], Validation Accuracy: 0.8308, Validation Loss: 0.2797
# Epoch [16/30], Step [20/67], Train Loss: 0.1801
# Epoch [16/30], Train Accuracy: 0.8938
# Epoch [16/30], Validation Accuracy: 0.8364, Validation Loss: 0.2630
# Epoch [16/30], Step [30/67], Train Loss: 0.1830
# Epoch [16/30], Train Accuracy: 0.8995
# Epoch [16/30], Validation Accuracy: 0.8271, Validation Loss: 0.2688
# Epoch [16/30], Step [40/67], Train Loss: 0.1590
# Epoch [16/30], Train Accuracy: 0.9070
# Epoch [16/30], Validation Accuracy: 0.8360, Validation Loss: 0.2658
# Epoch [16/30], Step [50/67], Train Loss: 0.1797
# Epoch [16/30], Train Accuracy: 0.9088
# Epoch [16/30], Validation Accuracy: 0.8295, Validation Loss: 0.2680
# Epoch [16/30], Step [60/67], Train Loss: 0.2073
# Epoch [16/30], Train Accuracy: 0.9113
# Epoch [16/30], Validation Accuracy: 0.8271, Validation Loss: 0.2715
# Epoch [16/30], Step [67/67], Train Loss: 0.1791
# Epoch [16/30], Train Accuracy: 0.9117
# Epoch [16/30], Validation Accuracy: 0.8001, Validation Loss: 0.2956
# Epoch [17/30], Step [10/67], Train Loss: 0.2255
# Epoch [17/30], Train Accuracy: 0.8727
# Epoch [17/30], Validation Accuracy: 0.8281, Validation Loss: 0.2775
# Epoch [17/30], Step [20/67], Train Loss: 0.1745
# Epoch [17/30], Train Accuracy: 0.8939
# Epoch [17/30], Validation Accuracy: 0.8346, Validation Loss: 0.2639
# Epoch [17/30], Step [30/67], Train Loss: 0.1525
# Epoch [17/30], Train Accuracy: 0.9048
# Epoch [17/30], Validation Accuracy: 0.8308, Validation Loss: 0.2677
# Epoch [17/30], Step [40/67], Train Loss: 0.1589
# Epoch [17/30], Train Accuracy: 0.9103
# Epoch [17/30], Validation Accuracy: 0.8290, Validation Loss: 0.2726
# Epoch [17/30], Step [50/67], Train Loss: 0.1740
# Epoch [17/30], Train Accuracy: 0.9130
# Epoch [17/30], Validation Accuracy: 0.8318, Validation Loss: 0.2676
# Epoch [17/30], Step [60/67], Train Loss: 0.1945
# Epoch [17/30], Train Accuracy: 0.9158
# Epoch [17/30], Validation Accuracy: 0.8290, Validation Loss: 0.2714
# Epoch [17/30], Step [67/67], Train Loss: 0.1838
# Epoch [17/30], Train Accuracy: 0.9157
# Epoch [17/30], Validation Accuracy: 0.8257, Validation Loss: 0.2783
# Epoch [18/30], Step [10/67], Train Loss: 0.2112
# Epoch [18/30], Train Accuracy: 0.8773
# Epoch [18/30], Validation Accuracy: 0.8299, Validation Loss: 0.2809
# Epoch [18/30], Step [20/67], Train Loss: 0.1722
# Epoch [18/30], Train Accuracy: 0.8984
# Epoch [18/30], Validation Accuracy: 0.8364, Validation Loss: 0.2693
# Epoch [18/30], Step [30/67], Train Loss: 0.1460
# Epoch [18/30], Train Accuracy: 0.9056
# Epoch [18/30], Validation Accuracy: 0.8322, Validation Loss: 0.2648
# Epoch [18/30], Step [40/67], Train Loss: 0.1469
# Epoch [18/30], Train Accuracy: 0.9149
# Epoch [18/30], Validation Accuracy: 0.8285, Validation Loss: 0.2720
# Epoch [18/30], Step [50/67], Train Loss: 0.1655
# Epoch [18/30], Train Accuracy: 0.9180
# Epoch [18/30], Validation Accuracy: 0.8346, Validation Loss: 0.2660
# Epoch [18/30], Step [60/67], Train Loss: 0.1950
# Epoch [18/30], Train Accuracy: 0.9208
# Epoch [18/30], Validation Accuracy: 0.8336, Validation Loss: 0.2769
# Epoch [18/30], Step [67/67], Train Loss: 0.1583
# Epoch [18/30], Train Accuracy: 0.9204
# Epoch [18/30], Validation Accuracy: 0.8169, Validation Loss: 0.2833
# Epoch [19/30], Step [10/67], Train Loss: 0.2125
# Epoch [19/30], Train Accuracy: 0.8770
# Epoch [19/30], Validation Accuracy: 0.8248, Validation Loss: 0.2789
# Epoch [19/30], Step [20/67], Train Loss: 0.1581
# Epoch [19/30], Train Accuracy: 0.9012
# Epoch [19/30], Validation Accuracy: 0.8369, Validation Loss: 0.2651
# Epoch [19/30], Step [30/67], Train Loss: 0.1440
# Epoch [19/30], Train Accuracy: 0.9139
# Epoch [19/30], Validation Accuracy: 0.8262, Validation Loss: 0.2711
# Epoch [19/30], Step [40/67], Train Loss: 0.1555
# Epoch [19/30], Train Accuracy: 0.9222
# Epoch [19/30], Validation Accuracy: 0.8257, Validation Loss: 0.2782
# Epoch [19/30], Step [50/67], Train Loss: 0.1536
# Epoch [19/30], Train Accuracy: 0.9233
# Epoch [19/30], Validation Accuracy: 0.8350, Validation Loss: 0.2664
# Epoch [19/30], Step [60/67], Train Loss: 0.1889
# Epoch [19/30], Train Accuracy: 0.9266
# Epoch [19/30], Validation Accuracy: 0.8313, Validation Loss: 0.2730
# Epoch [19/30], Step [67/67], Train Loss: 0.1373
# Epoch [19/30], Train Accuracy: 0.9268
# Epoch [19/30], Validation Accuracy: 0.8290, Validation Loss: 0.2715
# Epoch [20/30], Step [10/67], Train Loss: 0.2164
# Epoch [20/30], Train Accuracy: 0.8785
# Epoch [20/30], Validation Accuracy: 0.8262, Validation Loss: 0.2809
# Epoch [20/30], Step [20/67], Train Loss: 0.1442
# Epoch [20/30], Train Accuracy: 0.9049
# Epoch [20/30], Validation Accuracy: 0.8295, Validation Loss: 0.2665
# Epoch [20/30], Step [30/67], Train Loss: 0.1457
# Epoch [20/30], Train Accuracy: 0.9124
# Epoch [20/30], Validation Accuracy: 0.8327, Validation Loss: 0.2676
# Epoch [20/30], Step [40/67], Train Loss: 0.1439
# Epoch [20/30], Train Accuracy: 0.9214
# Epoch [20/30], Validation Accuracy: 0.8239, Validation Loss: 0.2791
# Epoch [20/30], Step [50/67], Train Loss: 0.1548
# Epoch [20/30], Train Accuracy: 0.9250
# Epoch [20/30], Validation Accuracy: 0.8295, Validation Loss: 0.2713
# Epoch [20/30], Step [60/67], Train Loss: 0.1701
# Epoch [20/30], Train Accuracy: 0.9279
# Epoch [20/30], Validation Accuracy: 0.8285, Validation Loss: 0.2761
# Epoch [20/30], Step [67/67], Train Loss: 0.1560
# Epoch [20/30], Train Accuracy: 0.9279
# Epoch [20/30], Validation Accuracy: 0.8322, Validation Loss: 0.2759
# Epoch [21/30], Step [10/67], Train Loss: 0.2130
# Epoch [21/30], Train Accuracy: 0.8871
# Epoch [21/30], Validation Accuracy: 0.8271, Validation Loss: 0.2800
# Epoch [21/30], Step [20/67], Train Loss: 0.1495
# Epoch [21/30], Train Accuracy: 0.9123
# Epoch [21/30], Validation Accuracy: 0.8267, Validation Loss: 0.2825
# Epoch [21/30], Step [30/67], Train Loss: 0.1398
# Epoch [21/30], Train Accuracy: 0.9220
# Epoch [21/30], Validation Accuracy: 0.8304, Validation Loss: 0.2744
# Epoch [21/30], Step [40/67], Train Loss: 0.1330
# Epoch [21/30], Train Accuracy: 0.9283
# Epoch [21/30], Validation Accuracy: 0.8276, Validation Loss: 0.2764
# Epoch [21/30], Step [50/67], Train Loss: 0.1430
# Epoch [21/30], Train Accuracy: 0.9321
# Epoch [21/30], Validation Accuracy: 0.8369, Validation Loss: 0.2720
# Epoch [21/30], Step [60/67], Train Loss: 0.1603
# Epoch [21/30], Train Accuracy: 0.9360
# Epoch [21/30], Validation Accuracy: 0.8281, Validation Loss: 0.2780
# Epoch [21/30], Step [67/67], Train Loss: 0.1967
# Epoch [21/30], Train Accuracy: 0.9352
# Epoch [21/30], Validation Accuracy: 0.8192, Validation Loss: 0.2891
# Epoch [22/30], Step [10/67], Train Loss: 0.2106
# Epoch [22/30], Train Accuracy: 0.8883
# Epoch [22/30], Validation Accuracy: 0.8257, Validation Loss: 0.2823
# Epoch [22/30], Step [20/67], Train Loss: 0.1399
# Epoch [22/30], Train Accuracy: 0.9141
# Epoch [22/30], Validation Accuracy: 0.8341, Validation Loss: 0.2780
# Epoch [22/30], Step [30/67], Train Loss: 0.1197
# Epoch [22/30], Train Accuracy: 0.9262
# Epoch [22/30], Validation Accuracy: 0.8322, Validation Loss: 0.2696
# Epoch [22/30], Step [40/67], Train Loss: 0.1198
# Epoch [22/30], Train Accuracy: 0.9333
# Epoch [22/30], Validation Accuracy: 0.8346, Validation Loss: 0.2705
# Epoch [22/30], Step [50/67], Train Loss: 0.1344
# Epoch [22/30], Train Accuracy: 0.9363
# Epoch [22/30], Validation Accuracy: 0.8313, Validation Loss: 0.2710
# Epoch [22/30], Step [60/67], Train Loss: 0.1631
# Epoch [22/30], Train Accuracy: 0.9392
# Epoch [22/30], Validation Accuracy: 0.8150, Validation Loss: 0.2859
# Epoch [22/30], Step [67/67], Train Loss: 0.1152
# Epoch [22/30], Train Accuracy: 0.9389
# Epoch [22/30], Validation Accuracy: 0.8285, Validation Loss: 0.2766
# Epoch [23/30], Step [10/67], Train Loss: 0.2109
# Epoch [23/30], Train Accuracy: 0.8879
# Epoch [23/30], Validation Accuracy: 0.8267, Validation Loss: 0.2901
# Epoch [23/30], Step [20/67], Train Loss: 0.1282
# Epoch [23/30], Train Accuracy: 0.9160
# Epoch [23/30], Validation Accuracy: 0.8383, Validation Loss: 0.2760
# Epoch [23/30], Step [30/67], Train Loss: 0.1230
# Epoch [23/30], Train Accuracy: 0.9247
# Epoch [23/30], Validation Accuracy: 0.8299, Validation Loss: 0.2701
# Epoch [23/30], Step [40/67], Train Loss: 0.1100
# Epoch [23/30], Train Accuracy: 0.9351
# Epoch [23/30], Validation Accuracy: 0.8308, Validation Loss: 0.2722
# Epoch [23/30], Step [50/67], Train Loss: 0.1565
# Epoch [23/30], Train Accuracy: 0.9390
# Epoch [23/30], Validation Accuracy: 0.8192, Validation Loss: 0.2900
# Epoch [23/30], Step [60/67], Train Loss: 0.1671
# Epoch [23/30], Train Accuracy: 0.9417
# Epoch [23/30], Validation Accuracy: 0.8215, Validation Loss: 0.3050
# Epoch [23/30], Step [67/67], Train Loss: 0.1448
# Epoch [23/30], Train Accuracy: 0.9391
# Epoch [23/30], Validation Accuracy: 0.8201, Validation Loss: 0.2856
# Epoch [24/30], Step [10/67], Train Loss: 0.2131
# Epoch [24/30], Train Accuracy: 0.8930
# Epoch [24/30], Validation Accuracy: 0.8239, Validation Loss: 0.2873
# Epoch [24/30], Step [20/67], Train Loss: 0.1167
# Epoch [24/30], Train Accuracy: 0.9193
# Epoch [24/30], Validation Accuracy: 0.8308, Validation Loss: 0.2729
# Epoch [24/30], Step [30/67], Train Loss: 0.0968
# Epoch [24/30], Train Accuracy: 0.9311
# Epoch [24/30], Validation Accuracy: 0.8308, Validation Loss: 0.2721
# Epoch [24/30], Step [40/67], Train Loss: 0.1415
# Epoch [24/30], Train Accuracy: 0.9396
# Epoch [24/30], Validation Accuracy: 0.8066, Validation Loss: 0.3048
# Epoch [24/30], Step [50/67], Train Loss: 0.1329
# Epoch [24/30], Train Accuracy: 0.9420
# Epoch [24/30], Validation Accuracy: 0.8262, Validation Loss: 0.2750
# Epoch [24/30], Step [60/67], Train Loss: 0.1849
# Epoch [24/30], Train Accuracy: 0.9447
# Epoch [24/30], Validation Accuracy: 0.8364, Validation Loss: 0.2998
# Epoch [24/30], Step [67/67], Train Loss: 0.1090
# Epoch [24/30], Train Accuracy: 0.9459
# Epoch [24/30], Validation Accuracy: 0.8159, Validation Loss: 0.2962
# Epoch [25/30], Step [10/67], Train Loss: 0.2199
# Epoch [25/30], Train Accuracy: 0.8906
# Epoch [25/30], Validation Accuracy: 0.8318, Validation Loss: 0.2893
# Epoch [25/30], Step [20/67], Train Loss: 0.1112
# Epoch [25/30], Train Accuracy: 0.9213
# Epoch [25/30], Validation Accuracy: 0.8313, Validation Loss: 0.2740
# Epoch [25/30], Step [30/67], Train Loss: 0.1071
# Epoch [25/30], Train Accuracy: 0.9352
# Epoch [25/30], Validation Accuracy: 0.8313, Validation Loss: 0.2797
# Epoch [25/30], Step [40/67], Train Loss: 0.1013
# Epoch [25/30], Train Accuracy: 0.9432
# Epoch [25/30], Validation Accuracy: 0.8253, Validation Loss: 0.2784
# Epoch [25/30], Step [50/67], Train Loss: 0.1307
# Epoch [25/30], Train Accuracy: 0.9476
# Epoch [25/30], Validation Accuracy: 0.8248, Validation Loss: 0.2828
# Epoch [25/30], Step [60/67], Train Loss: 0.1437
# Epoch [25/30], Train Accuracy: 0.9508
# Epoch [25/30], Validation Accuracy: 0.8215, Validation Loss: 0.2923
# Epoch [25/30], Step [67/67], Train Loss: 0.1026
# Epoch [25/30], Train Accuracy: 0.9487
# Epoch [25/30], Validation Accuracy: 0.8295, Validation Loss: 0.2825
# Epoch [26/30], Step [10/67], Train Loss: 0.2083
# Epoch [26/30], Train Accuracy: 0.8906
# Epoch [26/30], Validation Accuracy: 0.8248, Validation Loss: 0.2880
# Epoch [26/30], Step [20/67], Train Loss: 0.1000
# Epoch [26/30], Train Accuracy: 0.9248
# Epoch [26/30], Validation Accuracy: 0.8346, Validation Loss: 0.2751
# Epoch [26/30], Step [30/67], Train Loss: 0.1246
# Epoch [26/30], Train Accuracy: 0.9391
# Epoch [26/30], Validation Accuracy: 0.8243, Validation Loss: 0.2836
# Epoch [26/30], Step [40/67], Train Loss: 0.1078
# Epoch [26/30], Train Accuracy: 0.9470
# Epoch [26/30], Validation Accuracy: 0.8159, Validation Loss: 0.2901
# Epoch [26/30], Step [50/67], Train Loss: 0.1173
# Epoch [26/30], Train Accuracy: 0.9495
# Epoch [26/30], Validation Accuracy: 0.8327, Validation Loss: 0.2793
# Epoch [26/30], Step [60/67], Train Loss: 0.1259
# Epoch [26/30], Train Accuracy: 0.9533
# Epoch [26/30], Validation Accuracy: 0.8201, Validation Loss: 0.2881
# Epoch [26/30], Step [67/67], Train Loss: 0.1126
# Epoch [26/30], Train Accuracy: 0.9546
# Epoch [26/30], Validation Accuracy: 0.7973, Validation Loss: 0.3233
# Epoch [27/30], Step [10/67], Train Loss: 0.2021
# Epoch [27/30], Train Accuracy: 0.8926
# Epoch [27/30], Validation Accuracy: 0.8262, Validation Loss: 0.2926
# Epoch [27/30], Step [20/67], Train Loss: 0.1001
# Epoch [27/30], Train Accuracy: 0.9275
# Epoch [27/30], Validation Accuracy: 0.8248, Validation Loss: 0.2881
# Epoch [27/30], Step [30/67], Train Loss: 0.1077
# Epoch [27/30], Train Accuracy: 0.9404
# Epoch [27/30], Validation Accuracy: 0.8183, Validation Loss: 0.2869
# Epoch [27/30], Step [40/67], Train Loss: 0.0986
# Epoch [27/30], Train Accuracy: 0.9475
# Epoch [27/30], Validation Accuracy: 0.8169, Validation Loss: 0.2960
# Epoch [27/30], Step [50/67], Train Loss: 0.1036
# Epoch [27/30], Train Accuracy: 0.9505
# Epoch [27/30], Validation Accuracy: 0.8281, Validation Loss: 0.2847
# Epoch [27/30], Step [60/67], Train Loss: 0.1372
# Epoch [27/30], Train Accuracy: 0.9537
# Epoch [27/30], Validation Accuracy: 0.8290, Validation Loss: 0.2849
# Epoch [27/30], Step [67/67], Train Loss: 0.1203
# Epoch [27/30], Train Accuracy: 0.9553
# Epoch [27/30], Validation Accuracy: 0.8057, Validation Loss: 0.3048
# Epoch [28/30], Step [10/67], Train Loss: 0.1928
# Epoch [28/30], Train Accuracy: 0.8883
# Epoch [28/30], Validation Accuracy: 0.8225, Validation Loss: 0.2878
# Epoch [28/30], Step [20/67], Train Loss: 0.0907
# Epoch [28/30], Train Accuracy: 0.9258
# Epoch [28/30], Validation Accuracy: 0.8187, Validation Loss: 0.2867
# Epoch [28/30], Step [30/67], Train Loss: 0.1007
# Epoch [28/30], Train Accuracy: 0.9357
# Epoch [28/30], Validation Accuracy: 0.8187, Validation Loss: 0.2878
# Epoch [28/30], Step [40/67], Train Loss: 0.0863
# Epoch [28/30], Train Accuracy: 0.9467
# Epoch [28/30], Validation Accuracy: 0.8243, Validation Loss: 0.2880
# Epoch [28/30], Step [50/67], Train Loss: 0.1066
# Epoch [28/30], Train Accuracy: 0.9522
# Epoch [28/30], Validation Accuracy: 0.8197, Validation Loss: 0.2870
# Epoch [28/30], Step [60/67], Train Loss: 0.1214
# Epoch [28/30], Train Accuracy: 0.9555
# Epoch [28/30], Validation Accuracy: 0.8211, Validation Loss: 0.2988
# Epoch [28/30], Step [67/67], Train Loss: 0.0747
# Epoch [28/30], Train Accuracy: 0.9573
# Epoch [28/30], Validation Accuracy: 0.8187, Validation Loss: 0.2945
# Epoch [29/30], Step [10/67], Train Loss: 0.2046
# Epoch [29/30], Train Accuracy: 0.8906
# Epoch [29/30], Validation Accuracy: 0.8299, Validation Loss: 0.3004
# Epoch [29/30], Step [20/67], Train Loss: 0.0845
# Epoch [29/30], Train Accuracy: 0.9289
# Epoch [29/30], Validation Accuracy: 0.8304, Validation Loss: 0.2861
# Epoch [29/30], Step [30/67], Train Loss: 0.0746
# Epoch [29/30], Train Accuracy: 0.9418
# Epoch [29/30], Validation Accuracy: 0.8276, Validation Loss: 0.2849
# Epoch [29/30], Step [40/67], Train Loss: 0.0888
# Epoch [29/30], Train Accuracy: 0.9517
# Epoch [29/30], Validation Accuracy: 0.8155, Validation Loss: 0.2984
# Epoch [29/30], Step [50/67], Train Loss: 0.1085
# Epoch [29/30], Train Accuracy: 0.9563
# Epoch [29/30], Validation Accuracy: 0.8178, Validation Loss: 0.2872
# Epoch [29/30], Step [60/67], Train Loss: 0.1153
# Epoch [29/30], Train Accuracy: 0.9601
# Epoch [29/30], Validation Accuracy: 0.8192, Validation Loss: 0.3128
# Epoch [29/30], Step [67/67], Train Loss: 0.0706
# Epoch [29/30], Train Accuracy: 0.9598
# Epoch [29/30], Validation Accuracy: 0.8197, Validation Loss: 0.2964
# Epoch [30/30], Step [10/67], Train Loss: 0.1906
# Epoch [30/30], Train Accuracy: 0.8973
# Epoch [30/30], Validation Accuracy: 0.8155, Validation Loss: 0.2972
# Epoch [30/30], Step [20/67], Train Loss: 0.0838
# Epoch [30/30], Train Accuracy: 0.9334
# Epoch [30/30], Validation Accuracy: 0.8173, Validation Loss: 0.2976
# Epoch [30/30], Step [30/67], Train Loss: 0.1092
# Epoch [30/30], Train Accuracy: 0.9454
# Epoch [30/30], Validation Accuracy: 0.8253, Validation Loss: 0.2943
# Epoch [30/30], Step [40/67], Train Loss: 0.0928
# Epoch [30/30], Train Accuracy: 0.9546
# Epoch [30/30], Validation Accuracy: 0.8183, Validation Loss: 0.3078
# Epoch [30/30], Step [50/67], Train Loss: 0.1003
# Epoch [30/30], Train Accuracy: 0.9586
# Epoch [30/30], Validation Accuracy: 0.8225, Validation Loss: 0.2969
# Epoch [30/30], Step [60/67], Train Loss: 0.1117
# Epoch [30/30], Train Accuracy: 0.9621
# Epoch [30/30], Validation Accuracy: 0.8187, Validation Loss: 0.3091
# Epoch [30/30], Step [67/67], Train Loss: 0.1344
# Epoch [30/30], Train Accuracy: 0.9632
# Epoch [30/30], Validation Accuracy: 0.7945, Validation Loss: 0.3445
# Ended Training, Test Accuracy: 0.8420

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)

# %% [markdown]
# # Loading the Undersampled Dataset

# %%
if LOAD_DATASET:
    train_loader = torch.load(TRAIN_PATH)
    valid_loader = torch.load(VALID_PATH)
    test_loader = torch.load(TEST_PATH)
else:
    path = './data/ptb-xl-a-large-publicly-available-electrocardiography-dataset-1.0.3/'
    print("Start loading")    
    data, raw_labels = load_dataset(path)
    print("done loading")    
    labels = compute_label_agg(raw_labels, path)

    data, labels, y = select_data(data, labels)

    data, labels, y = undersample(data, labels, y)

    train_loader, valid_loader, test_loader = get_data_loaders(
        data, labels, y, BATCH_SIZE)

    # torch.save(train_loader, TRAIN_PATH)
    # torch.save(valid_loader, VALID_PATH)
    # torch.save(test_loader, TEST_PATH)

# %% [markdown]
# # Redefine Some Options

# %%
SAVE_DIR = './model_saves_undersampled/'

# %% [markdown]
# # Training the model

# %%
EPOCH = 30

model = MMCNN_SUM().to(device)
lr = 0.0001

train_accs, valid_accs, test_acc = trainer(model, train_loader, test_loader, valid_loader, lr = lr, num_epochs = EPOCH, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# model = train_RNN(EPOCH, train_loader, valid_loader, model,
#                   criterion, optimizer, device=device, save_dir=SAVE_DIR, model_save_name=SAVE_NAME)

# %% [markdown]
# # Evaluate and plot losses

# %%
# test_accuracy = evaluate_RNN(model, test_loader)
plot_losses(save_dir=SAVE_DIR, metrics_save_name=SAVE_NAME)
rename_with_acc(SAVE_NAME, SAVE_DIR, test_acc)
